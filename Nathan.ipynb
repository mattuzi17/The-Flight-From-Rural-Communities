# %%
#import all libraries needed 
import os
import pandas as pd
from api_keys import wkey

import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
#Get Path to get to the Datasets
firepath = os.path.join('Data Sets', 'California_Fire_Incidents.csv')
singlepath = os.path.join('Data Sets','City_zhvi_single_family.csv')

#read the files 
fire = pd.read_csv(firepath)
singlecity = pd.read_csv(singlepath)

# %%
#Collecting only the columns we want 
clfire = fire[['Name','AcresBurned','ArchiveYear','Counties','Started','Extinguished', 'Latitude',
       'Longitude','Fatalities','Injuries','StructuresDamaged', 'StructuresDestroyed',
       'StructuresEvacuated', 'StructuresThreatened','Location']]
#sort the 
clfire.sort_values(by ='AcresBurned',ascending = False)
# Out:
#                                 Name  AcresBurned  ArchiveYear     Counties  \
# 1055  Ranch Fire (Mendocino Complex)     410203.0         2018        Glenn
# 1054  Ranch Fire (Mendocino Complex)     410203.0         2018       Colusa
# 1056  Ranch Fire (Mendocino Complex)     410203.0         2018         Lake
# 1057  Ranch Fire (Mendocino Complex)     410203.0         2018    Mendocino
# 617                      Thomas Fire     281893.0         2017      Ventura
# ...                              ...          ...          ...          ...
# 1043                Rattlesnake Fire          0.0         2017     Mariposa
# 613                         Old Fire          0.0         2016  Los Angeles
# 1633                     Cashe Fire           NaN         2019         Yolo
# 1634                        Oak Fire          NaN         2019    San Diego
# 1635                   Johnson Fire           NaN         2019    Riverside
#
#                    Started          Extinguished   Latitude   Longitude  \
# 1055  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1054  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1056  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1057  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 617   2017-12-04T18:28:00Z  2019-03-14T11:24:00Z  34.415210 -119.091240
# ...                    ...                   ...        ...         ...
# 1043  2017-09-07T15:00:00Z  2018-01-09T13:19:00Z  37.735960 -119.782560
# 613   2016-06-04T16:09:00Z  2016-06-13T12:30:00Z   0.000000    0.000000
# 1633  2019-11-25T12:02:02Z                   NaN  38.734634 -121.729691
# 1634  2019-10-22T19:20:44Z                   NaN  33.351145 -117.403719
# 1635  2019-10-14T15:32:20Z                   NaN  33.451480 -116.058980
#
#       Fatalities  Injuries  StructuresDamaged  StructuresDestroyed  \
# 1055         1.0       3.0                NaN                246.0
# 1054         1.0       3.0                NaN                246.0
# 1056         1.0       3.0                NaN                246.0
# 1057         1.0       3.0                NaN                246.0
# 617          NaN       NaN              280.0               1063.0
# ...          ...       ...                ...                  ...
# 1043         NaN       NaN                NaN                  NaN
# 613          NaN       NaN                NaN                  NaN
# 1633         NaN       NaN                NaN                  NaN
# 1634         NaN       NaN                NaN                  NaN
# 1635         NaN       NaN                NaN                  NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 1055                  NaN                1050.0
# 1054                  NaN                1050.0
# 1056                  NaN                1050.0
# 1057                  NaN                1050.0
# 617                   NaN                   NaN
# ...                   ...                   ...
# 1043                  NaN                   NaN
# 613                   NaN                   NaN
# 1633                  NaN                   NaN
# 1634                  NaN                   NaN
# 1635                  NaN                   NaN
#
#                                                Location
# 1055  off Highway 20 near Potter Valley, northeast o...
# 1054  off Highway 20 near Potter Valley, northeast o...
# 1056  off Highway 20 near Potter Valley, northeast o...
# 1057  off Highway 20 near Potter Valley, northeast o...
# 617          Hwy 150 and Hwy 126, north of Santa Paula
# ...                                                 ...
# 1043         Hwy 120 and Big Oak Flat Road near Foresta
# 613   off of Old Topanga Canyon Road and Mulholland ...
# 1633  County Road 102 and County Road 17, North of W...
# 1634  Near Basilone Road and Las Pulgas Road, near C...
# 1635                          Johnson Street and Ave 82
#
# [1636 rows x 15 columns]

# %%
#to get all the names of the columns we want
singlecolumns = []
singlecolumns = singlecity.columns
counter = 0
yearlist = []
for i in singlecolumns:
    counter +=1
    if counter > 211:
        yearlist.append(i)
#print the list to copy it and paste it in the next cells
yearlist
# Out:
# ['2012-12-31',
#  '2013-01-31',
#  '2013-02-28',
#  '2013-03-31',
#  '2013-04-30',
#  '2013-05-31',
#  '2013-06-30',
#  '2013-07-31',
#  '2013-08-31',
#  '2013-09-30',
#  '2013-10-31',
#  '2013-11-30',
#  '2013-12-31',
#  '2014-01-31',
#  '2014-02-28',
#  '2014-03-31',
#  '2014-04-30',
#  '2014-05-31',
#  '2014-06-30',
#  '2014-07-31',
#  '2014-08-31',
#  '2014-09-30',
#  '2014-10-31',
#  '2014-11-30',
#  '2014-12-31',
#  '2015-01-31',
#  '2015-02-28',
#  '2015-03-31',
#  '2015-04-30',
#  '2015-05-31',
#  '2015-06-30',
#  '2015-07-31',
#  '2015-08-31',
#  '2015-09-30',
#  '2015-10-31',
#  '2015-11-30',
#  '2015-12-31',
#  '2016-01-31',
#  '2016-02-29',
#  '2016-03-31',
#  '2016-04-30',
#  '2016-05-31',
#  '2016-06-30',
#  '2016-07-31',
#  '2016-08-31',
#  '2016-09-30',
#  '2016-10-31',
#  '2016-11-30',
#  '2016-12-31',
#  '2017-01-31',
#  '2017-02-28',
#  '2017-03-31',
#  '2017-04-30',
#  '2017-05-31',
#  '2017-06-30',
#  '2017-07-31',
#  '2017-08-31',
#  '2017-09-30',
#  '2017-10-31',
#  '2017-11-30',
#  '2017-12-31',
#  '2018-01-31',
#  '2018-02-28',
#  '2018-03-31',
#  '2018-04-30',
#  '2018-05-31',
#  '2018-06-30',
#  '2018-07-31',
#  '2018-08-31',
#  '2018-09-30',
#  '2018-10-31',
#  '2018-11-30',
#  '2018-12-31',
#  '2019-01-31',
#  '2019-02-28',
#  '2019-03-31',
#  '2019-04-30',
#  '2019-05-31',
#  '2019-06-30',
#  '2019-07-31',
#  '2019-08-31',
#  '2019-09-30',
#  '2019-10-31',
#  '2019-11-30',
#  '2019-12-31',
#  '2020-01-31',
#  '2020-02-29',
#  '2020-03-31',
#  '2020-04-30',
#  '2020-05-31',
#  '2020-06-30']

# %%
#selecting the columns we want
clsinglecity = singlecity[["RegionID","SizeRank","RegionName","RegionType","StateName","State","Metro","CountyName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 

clsinglecity
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 26492     51821     29449  Eastabuchie       City        MS    MS
# 26493    232607     29449         Dean       City        TX    TX
# 26494      6638     29449      Pulaski       City        GA    GA
# 26495     33089     29449    New Paris       City        PA    PA
# 26496     11693     30967  Great Lakes       City        IL    IL
#
#                                   Metro          CountyName  2012-12-31  \
# 0           New York-Newark-Jersey City       Queens County    456770.0
# 1        Los Angeles-Long Beach-Anaheim  Los Angeles County    450942.0
# 2      Houston-The Woodlands-Sugar Land       Harris County    123220.0
# 3              Chicago-Naperville-Elgin         Cook County    157394.0
# 4             San Antonio-New Braunfels        Bexar County    125317.0
# ...                                 ...                 ...         ...
# 26492                            Laurel        Jones County     64854.0
# 26493                     Wichita Falls         Clay County    124149.0
# 26494                               NaN      Candler County     63066.0
# 26495                               NaN      Bedford County         NaN
# 26496          Chicago-Naperville-Elgin         Cook County    249843.0
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 0        457813.0  ...    672936.0    672209.0    671450.0    671253.0
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 2        124046.0  ...    192561.0    193168.0    193616.0    194133.0
# 3        158940.0  ...    228316.0    228191.0    228145.0    228217.0
# 4        126125.0  ...    186918.0    187543.0    188271.0    188410.0
# ...           ...  ...         ...         ...         ...         ...
# 26492     65194.0  ...     81352.0     81091.0     81224.0     81612.0
# 26493    124473.0  ...    181453.0    181941.0    182497.0    182893.0
# 26494     63485.0  ...     97205.0     97299.0     97627.0     97836.0
# 26495         NaN  ...    151755.0    152421.0    153723.0    154705.0
# 26496    248164.0  ...    270495.0    269721.0    269156.0    267781.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 0        671526.0    671719.0    671601.0    672261.0    672389.0    673213.0
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 2        194270.0    194724.0    195586.0    196630.0    197445.0    197941.0
# 3        228561.0    229004.0    229648.0    230000.0    230383.0    230957.0
# 4        188913.0    189028.0    189564.0    189684.0    189929.0    190068.0
# ...           ...         ...         ...         ...         ...         ...
# 26492     82230.0     83016.0     83265.0     83905.0     84212.0     84165.0
# 26493    183317.0    183288.0    183121.0    182587.0    181882.0    181599.0
# 26494     98273.0     98746.0     99501.0    100522.0    101658.0    102356.0
# 26495    155025.0    155328.0    155871.0    156029.0    155906.0    154597.0
# 26496    267119.0    266509.0    264543.0    261258.0    260245.0    260579.0
#
# [26497 rows x 99 columns]

# %%
#Grabing fires in Northern California only
Nfire = clfire.loc[clfire['Latitude'].gt(37)==True]
Nfire.sort_values(by ='AcresBurned',ascending = False)
# Out:
#                                 Name  AcresBurned  ArchiveYear   Counties  \
# 1057  Ranch Fire (Mendocino Complex)     410203.0         2018  Mendocino
# 1056  Ranch Fire (Mendocino Complex)     410203.0         2018       Lake
# 1055  Ranch Fire (Mendocino Complex)     410203.0         2018      Glenn
# 1054  Ranch Fire (Mendocino Complex)     410203.0         2018     Colusa
# 0                           Rim Fire     257314.0         2013   Tuolumne
# ...                              ...          ...          ...        ...
# 1046                      Creek Fire          0.0         2017      Glenn
# 1047                   Antelope Fire          0.0         2017     Lassen
# 1048                    Klamath Fire          0.0         2017   Siskiyou
# 1053              Oroville Spillway           0.0         2017      Butte
# 1633                     Cashe Fire           NaN         2019       Yolo
#
#                    Started          Extinguished   Latitude   Longitude  \
# 1057  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1056  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1055  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1054  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 0     2013-08-17T15:25:00Z  2013-09-06T18:30:00Z  37.857000 -120.086000
# ...                    ...                   ...        ...         ...
# 1046  2017-07-19T17:30:00Z  2018-01-09T12:02:00Z  39.754250 -122.176570
# 1047  2017-07-06T13:00:00Z  2018-01-09T11:45:00Z  40.636100 -120.964300
# 1048  2017-07-04T15:21:00Z  2018-01-09T11:43:00Z  41.866090 -122.730310
# 1053  2017-02-07T14:00:00Z  2018-01-09T09:24:00Z  39.511580 -121.556330
# 1633  2019-11-25T12:02:02Z                   NaN  38.734634 -121.729691
#
#       Fatalities  Injuries  StructuresDamaged  StructuresDestroyed  \
# 1057         1.0       3.0                NaN                246.0
# 1056         1.0       3.0                NaN                246.0
# 1055         1.0       3.0                NaN                246.0
# 1054         1.0       3.0                NaN                246.0
# 0            NaN       NaN                NaN                  NaN
# ...          ...       ...                ...                  ...
# 1046         NaN       NaN                NaN                  NaN
# 1047         NaN       NaN                NaN                  NaN
# 1048         NaN       NaN                NaN                  NaN
# 1053         NaN       NaN                NaN                  NaN
# 1633         NaN       NaN                NaN                  NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 1057                  NaN                1050.0
# 1056                  NaN                1050.0
# 1055                  NaN                1050.0
# 1054                  NaN                1050.0
# 0                     NaN                   NaN
# ...                   ...                   ...
# 1046                  NaN                   NaN
# 1047                  NaN                   NaN
# 1048                  NaN                   NaN
# 1053                  NaN                   NaN
# 1633                  NaN                   NaN
#
#                                                Location
# 1057  off Highway 20 near Potter Valley, northeast o...
# 1056  off Highway 20 near Potter Valley, northeast o...
# 1055  off Highway 20 near Potter Valley, northeast o...
# 1054  off Highway 20 near Potter Valley, northeast o...
# 0               3 miles east of Groveland along Hwy 120
# ...                                                 ...
# 1046                                Stony Creek, Orland
# 1047  10 Miles west of Eagle Lake, Lassen National F...
# 1048     Off Hwy 96 & Dutch Creek Rd, east of Oak Knoll
# 1053  Oroville Dam, Canyon Dr. & Oroville Dam Rd, Or...
# 1633  County Road 102 and County Road 17, North of W...
#
# [844 rows x 15 columns]

# %%
#looking through the data
grfire = Nfire.groupby(['Name','Counties','Started', "Extinguished"]).mean().sort_values(by ='AcresBurned',ascending = False)
grfire.to_csv('../GroupedFire.csv')
grfire
# Out:
#                                                                                                  AcresBurned  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z     410203.0
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z     410203.0
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z     410203.0
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z     410203.0
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z     257314.0
# ...                                                                                                      ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z          0.0
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z          0.0
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z          0.0
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z          0.0
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z          0.0
#
#                                                                                                  ArchiveYear  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         2018
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         2018
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         2018
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         2018
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z         2013
# ...                                                                                                      ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z         2017
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z         2017
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z         2017
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z         2018
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z         2014
#
#                                                                                                   Latitude  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z  39.243283
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z  39.243283
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z  39.243283
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z  39.243283
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z  37.857000
# ...                                                                                                    ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z  39.754250
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z  41.702000
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z  38.318020
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z  39.712170
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z  41.796000
#
#                                                                                                   Longitude  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z -123.103367
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z -123.103367
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z -123.103367
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z -123.103367
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z -120.086000
# ...                                                                                                     ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z -122.176570
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z -123.508000
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z -122.390520
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z -121.773850
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z -123.374000
#
#                                                                                                  Fatalities  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         1.0
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         1.0
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         1.0
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z         1.0
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z         NaN
# ...                                                                                                     ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z         NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z         NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z         NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z         NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z         NaN
#
#                                                                                                  Injuries  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z       3.0
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z       3.0
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z       3.0
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z       3.0
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z       NaN
# ...                                                                                                   ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z       NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z       NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z       NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z       NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z       NaN
#
#                                                                                                  StructuresDamaged  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                NaN
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                NaN
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                NaN
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                NaN
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z                NaN
# ...                                                                                                            ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z                NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z                NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z                NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z                NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z                NaN
#
#                                                                                                  StructuresDestroyed  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                246.0
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                246.0
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                246.0
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                246.0
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z                  NaN
# ...                                                                                                              ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z                  NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z                  NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z                  NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z                  NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z                  NaN
#
#                                                                                                  StructuresEvacuated  \
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                  NaN
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                  NaN
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                  NaN
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                  NaN
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z                  NaN
# ...                                                                                                              ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z                  NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z                  NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z                  NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z                  NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z                  NaN
#
#                                                                                                  StructuresThreatened
# Name                                        Counties  Started              Extinguished
# Ranch Fire (Mendocino Complex)              Colusa    2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                1050.0
#                                             Glenn     2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                1050.0
#                                             Lake      2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                1050.0
#                                             Mendocino 2018-07-27T12:05:00Z 2019-01-04T09:33:00Z                1050.0
# Rim Fire                                    Tuolumne  2013-08-17T15:25:00Z 2013-09-06T18:30:00Z                   NaN
# ...                                                                                                               ...
# Creek Fire                                  Glenn     2017-07-19T17:30:00Z 2018-01-09T12:02:00Z                   NaN
# Clear Complex (merged into Eclipse Complex) Siskiyou  2017-07-25T12:45:00Z 2018-01-09T12:05:00Z                   NaN
# Partrick Fire (Central LNU Complex)         Napa      2017-10-08T23:48:00Z 2018-01-09T13:33:00Z                   NaN
# Honey Flooding                              Butte     2018-11-29T23:30:00Z 2019-01-04T08:42:00Z                   NaN
# Happy Camp Complex                          Siskiyou  2014-08-11T22:00:00Z 2014-08-14T09:30:00Z                   NaN
#
# [807 rows x 10 columns]

# %%
#usinging only the cities in California
SingleCCal = singlecity.loc[singlecity['StateName'] =='CA']
SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  1996-01-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    193916.0
# 8                       San Diego-Carlsbad      San Diego County    216701.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    218822.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    305212.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    109287.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County         NaN
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        1996-02-29  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 1        193960.0  ...    759513.0    763224.0    766002.0    770182.0
# 8        216342.0  ...    725853.0    727571.0    730853.0    734733.0
# 11       218222.0  ...   1020573.0   1024151.0   1027883.0   1034380.0
# 14       304198.0  ...   1505519.0   1511407.0   1519514.0   1531203.0
# 30       108768.0  ...    350842.0    353592.0    356618.0    358601.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    610914.0    613382.0    613047.0    613266.0
# 26406         NaN  ...     34627.0     34688.0     34687.0     34614.0
# 26435         NaN  ...    211217.0    213588.0    215080.0    215313.0
# 26466         NaN  ...    672166.0    680526.0    688958.0    698685.0
# 26472         NaN  ...     48902.0     48826.0     48758.0     48704.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 8        740112.0    744208.0    748744.0    751096.0    753893.0    754223.0
# 11      1046264.0   1057397.0   1068942.0   1074703.0   1080058.0   1088749.0
# 14      1535710.0   1539101.0   1535882.0   1533941.0   1523778.0   1511653.0
# 30       360857.0    362724.0    365194.0    366583.0    366772.0    366198.0
# ...           ...         ...         ...         ...         ...         ...
# 26401    611159.0    610241.0    611718.0    615934.0    623633.0    631555.0
# 26406     34465.0     34328.0     34042.0     33631.0     33159.0     32578.0
# 26435    215703.0    214733.0    212881.0    211004.0    208809.0    205041.0
# 26466    707643.0    720505.0    733777.0    749997.0    767960.0    792172.0
# 26472     48665.0     48617.0     48550.0     48529.0     48557.0     48661.0
#
# [1108 rows x 302 columns]

# %%
#retrieving a list of the city names from the Single family owned homes
Single_City_Cal_List = SingleCCal['RegionName']
Single_City_Cal_List
# Out:
# 1          Los Angeles
# 8            San Diego
# 11            San Jose
# 14       San Francisco
# 30          Sacramento
#              ...
# 26401         Lockwood
# 26406           Tecopa
# 26435        Challenge
# 26466         Honeydew
# 26472           Darwin
# Name: RegionName, Length: 1108, dtype: object

# %%
#Creating lata and lng columns in the Single Family owned homes
SingleCCal['Latitude'] = ""
SingleCCal['Longitude'] =""
#creating lists to store the data of failed cities 
failedindex = []
failedcity = []

#create a for loop to find the lat and lng of the cities 
SingleCCal = pd.DataFrame(SingleCCal)
for index, row in SingleCCal.iterrows():
    #connect to the Weather API to get latitude and longitude for the cities 
    wurl =  f"http://api.openweathermap.org/data/2.5/weather?q={row[2]}&appid={wkey}"
    wapi = requests.get(wurl)
    #create a try and fail to not break the code if the information isnt found
    try:
        #grabbing the data from the API and loading it onto the DF
        SingleCCal.loc[index,'Longitude'] = wapi.json()['coord']['lon']
        SingleCCal.loc[index,'Latitude']  = wapi.json()['coord']['lat']
        #print successful
        print(f'Found {row[2]} in weather IPA, and Adding Latitude and Longitude')
    except:
        #print Failure
        print(f'Failed at finding Latitude and Longitude for {row[2]}')
        #store city information
        failedcity.append(row[2])
        failedindex.append(index)
# Out:
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Found Los Angeles in weather IPA, and Adding Latitude and Longitude
# Found San Diego in weather IPA, and Adding Latitude and Longitude
# Found San Jose in weather IPA, and Adding Latitude and Longitude
# Found San Francisco in weather IPA, and Adding Latitude and Longitude
# Found Sacramento in weather IPA, and Adding Latitude and Longitude
# Found Fresno in weather IPA, and Adding Latitude and Longitude
# Found Long Beach in weather IPA, and Adding Latitude and Longitude
# Found Oakland in weather IPA, and Adding Latitude and Longitude
# Found Riverside in weather IPA, and Adding Latitude and Longitude
# Found Bakersfield in weather IPA, and Adding Latitude and Longitude
# Found Anaheim in weather IPA, and Adding Latitude and Longitude
# Found Santa Ana in weather IPA, and Adding Latitude and Longitude
# Found Stockton in weather IPA, and Adding Latitude and Longitude
# Found Modesto in weather IPA, and Adding Latitude and Longitude
# Found San Bernardino in weather IPA, and Adding Latitude and Longitude
# Found Chula Vista in weather IPA, and Adding Latitude and Longitude
# Found Irvine in weather IPA, and Adding Latitude and Longitude
# Found Fremont in weather IPA, and Adding Latitude and Longitude
# Found Santa Clarita in weather IPA, and Adding Latitude and Longitude
# Found Fontana in weather IPA, and Adding Latitude and Longitude
# Found Santa Rosa in weather IPA, and Adding Latitude and Longitude
# Found Oxnard in weather IPA, and Adding Latitude and Longitude
# Found Corona in weather IPA, and Adding Latitude and Longitude
# Found Oceanside in weather IPA, and Adding Latitude and Longitude
# Found Glendale in weather IPA, and Adding Latitude and Longitude
# Found Moreno Valley in weather IPA, and Adding Latitude and Longitude
# Found Huntington Beach in weather IPA, and Adding Latitude and Longitude
# Found Salinas in weather IPA, and Adding Latitude and Longitude
# Found Hayward in weather IPA, and Adding Latitude and Longitude
# Found Lancaster in weather IPA, and Adding Latitude and Longitude
# Found Garden Grove in weather IPA, and Adding Latitude and Longitude
# Found Escondido in weather IPA, and Adding Latitude and Longitude
# Found Ontario in weather IPA, and Adding Latitude and Longitude
# Found Rancho Cucamonga in weather IPA, and Adding Latitude and Longitude
# Found Palmdale in weather IPA, and Adding Latitude and Longitude
# Found El Cajon in weather IPA, and Adding Latitude and Longitude
# Found Elk Grove in weather IPA, and Adding Latitude and Longitude
# Found Pomona in weather IPA, and Adding Latitude and Longitude
# Found Visalia in weather IPA, and Adding Latitude and Longitude
# Found Whittier in weather IPA, and Adding Latitude and Longitude
# Found Sunnyvale in weather IPA, and Adding Latitude and Longitude
# Found Pasadena in weather IPA, and Adding Latitude and Longitude
# Found Santa Maria in weather IPA, and Adding Latitude and Longitude
# Found Torrance in weather IPA, and Adding Latitude and Longitude
# Found Fullerton in weather IPA, and Adding Latitude and Longitude
# Found Orange in weather IPA, and Adding Latitude and Longitude
# Found Compton in weather IPA, and Adding Latitude and Longitude
# Found Inglewood in weather IPA, and Adding Latitude and Longitude
# Found Concord in weather IPA, and Adding Latitude and Longitude
# Found Thousand Oaks in weather IPA, and Adding Latitude and Longitude
# Found Victorville in weather IPA, and Adding Latitude and Longitude
# Found Roseville in weather IPA, and Adding Latitude and Longitude
# Found Simi Valley in weather IPA, and Adding Latitude and Longitude
# Found Murrieta in weather IPA, and Adding Latitude and Longitude
# Found Temecula in weather IPA, and Adding Latitude and Longitude
# Found Hemet in weather IPA, and Adding Latitude and Longitude
# Found East Los Angeles in weather IPA, and Adding Latitude and Longitude
# Found Vallejo in weather IPA, and Adding Latitude and Longitude
# Found Santa Clara in weather IPA, and Adding Latitude and Longitude
# Found Berkeley in weather IPA, and Adding Latitude and Longitude
# Found Clovis in weather IPA, and Adding Latitude and Longitude
# Found Vista in weather IPA, and Adding Latitude and Longitude
# Found Richmond in weather IPA, and Adding Latitude and Longitude
# Found Costa Mesa in weather IPA, and Adding Latitude and Longitude
# Found El Monte in weather IPA, and Adding Latitude and Longitude
# Found Chico in weather IPA, and Adding Latitude and Longitude
# Found Downey in weather IPA, and Adding Latitude and Longitude
# Found Tracy in weather IPA, and Adding Latitude and Longitude
# Found Ventura in weather IPA, and Adding Latitude and Longitude
# Found West Covina in weather IPA, and Adding Latitude and Longitude
# Found Redding in weather IPA, and Adding Latitude and Longitude
# Found Carlsbad in weather IPA, and Adding Latitude and Longitude
# Found Santa Barbara in weather IPA, and Adding Latitude and Longitude
# Found Norwalk in weather IPA, and Adding Latitude and Longitude
# Found Antioch in weather IPA, and Adding Latitude and Longitude
# Found Perris in weather IPA, and Adding Latitude and Longitude
# Found Fairfield in weather IPA, and Adding Latitude and Longitude
# Found San Leandro in weather IPA, and Adding Latitude and Longitude
# Found Burbank in weather IPA, and Adding Latitude and Longitude
# Found Vacaville in weather IPA, and Adding Latitude and Longitude
# Found Madera in weather IPA, and Adding Latitude and Longitude
# Found Hesperia in weather IPA, and Adding Latitude and Longitude
# Found San Mateo in weather IPA, and Adding Latitude and Longitude
# Found Merced in weather IPA, and Adding Latitude and Longitude
# Found Santa Cruz in weather IPA, and Adding Latitude and Longitude
# Found Daly City in weather IPA, and Adding Latitude and Longitude
# Found Rialto in weather IPA, and Adding Latitude and Longitude
# Found Napa in weather IPA, and Adding Latitude and Longitude
# Found Mission Viejo in weather IPA, and Adding Latitude and Longitude
# Found Livermore in weather IPA, and Adding Latitude and Longitude
# Found South Gate in weather IPA, and Adding Latitude and Longitude
# Found Hawthorne in weather IPA, and Adding Latitude and Longitude
# Found Indio in weather IPA, and Adding Latitude and Longitude
# Found Santa Monica in weather IPA, and Adding Latitude and Longitude
# Found Westminster in weather IPA, and Adding Latitude and Longitude
# Found Menifee in weather IPA, and Adding Latitude and Longitude
# Found San Marcos in weather IPA, and Adding Latitude and Longitude
# Found Chino in weather IPA, and Adding Latitude and Longitude
# Found Redwood City in weather IPA, and Adding Latitude and Longitude
# Found Pittsburg in weather IPA, and Adding Latitude and Longitude
# Found Newport Beach in weather IPA, and Adding Latitude and Longitude
# Found Arden-Arcade in weather IPA, and Adding Latitude and Longitude
# Found Tustin in weather IPA, and Adding Latitude and Longitude
# Found Citrus Heights in weather IPA, and Adding Latitude and Longitude
# Found Walnut Creek in weather IPA, and Adding Latitude and Longitude
# Found Buena Park in weather IPA, and Adding Latitude and Longitude
# Found Alhambra in weather IPA, and Adding Latitude and Longitude
# Found Watsonville in weather IPA, and Adding Latitude and Longitude
# Found Manteca in weather IPA, and Adding Latitude and Longitude
# Found Camarillo in weather IPA, and Adding Latitude and Longitude
# Found Apple Valley in weather IPA, and Adding Latitude and Longitude
# Found Lakewood in weather IPA, and Adding Latitude and Longitude
# Found Covina in weather IPA, and Adding Latitude and Longitude
# Found Upland in weather IPA, and Adding Latitude and Longitude
# Found Carson in weather IPA, and Adding Latitude and Longitude
# Found Porterville in weather IPA, and Adding Latitude and Longitude
# Found Mountain View in weather IPA, and Adding Latitude and Longitude
# Found Turlock in weather IPA, and Adding Latitude and Longitude
# Found Bellflower in weather IPA, and Adding Latitude and Longitude
# Found Lodi in weather IPA, and Adding Latitude and Longitude
# Found Rancho Cordova in weather IPA, and Adding Latitude and Longitude
# Found Baldwin Park in weather IPA, and Adding Latitude and Longitude
# Found Spring Valley in weather IPA, and Adding Latitude and Longitude
# Found San Ramon in weather IPA, and Adding Latitude and Longitude
# Found Redlands in weather IPA, and Adding Latitude and Longitude
# Found Folsom in weather IPA, and Adding Latitude and Longitude
# Found Huntington Park in weather IPA, and Adding Latitude and Longitude
# Found Petaluma in weather IPA, and Adding Latitude and Longitude
# Found La Mesa in weather IPA, and Adding Latitude and Longitude
# Found Lake Forest in weather IPA, and Adding Latitude and Longitude
# Found Milpitas in weather IPA, and Adding Latitude and Longitude
# Found Pleasanton in weather IPA, and Adding Latitude and Longitude
# Found Tulare in weather IPA, and Adding Latitude and Longitude
# Found Chino Hills in weather IPA, and Adding Latitude and Longitude
# Found Lake Elsinore in weather IPA, and Adding Latitude and Longitude
# Found San Rafael in weather IPA, and Adding Latitude and Longitude
# Found Yuba City in weather IPA, and Adding Latitude and Longitude
# Found Yorba Linda in weather IPA, and Adding Latitude and Longitude
# Found Redondo Beach in weather IPA, and Adding Latitude and Longitude
# Found Lynwood in weather IPA, and Adding Latitude and Longitude
# Found Union City in weather IPA, and Adding Latitude and Longitude
# Found Davis in weather IPA, and Adding Latitude and Longitude
# Found Brentwood in weather IPA, and Adding Latitude and Longitude
# Found Alameda in weather IPA, and Adding Latitude and Longitude
# Found Hanford in weather IPA, and Adding Latitude and Longitude
# Found Palo Alto in weather IPA, and Adding Latitude and Longitude
# Found Arcadia in weather IPA, and Adding Latitude and Longitude
# Found San Luis Obispo in weather IPA, and Adding Latitude and Longitude
# Found Pico Rivera in weather IPA, and Adding Latitude and Longitude
# Found Laguna Niguel in weather IPA, and Adding Latitude and Longitude
# Found Rosemead in weather IPA, and Adding Latitude and Longitude
# Found South San Francisco in weather IPA, and Adding Latitude and Longitude
# Found San Gabriel in weather IPA, and Adding Latitude and Longitude
# Found Montebello in weather IPA, and Adding Latitude and Longitude
# Found Woodland in weather IPA, and Adding Latitude and Longitude
# Found San Clemente in weather IPA, and Adding Latitude and Longitude
# Found Novato in weather IPA, and Adding Latitude and Longitude
# Found Florence-Graham in weather IPA, and Adding Latitude and Longitude
# Found Encinitas in weather IPA, and Adding Latitude and Longitude
# Found La Habra in weather IPA, and Adding Latitude and Longitude
# Found Monterey Park in weather IPA, and Adding Latitude and Longitude
# Found Gilroy in weather IPA, and Adding Latitude and Longitude
# Found National City in weather IPA, and Adding Latitude and Longitude
# Found Azusa in weather IPA, and Adding Latitude and Longitude
# Found Gardena in weather IPA, and Adding Latitude and Longitude
# Found Cupertino in weather IPA, and Adding Latitude and Longitude
# Found Carmichael in weather IPA, and Adding Latitude and Longitude
# Found Lompoc in weather IPA, and Adding Latitude and Longitude
# Found Fountain Valley in weather IPA, and Adding Latitude and Longitude
# Found South Whittier in weather IPA, and Adding Latitude and Longitude
# Found Rocklin in weather IPA, and Adding Latitude and Longitude
# Found Colton in weather IPA, and Adding Latitude and Longitude
# Found El Centro in weather IPA, and Adding Latitude and Longitude
# Found Santee in weather IPA, and Adding Latitude and Longitude
# Found Paramount in weather IPA, and Adding Latitude and Longitude
# Found Glendora in weather IPA, and Adding Latitude and Longitude
# Found Danville in weather IPA, and Adding Latitude and Longitude
# Found Palm Desert in weather IPA, and Adding Latitude and Longitude
# Found Delano in weather IPA, and Adding Latitude and Longitude
# Found Castro Valley in weather IPA, and Adding Latitude and Longitude
# Found Lincoln in weather IPA, and Adding Latitude and Longitude
# Found Hacienda Heights in weather IPA, and Adding Latitude and Longitude
# Found West Sacramento in weather IPA, and Adding Latitude and Longitude
# Found Yucaipa in weather IPA, and Adding Latitude and Longitude
# Found Oroville in weather IPA, and Adding Latitude and Longitude
# Found Placentia in weather IPA, and Adding Latitude and Longitude
# Found Hollister in weather IPA, and Adding Latitude and Longitude
# Found Poway in weather IPA, and Adding Latitude and Longitude
# Found Fallbrook in weather IPA, and Adding Latitude and Longitude
# Found Cathedral City in weather IPA, and Adding Latitude and Longitude
# Found Palm Springs in weather IPA, and Adding Latitude and Longitude
# Found La Mirada in weather IPA, and Adding Latitude and Longitude
# Found Cypress in weather IPA, and Adding Latitude and Longitude
# Found Cerritos in weather IPA, and Adding Latitude and Longitude
# Found Eastvale in weather IPA, and Adding Latitude and Longitude
# Found San Jacinto in weather IPA, and Adding Latitude and Longitude
# Found Aliso Viejo in weather IPA, and Adding Latitude and Longitude
# Found Diamond Bar in weather IPA, and Adding Latitude and Longitude
# Found Martinez in weather IPA, and Adding Latitude and Longitude
# Found Dublin in weather IPA, and Adding Latitude and Longitude
# Found Highland in weather IPA, and Adding Latitude and Longitude
# Found Morgan Hill in weather IPA, and Adding Latitude and Longitude
# Found Eureka in weather IPA, and Adding Latitude and Longitude
# Found Brea in weather IPA, and Adding Latitude and Longitude
# Found Auburn in weather IPA, and Adding Latitude and Longitude
# Found Desert Hot Springs in weather IPA, and Adding Latitude and Longitude
# Found Grass Valley in weather IPA, and Adding Latitude and Longitude
# Found Beaumont in weather IPA, and Adding Latitude and Longitude
# Found Coachella in weather IPA, and Adding Latitude and Longitude
# Found Rowland Heights in weather IPA, and Adding Latitude and Longitude
# Found Lakeside in weather IPA, and Adding Latitude and Longitude
# Found Newark in weather IPA, and Adding Latitude and Longitude
# Found Fair Oaks in weather IPA, and Adding Latitude and Longitude
# Found Monrovia in weather IPA, and Adding Latitude and Longitude
# Found Bell Gardens in weather IPA, and Adding Latitude and Longitude
# Found Rancho Santa Margarita in weather IPA, and Adding Latitude and Longitude
# Found Campbell in weather IPA, and Adding Latitude and Longitude
# Found Menlo Park in weather IPA, and Adding Latitude and Longitude
# Found San Bruno in weather IPA, and Adding Latitude and Longitude
# Found Paso Robles in weather IPA, and Adding Latitude and Longitude
# Found San Pablo in weather IPA, and Adding Latitude and Longitude
# Found La Puente in weather IPA, and Adding Latitude and Longitude
# Found Ceres in weather IPA, and Adding Latitude and Longitude
# Found Rancho Palos Verdes in weather IPA, and Adding Latitude and Longitude
# Found Los Banos in weather IPA, and Adding Latitude and Longitude
# Found Oakley in weather IPA, and Adding Latitude and Longitude
# Found Culver City in weather IPA, and Adding Latitude and Longitude
# Found Ramona in weather IPA, and Adding Latitude and Longitude
# Found La Quinta in weather IPA, and Adding Latitude and Longitude
# Found Montclair in weather IPA, and Adding Latitude and Longitude
# Found Pacifica in weather IPA, and Adding Latitude and Longitude
# Found El Dorado Hills in weather IPA, and Adding Latitude and Longitude
# Found Atwater in weather IPA, and Adding Latitude and Longitude
# Found Rohnert Park in weather IPA, and Adding Latitude and Longitude
# Found Moorpark in weather IPA, and Adding Latitude and Longitude
# Found Claremont in weather IPA, and Adding Latitude and Longitude
# Found Altadena in weather IPA, and Adding Latitude and Longitude
# Found Lemoore in weather IPA, and Adding Latitude and Longitude
# Found San Juan Capistrano in weather IPA, and Adding Latitude and Longitude
# Found Sonoma in weather IPA, and Adding Latitude and Longitude
# Found Wildomar in weather IPA, and Adding Latitude and Longitude
# Found West Hollywood in weather IPA, and Adding Latitude and Longitude
# Found Bell in weather IPA, and Adding Latitude and Longitude
# Found Santa Paula in weather IPA, and Adding Latitude and Longitude
# Found Placerville in weather IPA, and Adding Latitude and Longitude
# Found Temple City in weather IPA, and Adding Latitude and Longitude
# Found Calexico in weather IPA, and Adding Latitude and Longitude
# Found Los Gatos in weather IPA, and Adding Latitude and Longitude
# Found Barstow in weather IPA, and Adding Latitude and Longitude
# Found Rubidoux in weather IPA, and Adding Latitude and Longitude
# Found Beverly Hills in weather IPA, and Adding Latitude and Longitude
# Found Pleasant Hill in weather IPA, and Adding Latitude and Longitude
# Found Marysville in weather IPA, and Adding Latitude and Longitude
# Found Manhattan Beach in weather IPA, and Adding Latitude and Longitude
# Found Sanger in weather IPA, and Adding Latitude and Longitude
# Found Dana Point in weather IPA, and Adding Latitude and Longitude
# Found Shingle Springs in weather IPA, and Adding Latitude and Longitude
# Found Ridgecrest in weather IPA, and Adding Latitude and Longitude
# Found Galt in weather IPA, and Adding Latitude and Longitude
# Found Adelanto in weather IPA, and Adding Latitude and Longitude
# Found San Dimas in weather IPA, and Adding Latitude and Longitude
# Found La Verne in weather IPA, and Adding Latitude and Longitude
# Found Oakdale in weather IPA, and Adding Latitude and Longitude
# Found Banning in weather IPA, and Adding Latitude and Longitude
# Found Tehachapi in weather IPA, and Adding Latitude and Longitude
# Found Reedley in weather IPA, and Adding Latitude and Longitude
# Found Lawndale in weather IPA, and Adding Latitude and Longitude
# Found Los Altos in weather IPA, and Adding Latitude and Longitude
# Found Foster City in weather IPA, and Adding Latitude and Longitude
# Found Dinuba in weather IPA, and Adding Latitude and Longitude
# Found Atascadero in weather IPA, and Adding Latitude and Longitude
# Found Westmont in weather IPA, and Adding Latitude and Longitude
# Found Saratoga in weather IPA, and Adding Latitude and Longitude
# Found Winchester in weather IPA, and Adding Latitude and Longitude
# Found Ukiah in weather IPA, and Adding Latitude and Longitude
# Found Orangevale in weather IPA, and Adding Latitude and Longitude
# Found Burlingame in weather IPA, and Adding Latitude and Longitude
# Found Seaside in weather IPA, and Adding Latitude and Longitude
# Found Monterey in weather IPA, and Adding Latitude and Longitude
# Found Laguna Hills in weather IPA, and Adding Latitude and Longitude
# Found Walnut in weather IPA, and Adding Latitude and Longitude
# Found Selma in weather IPA, and Adding Latitude and Longitude
# Found San Carlos in weather IPA, and Adding Latitude and Longitude
# Found Lafayette in weather IPA, and Adding Latitude and Longitude
# Found Sebastopol in weather IPA, and Adding Latitude and Longitude
# Found San Lorenzo in weather IPA, and Adding Latitude and Longitude
# Found Arroyo Grande in weather IPA, and Adding Latitude and Longitude
# Found South Lake Tahoe in weather IPA, and Adding Latitude and Longitude
# Found Florin in weather IPA, and Adding Latitude and Longitude
# Found Mill Valley in weather IPA, and Adding Latitude and Longitude
# Found Norco in weather IPA, and Adding Latitude and Longitude
# Found Red Bluff in weather IPA, and Adding Latitude and Longitude
# Found Olivehurst in weather IPA, and Adding Latitude and Longitude
# Found Goleta in weather IPA, and Adding Latitude and Longitude
# Found Sonora in weather IPA, and Adding Latitude and Longitude
# Found Stanton in weather IPA, and Adding Latitude and Longitude
# Found Wasco in weather IPA, and Adding Latitude and Longitude
# Found Suisun City in weather IPA, and Adding Latitude and Longitude
# Found Ladera Ranch in weather IPA, and Adding Latitude and Longitude
# Found Windsor in weather IPA, and Adding Latitude and Longitude
# Found East Palo Alto in weather IPA, and Adding Latitude and Longitude
# Found Imperial Beach in weather IPA, and Adding Latitude and Longitude
# Found Belmont in weather IPA, and Adding Latitude and Longitude
# Found Maywood in weather IPA, and Adding Latitude and Longitude
# Found Isla Vista in weather IPA, and Adding Latitude and Longitude
# Found Corcoran in weather IPA, and Adding Latitude and Longitude
# Found South Pasadena in weather IPA, and Adding Latitude and Longitude
# Found Lemon Grove in weather IPA, and Adding Latitude and Longitude
# Found Soledad in weather IPA, and Adding Latitude and Longitude
# Found Benicia in weather IPA, and Adding Latitude and Longitude
# Found Paradise in weather IPA, and Adding Latitude and Longitude
# Found Patterson in weather IPA, and Adding Latitude and Longitude
# Found Aptos in weather IPA, and Adding Latitude and Longitude
# Found Yucca Valley in weather IPA, and Adding Latitude and Longitude
# Found Oildale in weather IPA, and Adding Latitude and Longitude
# Found Cudahy in weather IPA, and Adding Latitude and Longitude
# Found Seal Beach in weather IPA, and Adding Latitude and Longitude
# Found El Cerrito in weather IPA, and Adding Latitude and Longitude
# Found San Fernando in weather IPA, and Adding Latitude and Longitude
# Found Anderson in weather IPA, and Adding Latitude and Longitude
# Found Agoura Hills in weather IPA, and Adding Latitude and Longitude
# Found Mira Loma in weather IPA, and Adding Latitude and Longitude
# Found Coronado in weather IPA, and Adding Latitude and Longitude
# Found Rosemont in weather IPA, and Adding Latitude and Longitude
# Found North Tustin in weather IPA, and Adding Latitude and Longitude
# Found Calabasas in weather IPA, and Adding Latitude and Longitude
# Found Granite Bay in weather IPA, and Adding Latitude and Longitude
# Found Port Hueneme in weather IPA, and Adding Latitude and Longitude
# Found Dixon in weather IPA, and Adding Latitude and Longitude
# Found Castaic in weather IPA, and Adding Latitude and Longitude
# Found Millbrae in weather IPA, and Adding Latitude and Longitude
# Found Chowchilla in weather IPA, and Adding Latitude and Longitude
# Found Valley Center in weather IPA, and Adding Latitude and Longitude
# Found American Canyon in weather IPA, and Adding Latitude and Longitude
# Found Phelan in weather IPA, and Adding Latitude and Longitude
# Found West Carson in weather IPA, and Adding Latitude and Longitude
# Found Duarte in weather IPA, and Adding Latitude and Longitude
# Found Loma Linda in weather IPA, and Adding Latitude and Longitude
# Found Valinda in weather IPA, and Adding Latitude and Longitude
# Found Marina in weather IPA, and Adding Latitude and Longitude
# Found Willowbrook in weather IPA, and Adding Latitude and Longitude
# Found Hercules in weather IPA, and Adding Latitude and Longitude
# Found Los Alamitos in weather IPA, and Adding Latitude and Longitude
# Found Blythe in weather IPA, and Adding Latitude and Longitude
# Found Twentynine Palms in weather IPA, and Adding Latitude and Longitude
# Found La Canada Flintridge in weather IPA, and Adding Latitude and Longitude
# Found West Puente Valley in weather IPA, and Adding Latitude and Longitude
# Found Susanville in weather IPA, and Adding Latitude and Longitude
# Found Kerman in weather IPA, and Adding Latitude and Longitude
# Found Rosamond in weather IPA, and Adding Latitude and Longitude
# Found South El Monte in weather IPA, and Adding Latitude and Longitude
# Found Brawley in weather IPA, and Adding Latitude and Longitude
# Found Shafter in weather IPA, and Adding Latitude and Longitude
# Found Crescent City in weather IPA, and Adding Latitude and Longitude
# Found Greenfield in weather IPA, and Adding Latitude and Longitude
# Found Arcata in weather IPA, and Adding Latitude and Longitude
# Found Healdsburg in weather IPA, and Adding Latitude and Longitude
# Found Arvin in weather IPA, and Adding Latitude and Longitude
# Found Lomita in weather IPA, and Adding Latitude and Longitude
# Found Ojai in weather IPA, and Adding Latitude and Longitude
# Found Coalinga in weather IPA, and Adding Latitude and Longitude
# Found Lathrop in weather IPA, and Adding Latitude and Longitude
# Found Laguna Beach in weather IPA, and Adding Latitude and Longitude
# Found Bloomington in weather IPA, and Adding Latitude and Longitude
# Found Albany in weather IPA, and Adding Latitude and Longitude
# Found Nipomo in weather IPA, and Adding Latitude and Longitude
# Found La Crescenta-Montrose in weather IPA, and Adding Latitude and Longitude
# Found Nevada City in weather IPA, and Adding Latitude and Longitude
# Found Lindsay in weather IPA, and Adding Latitude and Longitude
# Found Pinole in weather IPA, and Adding Latitude and Longitude
# Found Truckee in weather IPA, and Adding Latitude and Longitude
# Found Malibu in weather IPA, and Adding Latitude and Longitude
# Found Alpine in weather IPA, and Adding Latitude and Longitude
# Found Hermosa Beach in weather IPA, and Adding Latitude and Longitude
# Found McKinleyville in weather IPA, and Adding Latitude and Longitude
# Found Fillmore in weather IPA, and Adding Latitude and Longitude
# Found Santa Fe Springs in weather IPA, and Adding Latitude and Longitude
# Found Orinda in weather IPA, and Adding Latitude and Longitude
# Found Taft in weather IPA, and Adding Latitude and Longitude
# Found Ripon in weather IPA, and Adding Latitude and Longitude
# Found Rosedale in weather IPA, and Adding Latitude and Longitude
# Found South San Jose Hills in weather IPA, and Adding Latitude and Longitude
# Found Thermal in weather IPA, and Adding Latitude and Longitude
# Found Riverbank in weather IPA, and Adding Latitude and Longitude
# Found Alamo in weather IPA, and Adding Latitude and Longitude
# Found Rancho Mirage in weather IPA, and Adding Latitude and Longitude
# Found Moraga in weather IPA, and Adding Latitude and Longitude
# Found Artesia in weather IPA, and Adding Latitude and Longitude
# Found El Segundo in weather IPA, and Adding Latitude and Longitude
# Found Bonita in weather IPA, and Adding Latitude and Longitude
# Found Kingsburg in weather IPA, and Adding Latitude and Longitude
# Found Carpinteria in weather IPA, and Adding Latitude and Longitude
# Found Exeter in weather IPA, and Adding Latitude and Longitude
# Found Livingston in weather IPA, and Adding Latitude and Longitude
# Found Laguna Woods in weather IPA, and Adding Latitude and Longitude
# Found Nuevo in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Mc Farland
# Found La Palma in weather IPA, and Adding Latitude and Longitude
# Found Parlier in weather IPA, and Adding Latitude and Longitude
# Found Winton in weather IPA, and Adding Latitude and Longitude
# Found Glen Avon in weather IPA, and Adding Latitude and Longitude
# Found Half Moon Bay in weather IPA, and Adding Latitude and Longitude
# Found Orland in weather IPA, and Adding Latitude and Longitude
# Found San Anselmo in weather IPA, and Adding Latitude and Longitude
# Found Corning in weather IPA, and Adding Latitude and Longitude
# Found Loomis in weather IPA, and Adding Latitude and Longitude
# Found King City in weather IPA, and Adding Latitude and Longitude
# Found Cottonwood in weather IPA, and Adding Latitude and Longitude
# Found Firebaugh in weather IPA, and Adding Latitude and Longitude
# Found Pacific Grove in weather IPA, and Adding Latitude and Longitude
# Found Rio Linda in weather IPA, and Adding Latitude and Longitude
# Found Littlerock in weather IPA, and Adding Latitude and Longitude
# Found Oak Park in weather IPA, and Adding Latitude and Longitude
# Found Carmel-by-the-Sea in weather IPA, and Adding Latitude and Longitude
# Found Los Osos in weather IPA, and Adding Latitude and Longitude
# Found Scotts Valley in weather IPA, and Adding Latitude and Longitude
# Found Stanford in weather IPA, and Adding Latitude and Longitude
# Found Clearlake in weather IPA, and Adding Latitude and Longitude
# Found Imperial in weather IPA, and Adding Latitude and Longitude
# Found Hawaiian Gardens in weather IPA, and Adding Latitude and Longitude
# Found Coto de Caza in weather IPA, and Adding Latitude and Longitude
# Found Hughson in weather IPA, and Adding Latitude and Longitude
# Found Westlake Village in weather IPA, and Adding Latitude and Longitude
# Found Alum Rock in weather IPA, and Adding Latitude and Longitude
# Found Willits in weather IPA, and Adding Latitude and Longitude
# Found Avenal in weather IPA, and Adding Latitude and Longitude
# Found Holtville in weather IPA, and Adding Latitude and Longitude
# Found Grover Beach in weather IPA, and Adding Latitude and Longitude
# Found Fort Bragg in weather IPA, and Adding Latitude and Longitude
# Found Bishop in weather IPA, and Adding Latitude and Longitude
# Found Clayton in weather IPA, and Adding Latitude and Longitude
# Found Commerce in weather IPA, and Adding Latitude and Longitude
# Found San Marino in weather IPA, and Adding Latitude and Longitude
# Found Avocado Heights in weather IPA, and Adding Latitude and Longitude
# Found Valley Springs in weather IPA, and Adding Latitude and Longitude
# Found Pedley in weather IPA, and Adding Latitude and Longitude
# Found Escalon in weather IPA, and Adding Latitude and Longitude
# Found Fortuna in weather IPA, and Adding Latitude and Longitude
# Found Newman in weather IPA, and Adding Latitude and Longitude
# Found Lamont in weather IPA, and Adding Latitude and Longitude
# Found Palos Verdes Estates in weather IPA, and Adding Latitude and Longitude
# Found Sausalito in weather IPA, and Adding Latitude and Longitude
# Found Delhi in weather IPA, and Adding Latitude and Longitude
# Found Calimesa in weather IPA, and Adding Latitude and Longitude
# Found Canyon Lake in weather IPA, and Adding Latitude and Longitude
# Found Mecca in weather IPA, and Adding Latitude and Longitude
# Found Grand Terrace in weather IPA, and Adding Latitude and Longitude
# Found Gridley in weather IPA, and Adding Latitude and Longitude
# Found View Park-Windsor Hills in weather IPA, and Adding Latitude and Longitude
# Found Coarsegold in weather IPA, and Adding Latitude and Longitude
# Found El Sobrante in weather IPA, and Adding Latitude and Longitude
# Found Piedmont in weather IPA, and Adding Latitude and Longitude
# Found Solana Beach in weather IPA, and Adding Latitude and Longitude
# Found Big Bear City in weather IPA, and Adding Latitude and Longitude
# Found Kelseyville in weather IPA, and Adding Latitude and Longitude
# Found Magalia in weather IPA, and Adding Latitude and Longitude
# Found Orosi in weather IPA, and Adding Latitude and Longitude
# Found Signal Hill in weather IPA, and Adding Latitude and Longitude
# Found Live Oak in weather IPA, and Adding Latitude and Longitude
# Found Garden Acres in weather IPA, and Adding Latitude and Longitude
# Found Hillsborough in weather IPA, and Adding Latitude and Longitude
# Found Sierra Madre in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Newport Coast
# Found California City in weather IPA, and Adding Latitude and Longitude
# Found Dos Palos in weather IPA, and Adding Latitude and Longitude
# Found Lakeport in weather IPA, and Adding Latitude and Longitude
# Found Cotati in weather IPA, and Adding Latitude and Longitude
# Found Woodside in weather IPA, and Adding Latitude and Longitude
# Found Lake Arrowhead in weather IPA, and Adding Latitude and Longitude
# Found Tiburon in weather IPA, and Adding Latitude and Longitude
# Found East La Mirada in weather IPA, and Adding Latitude and Longitude
# Found North Fair Oaks in weather IPA, and Adding Latitude and Longitude
# Found Morro Bay in weather IPA, and Adding Latitude and Longitude
# Found Jamul in weather IPA, and Adding Latitude and Longitude
# Found Emeryville in weather IPA, and Adding Latitude and Longitude
# Found Soquel in weather IPA, and Adding Latitude and Longitude
# Found Shasta Lake in weather IPA, and Adding Latitude and Longitude
# Found Rancho Santa Fe in weather IPA, and Adding Latitude and Longitude
# Found Cloverdale in weather IPA, and Adding Latitude and Longitude
# Found Mariposa in weather IPA, and Adding Latitude and Longitude
# Found Corte Madera in weather IPA, and Adding Latitude and Longitude
# Found Rodeo in weather IPA, and Adding Latitude and Longitude
# Found Muscoy in weather IPA, and Adding Latitude and Longitude
# Found Rolling Hills Estates in weather IPA, and Adding Latitude and Longitude
# Found Colfax in weather IPA, and Adding Latitude and Longitude
# Found Marina del Rey in weather IPA, and Adding Latitude and Longitude
# Found Woodlake in weather IPA, and Adding Latitude and Longitude
# Found Pollock Pines in weather IPA, and Adding Latitude and Longitude
# Found Earlimart in weather IPA, and Adding Latitude and Longitude
# Found La Riviera in weather IPA, and Adding Latitude and Longitude
# Found Penn Valley in weather IPA, and Adding Latitude and Longitude
# Found Boulder Creek in weather IPA, and Adding Latitude and Longitude
# Found Joshua Tree in weather IPA, and Adding Latitude and Longitude
# Found Orange Cove in weather IPA, and Adding Latitude and Longitude
# Found Salida in weather IPA, and Adding Latitude and Longitude
# Found Discovery Bay in weather IPA, and Adding Latitude and Longitude
# Found Waterford in weather IPA, and Adding Latitude and Longitude
# Found Capitola in weather IPA, and Adding Latitude and Longitude
# Found Gonzales in weather IPA, and Adding Latitude and Longitude
# Found Winters in weather IPA, and Adding Latitude and Longitude
# Found Ladera Heights in weather IPA, and Adding Latitude and Longitude
# Found East Foothills in weather IPA, and Adding Latitude and Longitude
# Found Saint Helena in weather IPA, and Adding Latitude and Longitude
# Found Yreka in weather IPA, and Adding Latitude and Longitude
# Found Templeton in weather IPA, and Adding Latitude and Longitude
# Found Indian Wells in weather IPA, and Adding Latitude and Longitude
# Found Gustine in weather IPA, and Adding Latitude and Longitude
# Found Fairfax in weather IPA, and Adding Latitude and Longitude
# Found Castroville in weather IPA, and Adding Latitude and Longitude
# Found Jamestown in weather IPA, and Adding Latitude and Longitude
# Found Willows in weather IPA, and Adding Latitude and Longitude
# Found Mentone in weather IPA, and Adding Latitude and Longitude
# Found Riverdale in weather IPA, and Adding Latitude and Longitude
# Found Mendota in weather IPA, and Adding Latitude and Longitude
# Found Oceano in weather IPA, and Adding Latitude and Longitude
# Found Los Altos Hills in weather IPA, and Adding Latitude and Longitude
# Found West Athens in weather IPA, and Adding Latitude and Longitude
# Found Mammoth Lakes in weather IPA, and Adding Latitude and Longitude
# Found Colusa in weather IPA, and Adding Latitude and Longitude
# Found Thousand Palms in weather IPA, and Adding Latitude and Longitude
# Found Crestline in weather IPA, and Adding Latitude and Longitude
# Found Acton in weather IPA, and Adding Latitude and Longitude
# Found Calistoga in weather IPA, and Adding Latitude and Longitude
# Found Solvang in weather IPA, and Adding Latitude and Longitude
# Found Felton in weather IPA, and Adding Latitude and Longitude
# Found Alondra Park in weather IPA, and Adding Latitude and Longitude
# Found Lucerne Valley in weather IPA, and Adding Latitude and Longitude
# Found Hilmar in weather IPA, and Adding Latitude and Longitude
# Found August in weather IPA, and Adding Latitude and Longitude
# Found Newcastle in weather IPA, and Adding Latitude and Longitude
# Found Atherton in weather IPA, and Adding Latitude and Longitude
# Found Montecito in weather IPA, and Adding Latitude and Longitude
# Found Denair in weather IPA, and Adding Latitude and Longitude
# Found Calipatria in weather IPA, and Adding Latitude and Longitude
# Found Farmersville in weather IPA, and Adding Latitude and Longitude
# Found Heber in weather IPA, and Adding Latitude and Longitude
# Found Jackson in weather IPA, and Adding Latitude and Longitude
# Found Guadalupe in weather IPA, and Adding Latitude and Longitude
# Found Elverta in weather IPA, and Adding Latitude and Longitude
# Found Acampo in weather IPA, and Adding Latitude and Longitude
# Found Rio Vista in weather IPA, and Adding Latitude and Longitude
# Found Kentfield in weather IPA, and Adding Latitude and Longitude
# Found Freedom in weather IPA, and Adding Latitude and Longitude
# Found La Habra Heights in weather IPA, and Adding Latitude and Longitude
# Found Mojave in weather IPA, and Adding Latitude and Longitude
# Found Fowler in weather IPA, and Adding Latitude and Longitude
# Found San Miguel in weather IPA, and Adding Latitude and Longitude
# Found Silverado in weather IPA, and Adding Latitude and Longitude
# Found Topanga in weather IPA, and Adding Latitude and Longitude
# Found Larkspur in weather IPA, and Adding Latitude and Longitude
# Found Redwood Valley in weather IPA, and Adding Latitude and Longitude
# Found French Camp in weather IPA, and Adding Latitude and Longitude
# Found Oak View in weather IPA, and Adding Latitude and Longitude
# Found Strathmore in weather IPA, and Adding Latitude and Longitude
# Found Cutler in weather IPA, and Adding Latitude and Longitude
# Found Pixley in weather IPA, and Adding Latitude and Longitude
# Found Sloughhouse in weather IPA, and Adding Latitude and Longitude
# Found Ben Lomond in weather IPA, and Adding Latitude and Longitude
# Found Quincy in weather IPA, and Adding Latitude and Longitude
# Found Carmel Valley in weather IPA, and Adding Latitude and Longitude
# Found Huron in weather IPA, and Adding Latitude and Longitude
# Found Lake Isabella in weather IPA, and Adding Latitude and Longitude
# Found Homeland in weather IPA, and Adding Latitude and Longitude
# Found San Martin in weather IPA, and Adding Latitude and Longitude
# Found Williams in weather IPA, and Adding Latitude and Longitude
# Found Villa Park in weather IPA, and Adding Latitude and Longitude
# Found Caruthers in weather IPA, and Adding Latitude and Longitude
# Found Terra Bella in weather IPA, and Adding Latitude and Longitude
# Found Montague in weather IPA, and Adding Latitude and Longitude
# Found Oakhurst in weather IPA, and Adding Latitude and Longitude
# Found Pismo Beach in weather IPA, and Adding Latitude and Longitude
# Found Kensington in weather IPA, and Adding Latitude and Longitude
# Found Foresthill in weather IPA, and Adding Latitude and Longitude
# Found Buellton in weather IPA, and Adding Latitude and Longitude
# Found Santa Ynez in weather IPA, and Adding Latitude and Longitude
# Found Forestville in weather IPA, and Adding Latitude and Longitude
# Found Linden in weather IPA, and Adding Latitude and Longitude
# Found East Pasadena in weather IPA, and Adding Latitude and Longitude
# Found Helendale in weather IPA, and Adding Latitude and Longitude
# Found Cambria in weather IPA, and Adding Latitude and Longitude
# Found Murphys in weather IPA, and Adding Latitude and Longitude
# Found Moss Landing in weather IPA, and Adding Latitude and Longitude
# Found South Yuba City in weather IPA, and Adding Latitude and Longitude
# Found Pioneer in weather IPA, and Adding Latitude and Longitude
# Found Arbuckle in weather IPA, and Adding Latitude and Longitude
# Found Pine Grove in weather IPA, and Adding Latitude and Longitude
# Found Weed in weather IPA, and Adding Latitude and Longitude
# Found Big Bear Lake in weather IPA, and Adding Latitude and Longitude
# Found Mount Shasta in weather IPA, and Adding Latitude and Longitude
# Found Pinon Hills in weather IPA, and Adding Latitude and Longitude
# Found Wilton in weather IPA, and Adding Latitude and Longitude
# Found San Joaquin in weather IPA, and Adding Latitude and Longitude
# Found Diamond Springs in weather IPA, and Adding Latitude and Longitude
# Found Camino in weather IPA, and Adding Latitude and Longitude
# Found San Juan Bautista in weather IPA, and Adding Latitude and Longitude
# Found Hidden Valley Lake in weather IPA, and Adding Latitude and Longitude
# Found Kennedy in weather IPA, and Adding Latitude and Longitude
# Found Rescue in weather IPA, and Adding Latitude and Longitude
# Found Cool in weather IPA, and Adding Latitude and Longitude
# Found Keyes in weather IPA, and Adding Latitude and Longitude
# Found Frazier Park in weather IPA, and Adding Latitude and Longitude
# Found San Andreas in weather IPA, and Adding Latitude and Longitude
# Found Bonsall in weather IPA, and Adding Latitude and Longitude
# Found Penngrove in weather IPA, and Adding Latitude and Longitude
# Found Morongo Valley in weather IPA, and Adding Latitude and Longitude
# Found Del Monte Forest in weather IPA, and Adding Latitude and Longitude
# Found Guerneville in weather IPA, and Adding Latitude and Longitude
# Found Wheatland in weather IPA, and Adding Latitude and Longitude
# Found Morada in weather IPA, and Adding Latitude and Longitude
# Found Brisbane in weather IPA, and Adding Latitude and Longitude
# Found Clearlake Oaks in weather IPA, and Adding Latitude and Longitude
# Found Needles in weather IPA, and Adding Latitude and Longitude
# Found Aromas in weather IPA, and Adding Latitude and Longitude
# Found Meadow Vista in weather IPA, and Adding Latitude and Longitude
# Found Lower Lake in weather IPA, and Adding Latitude and Longitude
# Found Middletown in weather IPA, and Adding Latitude and Longitude
# Found Twain Harte in weather IPA, and Adding Latitude and Longitude
# Found Glen Ellen in weather IPA, and Adding Latitude and Longitude
# Found Lincoln Village in weather IPA, and Adding Latitude and Longitude
# Found Mather in weather IPA, and Adding Latitude and Longitude
# Found Esparto in weather IPA, and Adding Latitude and Longitude
# Found Portola Valley in weather IPA, and Adding Latitude and Longitude
# Found Angwin in weather IPA, and Adding Latitude and Longitude
# Found Alturas in weather IPA, and Adding Latitude and Longitude
# Found Highlands-Baywood Park in weather IPA, and Adding Latitude and Longitude
# Found Garden Valley in weather IPA, and Adding Latitude and Longitude
# Found Le Grand in weather IPA, and Adding Latitude and Longitude
# Found Descanso in weather IPA, and Adding Latitude and Longitude
# Found Palo Cedro in weather IPA, and Adding Latitude and Longitude
# Found Tipton in weather IPA, and Adding Latitude and Longitude
# Found Wrightwood in weather IPA, and Adding Latitude and Longitude
# Found Garberville in weather IPA, and Adding Latitude and Longitude
# Found Campo in weather IPA, and Adding Latitude and Longitude
# Found Shandon in weather IPA, and Adding Latitude and Longitude
# Found Shingletown in weather IPA, and Adding Latitude and Longitude
# Found Laton in weather IPA, and Adding Latitude and Longitude
# Found Del Mar in weather IPA, and Adding Latitude and Longitude
# Found Durham in weather IPA, and Adding Latitude and Longitude
# Found Burney in weather IPA, and Adding Latitude and Longitude
# Found El Dorado in weather IPA, and Adding Latitude and Longitude
# Found Lake Hughes in weather IPA, and Adding Latitude and Longitude
# Found Del Rey in weather IPA, and Adding Latitude and Longitude
# Found Cambrian Park in weather IPA, and Adding Latitude and Longitude
# Found Emerald Lake Hills in weather IPA, and Adding Latitude and Longitude
# Found Running Springs in weather IPA, and Adding Latitude and Longitude
# Found Landers in weather IPA, and Adding Latitude and Longitude
# Found Avalon in weather IPA, and Adding Latitude and Longitude
# Found Janesville in weather IPA, and Adding Latitude and Longitude
# Found Plymouth in weather IPA, and Adding Latitude and Longitude
# Found Tuolumne in weather IPA, and Adding Latitude and Longitude
# Found Gerber in weather IPA, and Adding Latitude and Longitude
# Found Portola in weather IPA, and Adding Latitude and Longitude
# Found Agua Dulce in weather IPA, and Adding Latitude and Longitude
# Found Groveland in weather IPA, and Adding Latitude and Longitude
# Found Ivanhoe in weather IPA, and Adding Latitude and Longitude
# Found Boron in weather IPA, and Adding Latitude and Longitude
# Found Ferndale in weather IPA, and Adding Latitude and Longitude
# Found Aguanga in weather IPA, and Adding Latitude and Longitude
# Found Cressey in weather IPA, and Adding Latitude and Longitude
# Found North Fork in weather IPA, and Adding Latitude and Longitude
# Found Buttonwillow in weather IPA, and Adding Latitude and Longitude
# Found Farmington in weather IPA, and Adding Latitude and Longitude
# Found Weaverville in weather IPA, and Adding Latitude and Longitude
# Found Monte Sereno in weather IPA, and Adding Latitude and Longitude
# Found Lockeford in weather IPA, and Adding Latitude and Longitude
# Found Lucerne in weather IPA, and Adding Latitude and Longitude
# Found Llano in weather IPA, and Adding Latitude and Longitude
# Found Sunnyslope in weather IPA, and Adding Latitude and Longitude
# Found Rio Dell in weather IPA, and Adding Latitude and Longitude
# Found Planada in weather IPA, and Adding Latitude and Longitude
# Found Moss Beach in weather IPA, and Adding Latitude and Longitude
# Found Auberry in weather IPA, and Adding Latitude and Longitude
# Found Herald in weather IPA, and Adding Latitude and Longitude
# Found Somis in weather IPA, and Adding Latitude and Longitude
# Found Ahwahnee in weather IPA, and Adding Latitude and Longitude
# Found White Water in weather IPA, and Adding Latitude and Longitude
# Found Yountville in weather IPA, and Adding Latitude and Longitude
# Found Kings Beach in weather IPA, and Adding Latitude and Longitude
# Found Somerset in weather IPA, and Adding Latitude and Longitude
# Found Walnut Grove in weather IPA, and Adding Latitude and Longitude
# Found Flournoy in weather IPA, and Adding Latitude and Longitude
# Found Georgetown in weather IPA, and Adding Latitude and Longitude
# Found Squaw Valley in weather IPA, and Adding Latitude and Longitude
# Found Dulzura in weather IPA, and Adding Latitude and Longitude
# Found Springville in weather IPA, and Adding Latitude and Longitude
# Found Anza in weather IPA, and Adding Latitude and Longitude
# Found Lost Hills in weather IPA, and Adding Latitude and Longitude
# Found Niland in weather IPA, and Adding Latitude and Longitude
# Found Fort Jones in weather IPA, and Adding Latitude and Longitude
# Found Geyserville in weather IPA, and Adding Latitude and Longitude
# Found Cayucos in weather IPA, and Adding Latitude and Longitude
# Found Maricopa in weather IPA, and Adding Latitude and Longitude
# Found Mission Canyon in weather IPA, and Adding Latitude and Longitude
# Found Ross in weather IPA, and Adding Latitude and Longitude
# Found Julian in weather IPA, and Adding Latitude and Longitude
# Found Home Gardens in weather IPA, and Adding Latitude and Longitude
# Found Covelo in weather IPA, and Adding Latitude and Longitude
# Found Mountain Center in weather IPA, and Adding Latitude and Longitude
# Found Mokelumne Hill in weather IPA, and Adding Latitude and Longitude
# Found Cabazon in weather IPA, and Adding Latitude and Longitude
# Found Penryn in weather IPA, and Adding Latitude and Longitude
# Found Borrego Springs in weather IPA, and Adding Latitude and Longitude
# Found Biggs in weather IPA, and Adding Latitude and Longitude
# Found Upper Lake in weather IPA, and Adding Latitude and Longitude
# Found Westwood in weather IPA, and Adding Latitude and Longitude
# Found Nice in weather IPA, and Adding Latitude and Longitude
# Found Bethel Island in weather IPA, and Adding Latitude and Longitude
# Found Pearblossom in weather IPA, and Adding Latitude and Longitude
# Found Weldon in weather IPA, and Adding Latitude and Longitude
# Found Colma in weather IPA, and Adding Latitude and Longitude
# Found San Quentin in weather IPA, and Adding Latitude and Longitude
# Found Arnold in weather IPA, and Adding Latitude and Longitude
# ...
# Found Tahoma in weather IPA, and Adding Latitude and Longitude
# Found Avila Beach in weather IPA, and Adding Latitude and Longitude
# Found Tranquillity in weather IPA, and Adding Latitude and Longitude
# Found Bodega Bay in weather IPA, and Adding Latitude and Longitude
# Found Elk in weather IPA, and Adding Latitude and Longitude
# Found Oak Run in weather IPA, and Adding Latitude and Longitude
# Found Whitmore in weather IPA, and Adding Latitude and Longitude
# Found Dobbins in weather IPA, and Adding Latitude and Longitude
# Found Traver in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Bell Canyon
# Found Robbins in weather IPA, and Adding Latitude and Longitude
# Found Baker in weather IPA, and Adding Latitude and Longitude
# Found Bridgeport in weather IPA, and Adding Latitude and Longitude
# Found Scotia in weather IPA, and Adding Latitude and Longitude
# Found Los Olivos in weather IPA, and Adding Latitude and Longitude
# Found Myers Flat in weather IPA, and Adding Latitude and Longitude
# Found Boonville in weather IPA, and Adding Latitude and Longitude
# Found Doyle in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Mi Wuk Village
# Found Midpines in weather IPA, and Adding Latitude and Longitude
# Found Dillon Beach in weather IPA, and Adding Latitude and Longitude
# Found Ranchita in weather IPA, and Adding Latitude and Longitude
# Found Pine Valley in weather IPA, and Adding Latitude and Longitude
# Found Lakeshore in weather IPA, and Adding Latitude and Longitude
# Found Hornbrook in weather IPA, and Adding Latitude and Longitude
# Found Oregon House in weather IPA, and Adding Latitude and Longitude
# Found Glenhaven in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Dorris
# Found Albion in weather IPA, and Adding Latitude and Longitude
# Found Westmorland in weather IPA, and Adding Latitude and Longitude
# Found Cantua Creek in weather IPA, and Adding Latitude and Longitude
# Found Maxwell in weather IPA, and Adding Latitude and Longitude
# Found Onyx in weather IPA, and Adding Latitude and Longitude
# Found Green Valley Lake in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for The Sea Ranch
# Found Shaver Lake in weather IPA, and Adding Latitude and Longitude
# Found Applegate in weather IPA, and Adding Latitude and Longitude
# Found Salyer in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Mc Kittrick
# Found Lotus in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Sunol-Midtown
# Found Catheys Valley in weather IPA, and Adding Latitude and Longitude
# Found Jenner in weather IPA, and Adding Latitude and Longitude
# Found Birds Landing in weather IPA, and Adding Latitude and Longitude
# Found Markleeville in weather IPA, and Adding Latitude and Longitude
# Found Whitethorn in weather IPA, and Adding Latitude and Longitude
# Found Bass Lake in weather IPA, and Adding Latitude and Longitude
# Found McArthur in weather IPA, and Adding Latitude and Longitude
# Found Litchfield in weather IPA, and Adding Latitude and Longitude
# Found Petrolia in weather IPA, and Adding Latitude and Longitude
# Found Lewiston in weather IPA, and Adding Latitude and Longitude
# Found Wendel in weather IPA, and Adding Latitude and Longitude
# Found Potrero in weather IPA, and Adding Latitude and Longitude
# Found Wallace in weather IPA, and Adding Latitude and Longitude
# Found Inverness in weather IPA, and Adding Latitude and Longitude
# Found El Nido in weather IPA, and Adding Latitude and Longitude
# Found Graton in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Hyampom
# Found Old Station in weather IPA, and Adding Latitude and Longitude
# Found French Gulch in weather IPA, and Adding Latitude and Longitude
# Found Carnelian Bay in weather IPA, and Adding Latitude and Longitude
# Found Ione in weather IPA, and Adding Latitude and Longitude
# Found Lebec in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for San Ardo
# Found Junction City in weather IPA, and Adding Latitude and Longitude
# Found Korbel in weather IPA, and Adding Latitude and Longitude
# Found Stirling City in weather IPA, and Adding Latitude and Longitude
# Found Independence in weather IPA, and Adding Latitude and Longitude
# Found Redcrest in weather IPA, and Adding Latitude and Longitude
# Found Port Costa in weather IPA, and Adding Latitude and Longitude
# Found Bangor in weather IPA, and Adding Latitude and Longitude
# Found Hat Creek in weather IPA, and Adding Latitude and Longitude
# Found Montgomery Creek in weather IPA, and Adding Latitude and Longitude
# Found Alta in weather IPA, and Adding Latitude and Longitude
# Found Ducor in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for O Neals
# Found Sugarloaf in weather IPA, and Adding Latitude and Longitude
# Found Strawberry in weather IPA, and Adding Latitude and Longitude
# Found Bella Vista in weather IPA, and Adding Latitude and Longitude
# Found San Simeon in weather IPA, and Adding Latitude and Longitude
# Found Vernon in weather IPA, and Adding Latitude and Longitude
# Found Vallecito in weather IPA, and Adding Latitude and Longitude
# Found San Geronimo in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Caspar
# Found Gold Run in weather IPA, and Adding Latitude and Longitude
# Found Montara in weather IPA, and Adding Latitude and Longitude
# Found Annapolis in weather IPA, and Adding Latitude and Longitude
# Found Pope Valley in weather IPA, and Adding Latitude and Longitude
# Found Armona in weather IPA, and Adding Latitude and Longitude
# Found Kettleman City in weather IPA, and Adding Latitude and Longitude
# Found Fiddletown in weather IPA, and Adding Latitude and Longitude
# Found Marshall in weather IPA, and Adding Latitude and Longitude
# Found Paskenta in weather IPA, and Adding Latitude and Longitude
# Found Miramonte in weather IPA, and Adding Latitude and Longitude
# Found Stinson Beach in weather IPA, and Adding Latitude and Longitude
# Found Sutter Creek in weather IPA, and Adding Latitude and Longitude
# Found Forest Falls in weather IPA, and Adding Latitude and Longitude
# Found Butte City in weather IPA, and Adding Latitude and Longitude
# Found Cedarville in weather IPA, and Adding Latitude and Longitude
# Found Madeline in weather IPA, and Adding Latitude and Longitude
# Found Termo in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Comptche
# Failed at finding Latitude and Longitude for Orick
# Found Burnt Ranch in weather IPA, and Adding Latitude and Longitude
# Found Badger in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Blocksburg
# Found Tomales in weather IPA, and Adding Latitude and Longitude
# Found Grenada in weather IPA, and Adding Latitude and Longitude
# Found Camptonville in weather IPA, and Adding Latitude and Longitude
# Found Bridgeville in weather IPA, and Adding Latitude and Longitude
# Found Pinecrest in weather IPA, and Adding Latitude and Longitude
# Found Bodega in weather IPA, and Adding Latitude and Longitude
# Found Campo Seco in weather IPA, and Adding Latitude and Longitude
# Found Harmony in weather IPA, and Adding Latitude and Longitude
# Found Homewood in weather IPA, and Adding Latitude and Longitude
# Found Taylorsville in weather IPA, and Adding Latitude and Longitude
# Found Green Valley in weather IPA, and Adding Latitude and Longitude
# Found Elk Creek in weather IPA, and Adding Latitude and Longitude
# Found Leggett in weather IPA, and Adding Latitude and Longitude
# Found Piru in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Nubieber
# Found San Gregorio in weather IPA, and Adding Latitude and Longitude
# Found Chilcoot in weather IPA, and Adding Latitude and Longitude
# Found Big Bar in weather IPA, and Adding Latitude and Longitude
# Found Round Mountain in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Lee Vining
# Found Brooks in weather IPA, and Adding Latitude and Longitude
# Found Manchester in weather IPA, and Adding Latitude and Longitude
# Found Fish Camp in weather IPA, and Adding Latitude and Longitude
# Found Westport in weather IPA, and Adding Latitude and Longitude
# Found Vina in weather IPA, and Adding Latitude and Longitude
# Found Essex in weather IPA, and Adding Latitude and Longitude
# Found Canby in weather IPA, and Adding Latitude and Longitude
# Found Los Alamos in weather IPA, and Adding Latitude and Longitude
# Found Adin in weather IPA, and Adding Latitude and Longitude
# Found Callahan in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Fort Bidwell
# Found Orleans in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Jacumba
# Found Paynes Creek in weather IPA, and Adding Latitude and Longitude
# Found Seiad Valley in weather IPA, and Adding Latitude and Longitude
# Found Davis Creek in weather IPA, and Adding Latitude and Longitude
# Found Big Creek in weather IPA, and Adding Latitude and Longitude
# Found Westley in weather IPA, and Adding Latitude and Longitude
# Found Valley Ford in weather IPA, and Adding Latitude and Longitude
# Found Willow Creek in weather IPA, and Adding Latitude and Longitude
# Found Graeagle in weather IPA, and Adding Latitude and Longitude
# Found Mill Creek in weather IPA, and Adding Latitude and Longitude
# Found Big Bend in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for June Lake
# Found Manton in weather IPA, and Adding Latitude and Longitude
# Found Likely in weather IPA, and Adding Latitude and Longitude
# Found Downieville in weather IPA, and Adding Latitude and Longitude
# Found Zenia in weather IPA, and Adding Latitude and Longitude
# Found Branscomb in weather IPA, and Adding Latitude and Longitude
# Found Wilseyville in weather IPA, and Adding Latitude and Longitude
# Found Glencoe in weather IPA, and Adding Latitude and Longitude
# Found El Portal in weather IPA, and Adding Latitude and Longitude
# Found Casmalia in weather IPA, and Adding Latitude and Longitude
# Found Yermo in weather IPA, and Adding Latitude and Longitude
# Found Castella in weather IPA, and Adding Latitude and Longitude
# Found Avery in weather IPA, and Adding Latitude and Longitude
# Found Sierra City in weather IPA, and Adding Latitude and Longitude
# Found Keene in weather IPA, and Adding Latitude and Longitude
# Found Grimes in weather IPA, and Adding Latitude and Longitude
# Found Daggett in weather IPA, and Adding Latitude and Longitude
# Found Bieber in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for New Pine Creek
# Found Clio in weather IPA, and Adding Latitude and Longitude
# Found Raisin City in weather IPA, and Adding Latitude and Longitude
# Found Lookout in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Nipton
# Found Forbestown in weather IPA, and Adding Latitude and Longitude
# Found Clipper Mills in weather IPA, and Adding Latitude and Longitude
# Found Dutch Flat in weather IPA, and Adding Latitude and Longitude
# Found Lemon Cove in weather IPA, and Adding Latitude and Longitude
# Found Topaz in weather IPA, and Adding Latitude and Longitude
# Found Mad River in weather IPA, and Adding Latitude and Longitude
# Found Alderpoint in weather IPA, and Adding Latitude and Longitude
# Found Standish in weather IPA, and Adding Latitude and Longitude
# Found Hornitos in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Olancha
# Found Woody in weather IPA, and Adding Latitude and Longitude
# Found Calpine in weather IPA, and Adding Latitude and Longitude
# Found Eagleville in weather IPA, and Adding Latitude and Longitude
# Found Milford in weather IPA, and Adding Latitude and Longitude
# Found Hume in weather IPA, and Adding Latitude and Longitude
# Found Rackerby in weather IPA, and Adding Latitude and Longitude
# Found Princeton in weather IPA, and Adding Latitude and Longitude
# Found Lake City in weather IPA, and Adding Latitude and Longitude
# Found Benton in weather IPA, and Adding Latitude and Longitude
# Found Strawberry Valley in weather IPA, and Adding Latitude and Longitude
# Found Emigrant Gap in weather IPA, and Adding Latitude and Longitude
# Found Palomar Mountain in weather IPA, and Adding Latitude and Longitude
# Found Ravendale in weather IPA, and Adding Latitude and Longitude
# Found Clements in weather IPA, and Adding Latitude and Longitude
# Found Valyermo in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Canyon Dam
# Failed at finding Latitude and Longitude for Somes Bar
# Found Beckwourth in weather IPA, and Adding Latitude and Longitude
# Found Duncans Mills in weather IPA, and Adding Latitude and Longitude
# Found Thornton in weather IPA, and Adding Latitude and Longitude
# Found Deer Park in weather IPA, and Adding Latitude and Longitude
# Found Glennville in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Sierraville
# Found Twain in weather IPA, and Adding Latitude and Longitude
# Found Loma Mar in weather IPA, and Adding Latitude and Longitude
# Found Elmira in weather IPA, and Adding Latitude and Longitude
# Found Crescent Mills in weather IPA, and Adding Latitude and Longitude
# Found Zamora in weather IPA, and Adding Latitude and Longitude
# Found Long Barn in weather IPA, and Adding Latitude and Longitude
# Found Fawnskin in weather IPA, and Adding Latitude and Longitude
# Found Soda Springs in weather IPA, and Adding Latitude and Longitude
# Found Kyburz in weather IPA, and Adding Latitude and Longitude
# Found Twin Bridges in weather IPA, and Adding Latitude and Longitude
# Found Echo Lake in weather IPA, and Adding Latitude and Longitude
# Found Tehama in weather IPA, and Adding Latitude and Longitude
# Found Nelson in weather IPA, and Adding Latitude and Longitude
# Found Big Oak Flat in weather IPA, and Adding Latitude and Longitude
# Found Miranda in weather IPA, and Adding Latitude and Longitude
# Found Madison in weather IPA, and Adding Latitude and Longitude
# Found Camp Meeker in weather IPA, and Adding Latitude and Longitude
# Found Bear Valley in weather IPA, and Adding Latitude and Longitude
# Found Guinda in weather IPA, and Adding Latitude and Longitude
# Found Meadow Valley in weather IPA, and Adding Latitude and Longitude
# Found Keeler in weather IPA, and Adding Latitude and Longitude
# Found Washington in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Little Grass Valley
# Found Shasta in weather IPA, and Adding Latitude and Longitude
# Found Biola in weather IPA, and Adding Latitude and Longitude
# Found Cassel in weather IPA, and Adding Latitude and Longitude
# Found Amador City in weather IPA, and Adding Latitude and Longitude
# Found Kirkwood in weather IPA, and Adding Latitude and Longitude
# Found San Lucas in weather IPA, and Adding Latitude and Longitude
# Found Empire in weather IPA, and Adding Latitude and Longitude
# Found Goodyears Bar in weather IPA, and Adding Latitude and Longitude
# Found River Pines in weather IPA, and Adding Latitude and Longitude
# Found McCloud in weather IPA, and Adding Latitude and Longitude
# Found Mount Baldy in weather IPA, and Adding Latitude and Longitude
# Found Mettler in weather IPA, and Adding Latitude and Longitude
# Found North Palm Springs in weather IPA, and Adding Latitude and Longitude
# Found Fields Landing in weather IPA, and Adding Latitude and Longitude
# Found Lockwood in weather IPA, and Adding Latitude and Longitude
# Failed at finding Latitude and Longitude for Tecopa
# Found Challenge in weather IPA, and Adding Latitude and Longitude
# Found Honeydew in weather IPA, and Adding Latitude and Longitude
# Found Darwin in weather IPA, and Adding Latitude and Longitude

# %%
#print count of cities that failed and the names
print(len(failedcity))
print((failedcity))
# Out:
# 39
# ['Mc Farland', 'Newport Coast', 'Fall River Mills', 'Herlong', 'Desert Center', 'Warner Springs', 'Lakehead', 'Big Sur', 'Macdoel', 'Trinity Center', 'Point Arena', 'Klamath River', 'Palos Verdes Peninsula', 'Bell Canyon', 'Mi Wuk Village', 'Dorris', 'The Sea Ranch', 'Mc Kittrick', 'Sunol-Midtown', 'Hyampom', 'San Ardo', 'O Neals', 'Caspar', 'Comptche', 'Orick', 'Blocksburg', 'Nubieber', 'Lee Vining', 'Fort Bidwell', 'Jacumba', 'June Lake', 'New Pine Creek', 'Nipton', 'Olancha', 'Canyon Dam', 'Somes Bar', 'Sierraville', 'Little Grass Valley', 'Tecopa']

# %%
#Show the new DF
SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  1996-01-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    193916.0
# 8                       San Diego-Carlsbad      San Diego County    216701.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    218822.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    305212.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    109287.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County         NaN
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        1996-02-29  ...  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 1        193960.0  ...    766002.0    770182.0    774078.0    780205.0
# 8        216342.0  ...    730853.0    734733.0    740112.0    744208.0
# 11       218222.0  ...   1027883.0   1034380.0   1046264.0   1057397.0
# 14       304198.0  ...   1519514.0   1531203.0   1535710.0   1539101.0
# 30       108768.0  ...    356618.0    358601.0    360857.0    362724.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    613047.0    613266.0    611159.0    610241.0
# 26406         NaN  ...     34687.0     34614.0     34465.0     34328.0
# 26435         NaN  ...    215080.0    215313.0    215703.0    214733.0
# 26466         NaN  ...    688958.0    698685.0    707643.0    720505.0
# 26472         NaN  ...     48758.0     48704.0     48665.0     48617.0
#
#        2020-03-31  2020-04-30  2020-05-31  2020-06-30  Latitude  Longitude
# 1        785793.0    789989.0    790037.0    788920.0     34.05    -118.24
# 8        748744.0    751096.0    753893.0    754223.0     32.72    -117.16
# 11      1068942.0   1074703.0   1080058.0   1088749.0     37.34    -121.89
# 14      1535882.0   1533941.0   1523778.0   1511653.0     37.77    -122.42
# 30       365194.0    366583.0    366772.0    366198.0     38.47    -121.32
# ...           ...         ...         ...         ...       ...        ...
# 26401    611718.0    615934.0    623633.0    631555.0     45.82    -108.41
# 26406     34042.0     33631.0     33159.0     32578.0       NaN        NaN
# 26435    212881.0    211004.0    208809.0    205041.0     39.49    -121.22
# 26466    733777.0    749997.0    767960.0    792172.0     40.24    -124.12
# 26472     48550.0     48529.0     48557.0     48661.0    -12.46     130.84
#
# [1108 rows x 304 columns]

# %%
#Converting column values to numbers
SingleCCal['Latitude']  = pd.to_numeric(SingleCCal['Latitude'],errors = 'coerce')
SingleCCal['Longitude']  = pd.to_numeric(SingleCCal['Longitude'],errors = 'coerce')
#Creating a DF for just Northern California
SingleNCity  = SingleCCal.loc[SingleCCal['Latitude'].gt(37)==True]
SingleNCity
# Out:
#        RegionID  SizeRank      RegionName RegionType StateName State  \
# 11        33839        11        San Jose       City        CA    CA
# 14        20330        14   San Francisco       City        CA    CA
# 30        20288        30      Sacramento       City        CA    CA
# 45        13072        45         Oakland       City        CA    CA
# 79         7266        80        Stockton       City        CA    CA
# ...         ...       ...             ...        ...       ...   ...
# 26246    116564     29449         Mettler       City        CA    CA
# 26305     11431     29449  Fields Landing       City        CA    CA
# 26401     29195     29449        Lockwood       City        CA    CA
# 26435     17380     29449       Challenge       City        CA    CA
# 26466     21913     29449        Honeydew       City        CA    CA
#
#                                      Metro            CountyName  1996-01-31  \
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    218822.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    305212.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    109287.0
# 45           San Francisco-Oakland-Hayward        Alameda County    169332.0
# 79                           Stockton-Lodi    San Joaquin County     91785.0
# ...                                    ...                   ...         ...
# 26246                          Bakersfield           Kern County         NaN
# 26305                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26401                              Salinas       Monterey County         NaN
# 26435                            Yuba City           Yuba County         NaN
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
#
#        1996-02-29  ...  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 11       218222.0  ...   1027883.0   1034380.0   1046264.0   1057397.0
# 14       304198.0  ...   1519514.0   1531203.0   1535710.0   1539101.0
# 30       108768.0  ...    356618.0    358601.0    360857.0    362724.0
# 45       168605.0  ...    831207.0    836265.0    842970.0    847396.0
# 79        91382.0  ...    314393.0    316322.0    317459.0    319191.0
# ...           ...  ...         ...         ...         ...         ...
# 26246         NaN  ...    197364.0    198346.0    199893.0    201593.0
# 26305         NaN  ...    280930.0    280717.0    278815.0    277085.0
# 26401         NaN  ...    613047.0    613266.0    611159.0    610241.0
# 26435         NaN  ...    215080.0    215313.0    215703.0    214733.0
# 26466         NaN  ...    688958.0    698685.0    707643.0    720505.0
#
#        2020-03-31  2020-04-30  2020-05-31  2020-06-30  Latitude  Longitude
# 11      1068942.0   1074703.0   1080058.0   1088749.0     37.34    -121.89
# 14      1535882.0   1533941.0   1523778.0   1511653.0     37.77    -122.42
# 30       365194.0    366583.0    366772.0    366198.0     38.47    -121.32
# 45       849890.0    848782.0    845181.0    841257.0     42.67     -83.40
# 79       319988.0    321367.0    321519.0    320896.0     37.96    -121.29
# ...           ...         ...         ...         ...       ...        ...
# 26246    202968.0    203302.0    202489.0    201791.0     40.50     -74.54
# 26305    275763.0    276381.0    277400.0    277990.0     40.73    -124.22
# 26401    611718.0    615934.0    623633.0    631555.0     45.82    -108.41
# 26435    212881.0    211004.0    208809.0    205041.0     39.49    -121.22
# 26466    733777.0    749997.0    767960.0    792172.0     40.24    -124.12
#
# [533 rows x 304 columns]

# %%
#Declairing a function and setting 4 variable  Max and min on  Longitude and latitude 
def singlecity(latMin, latMax, lngMin, lngMax):  
    #Create a copy of the DF of fire and single city
    SingleFire = Nfire.copy()
    #create a box of latitude and longitude using the DFs
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMin))==True]
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMax))==False]

    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMin))==False]
    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMax))==True]
    
    
    SingleCity = SingleNCity.copy()
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMin))==True]
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMax))==False]

    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMin))==False]
    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMax))==True]
    #return the DF into a list
    return [SingleCity, SingleFire]

# %%
#Create a list to hold the DF
SingleCity_Fire = []
#choose the Lat and Long
SingleCity_Fire =singlecity(37,38,-118,-120)
#Choose DF to show
SingleCity_Fire[0]
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State   Metro  \
# 372       32629       378         Madera       City        CA    CA  Madera
# 4045      23717      4214         Bishop       City        CA    CA     NaN
# 4547      44661      4747     Coarsegold       City        CA    CA  Madera
# 5074      19207      5312       Mariposa       City        CA    CA     NaN
# 5911      35858      6215  Mammoth Lakes       City        CA    CA     NaN
# 11233     28224     12071        Auberry       City        CA    CA  Fresno
# 11286      3333     12131       Ahwahnee       City        CA    CA  Madera
# 13070     36429     14181      Tollhouse       City        CA    CA  Fresno
# 14193     44163     15490       Big Pine       City        CA    CA     NaN
# 16354     36187     18050        Prather       City        CA    CA  Fresno
# 19944     56407     22410       Midpines       City        CA    CA     NaN
# 20516      7035     23132    Shaver Lake       City        CA    CA  Fresno
# 23565     38527     26923      Fish Camp       City        CA    CA     NaN
#
#             CountyName  1996-01-31  1996-02-29  ...  2019-11-30  2019-12-31  \
# 372      Madera County         NaN         NaN  ...    256551.0    258363.0
# 4045       Inyo County         NaN         NaN  ...    428489.0    427864.0
# 4547     Madera County         NaN         NaN  ...    303735.0    305076.0
# 5074   Mariposa County         NaN         NaN  ...    307772.0    307829.0
# 5911       Mono County         NaN         NaN  ...    785180.0    785724.0
# 11233    Fresno County    115103.0    114534.0  ...    323350.0    323026.0
# 11286    Madera County         NaN         NaN  ...    344062.0    344916.0
# 13070    Fresno County    120189.0    119391.0  ...    327124.0    328417.0
# 14193      Inyo County         NaN         NaN  ...    280065.0    280155.0
# 16354    Fresno County    160637.0    159943.0  ...    405748.0    406006.0
# 19944  Mariposa County         NaN         NaN  ...    294156.0    294217.0
# 20516    Fresno County    172524.0    171547.0  ...    480221.0    480259.0
# 23565  Mariposa County         NaN         NaN  ...    399960.0    397848.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# 372      260681.0    262454.0    263888.0    265222.0    266203.0    267297.0
# 4045     427637.0    427227.0    426893.0    426367.0    425207.0    423626.0
# 4547     307052.0    308750.0    310050.0    311201.0    311894.0    312873.0
# 5074     307935.0    307984.0    307635.0    307033.0    306186.0    305309.0
# 5911     786616.0    787233.0    788172.0    787610.0    787095.0    784957.0
# 11233    323512.0    325098.0    326705.0    328963.0    329393.0    328748.0
# 11286    347171.0    349200.0    351369.0    351667.0    350772.0    349172.0
# 13070    328499.0    330061.0    331495.0    334197.0    336202.0    337249.0
# 14193    280990.0    282251.0    283584.0    284200.0    284199.0    284368.0
# 16354    406320.0    407431.0    407477.0    408113.0    407753.0    407014.0
# 19944    294287.0    294442.0    294106.0    293445.0    292417.0    291258.0
# 20516    479377.0    478534.0    478682.0    479503.0    478834.0    476076.0
# 23565    396888.0    396358.0    394937.0    391227.0    385333.0    379686.0
#
#        Latitude  Longitude
# 372       37.17    -119.83
# 4045      37.36    -118.40
# 4547      37.26    -119.70
# 5074      37.48    -119.97
# 5911      37.65    -118.97
# 11233     37.08    -119.49
# 11286     37.37    -119.73
# 13070     37.02    -119.40
# 14193     37.16    -118.29
# 16354     37.04    -119.51
# 19944     37.54    -119.92
# 20516     37.11    -119.32
# 23565     37.48    -119.64
#
# [13 rows x 304 columns]
