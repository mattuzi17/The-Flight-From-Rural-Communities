# %%
#import all libraries needed 
import os
import pandas as pd

from api_keys import wkey
from api_keys import gkey
import gmaps
import gmaps.datasets
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
#Get Path to get to the Datasets
firepath = os.path.join('Data Sets', 'California_Fire_Incidents.csv')
singlepath = os.path.join('Data Sets','City_zhvi_single_family.csv')

#read the files 
fire = pd.read_csv(firepath)
singlecity = pd.read_csv(singlepath)

# %%
#Collecting only the columns we want 
clfire = fire[['Name','AcresBurned','ArchiveYear','Counties','Started','Extinguished', 'Latitude',
       'Longitude','Fatalities','Injuries','StructuresDamaged', 'StructuresDestroyed',
       'StructuresEvacuated', 'StructuresThreatened','Location']]
#sort the 
clfire.sort_values(by ='AcresBurned',ascending = False)
# Out:
#                                 Name  AcresBurned  ArchiveYear     Counties  \
# 1055  Ranch Fire (Mendocino Complex)     410203.0         2018        Glenn
# 1054  Ranch Fire (Mendocino Complex)     410203.0         2018       Colusa
# 1056  Ranch Fire (Mendocino Complex)     410203.0         2018         Lake
# 1057  Ranch Fire (Mendocino Complex)     410203.0         2018    Mendocino
# 617                      Thomas Fire     281893.0         2017      Ventura
# ...                              ...          ...          ...          ...
# 1043                Rattlesnake Fire          0.0         2017     Mariposa
# 613                         Old Fire          0.0         2016  Los Angeles
# 1633                     Cashe Fire           NaN         2019         Yolo
# 1634                        Oak Fire          NaN         2019    San Diego
# 1635                   Johnson Fire           NaN         2019    Riverside
#
#                    Started          Extinguished   Latitude   Longitude  \
# 1055  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1054  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1056  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1057  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 617   2017-12-04T18:28:00Z  2019-03-14T11:24:00Z  34.415210 -119.091240
# ...                    ...                   ...        ...         ...
# 1043  2017-09-07T15:00:00Z  2018-01-09T13:19:00Z  37.735960 -119.782560
# 613   2016-06-04T16:09:00Z  2016-06-13T12:30:00Z   0.000000    0.000000
# 1633  2019-11-25T12:02:02Z                   NaN  38.734634 -121.729691
# 1634  2019-10-22T19:20:44Z                   NaN  33.351145 -117.403719
# 1635  2019-10-14T15:32:20Z                   NaN  33.451480 -116.058980
#
#       Fatalities  Injuries  StructuresDamaged  StructuresDestroyed  \
# 1055         1.0       3.0                NaN                246.0
# 1054         1.0       3.0                NaN                246.0
# 1056         1.0       3.0                NaN                246.0
# 1057         1.0       3.0                NaN                246.0
# 617          NaN       NaN              280.0               1063.0
# ...          ...       ...                ...                  ...
# 1043         NaN       NaN                NaN                  NaN
# 613          NaN       NaN                NaN                  NaN
# 1633         NaN       NaN                NaN                  NaN
# 1634         NaN       NaN                NaN                  NaN
# 1635         NaN       NaN                NaN                  NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 1055                  NaN                1050.0
# 1054                  NaN                1050.0
# 1056                  NaN                1050.0
# 1057                  NaN                1050.0
# 617                   NaN                   NaN
# ...                   ...                   ...
# 1043                  NaN                   NaN
# 613                   NaN                   NaN
# 1633                  NaN                   NaN
# 1634                  NaN                   NaN
# 1635                  NaN                   NaN
#
#                                                Location
# 1055  off Highway 20 near Potter Valley, northeast o...
# 1054  off Highway 20 near Potter Valley, northeast o...
# 1056  off Highway 20 near Potter Valley, northeast o...
# 1057  off Highway 20 near Potter Valley, northeast o...
# 617          Hwy 150 and Hwy 126, north of Santa Paula
# ...                                                 ...
# 1043         Hwy 120 and Big Oak Flat Road near Foresta
# 613   off of Old Topanga Canyon Road and Mulholland ...
# 1633  County Road 102 and County Road 17, North of W...
# 1634  Near Basilone Road and Las Pulgas Road, near C...
# 1635                          Johnson Street and Ave 82
#
# [1636 rows x 15 columns]

# %%
#to get all the names of the columns we want
singlecolumns = []
singlecolumns = singlecity.columns
counter = 0
yearlist = []
for i in singlecolumns:
    counter +=1
    if counter > 211:
        yearlist.append(i)
#print the list to copy it and paste it in the next cells
yearlist
# Out:
# ['2012-12-31',
#  '2013-01-31',
#  '2013-02-28',
#  '2013-03-31',
#  '2013-04-30',
#  '2013-05-31',
#  '2013-06-30',
#  '2013-07-31',
#  '2013-08-31',
#  '2013-09-30',
#  '2013-10-31',
#  '2013-11-30',
#  '2013-12-31',
#  '2014-01-31',
#  '2014-02-28',
#  '2014-03-31',
#  '2014-04-30',
#  '2014-05-31',
#  '2014-06-30',
#  '2014-07-31',
#  '2014-08-31',
#  '2014-09-30',
#  '2014-10-31',
#  '2014-11-30',
#  '2014-12-31',
#  '2015-01-31',
#  '2015-02-28',
#  '2015-03-31',
#  '2015-04-30',
#  '2015-05-31',
#  '2015-06-30',
#  '2015-07-31',
#  '2015-08-31',
#  '2015-09-30',
#  '2015-10-31',
#  '2015-11-30',
#  '2015-12-31',
#  '2016-01-31',
#  '2016-02-29',
#  '2016-03-31',
#  '2016-04-30',
#  '2016-05-31',
#  '2016-06-30',
#  '2016-07-31',
#  '2016-08-31',
#  '2016-09-30',
#  '2016-10-31',
#  '2016-11-30',
#  '2016-12-31',
#  '2017-01-31',
#  '2017-02-28',
#  '2017-03-31',
#  '2017-04-30',
#  '2017-05-31',
#  '2017-06-30',
#  '2017-07-31',
#  '2017-08-31',
#  '2017-09-30',
#  '2017-10-31',
#  '2017-11-30',
#  '2017-12-31',
#  '2018-01-31',
#  '2018-02-28',
#  '2018-03-31',
#  '2018-04-30',
#  '2018-05-31',
#  '2018-06-30',
#  '2018-07-31',
#  '2018-08-31',
#  '2018-09-30',
#  '2018-10-31',
#  '2018-11-30',
#  '2018-12-31',
#  '2019-01-31',
#  '2019-02-28',
#  '2019-03-31',
#  '2019-04-30',
#  '2019-05-31',
#  '2019-06-30',
#  '2019-07-31',
#  '2019-08-31',
#  '2019-09-30',
#  '2019-10-31',
#  '2019-11-30',
#  '2019-12-31',
#  '2020-01-31',
#  '2020-02-29',
#  '2020-03-31',
#  '2020-04-30',
#  '2020-05-31',
#  '2020-06-30']

# %%
#selecting the columns we want
clsinglecity = singlecity[["RegionID","SizeRank","RegionName","RegionType","StateName","State","Metro","CountyName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 

clsinglecity
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 26492     51821     29449  Eastabuchie       City        MS    MS
# 26493    232607     29449         Dean       City        TX    TX
# 26494      6638     29449      Pulaski       City        GA    GA
# 26495     33089     29449    New Paris       City        PA    PA
# 26496     11693     30967  Great Lakes       City        IL    IL
#
#                                   Metro          CountyName  2012-12-31  \
# 0           New York-Newark-Jersey City       Queens County    456770.0
# 1        Los Angeles-Long Beach-Anaheim  Los Angeles County    450942.0
# 2      Houston-The Woodlands-Sugar Land       Harris County    123220.0
# 3              Chicago-Naperville-Elgin         Cook County    157394.0
# 4             San Antonio-New Braunfels        Bexar County    125317.0
# ...                                 ...                 ...         ...
# 26492                            Laurel        Jones County     64854.0
# 26493                     Wichita Falls         Clay County    124149.0
# 26494                               NaN      Candler County     63066.0
# 26495                               NaN      Bedford County         NaN
# 26496          Chicago-Naperville-Elgin         Cook County    249843.0
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 0        457813.0  ...    672936.0    672209.0    671450.0    671253.0
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 2        124046.0  ...    192561.0    193168.0    193616.0    194133.0
# 3        158940.0  ...    228316.0    228191.0    228145.0    228217.0
# 4        126125.0  ...    186918.0    187543.0    188271.0    188410.0
# ...           ...  ...         ...         ...         ...         ...
# 26492     65194.0  ...     81352.0     81091.0     81224.0     81612.0
# 26493    124473.0  ...    181453.0    181941.0    182497.0    182893.0
# 26494     63485.0  ...     97205.0     97299.0     97627.0     97836.0
# 26495         NaN  ...    151755.0    152421.0    153723.0    154705.0
# 26496    248164.0  ...    270495.0    269721.0    269156.0    267781.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 0        671526.0    671719.0    671601.0    672261.0    672389.0    673213.0
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 2        194270.0    194724.0    195586.0    196630.0    197445.0    197941.0
# 3        228561.0    229004.0    229648.0    230000.0    230383.0    230957.0
# 4        188913.0    189028.0    189564.0    189684.0    189929.0    190068.0
# ...           ...         ...         ...         ...         ...         ...
# 26492     82230.0     83016.0     83265.0     83905.0     84212.0     84165.0
# 26493    183317.0    183288.0    183121.0    182587.0    181882.0    181599.0
# 26494     98273.0     98746.0     99501.0    100522.0    101658.0    102356.0
# 26495    155025.0    155328.0    155871.0    156029.0    155906.0    154597.0
# 26496    267119.0    266509.0    264543.0    261258.0    260245.0    260579.0
#
# [26497 rows x 99 columns]

# %%
#Grabing fires in Northern California only
Nfire = clfire.loc[clfire['Latitude'].gt(37)==True]
Nfire.sort_values(by ='AcresBurned',ascending = False)
Nfire = pd.DataFrame(Nfire)
Nfire['Extinguished'] = Nfire['Extinguished'].astype(str)
Nfire = pd.DataFrame(Nfire)


for index, row in Nfire.iterrows():
    start= row[4]
    finish = row[5]
    Nfire.loc[index,'Started'] = start.split("T")[0]
    Nfire.loc[index,'Extinguished'] = finish.split('T')[0]
Nfire
# Out:
#                       Name  AcresBurned  ArchiveYear  Counties     Started  \
# 0                 Rim Fire     257314.0         2013  Tuolumne  2013-08-17
# 3            American Fire      27440.0         2013    Placer  2013-08-10
# 5               Aspen Fire      22992.0         2013    Fresno  2013-07-22
# 7     Salmon River Complex      14754.0         2013  Siskiyou  2013-07-31
# 8           Corral Complex      12503.0         2013  Humboldt  2013-08-10
# ...                    ...          ...          ...       ...         ...
# 1628            Moms Fire          10.0         2019     Butte  2019-07-23
# 1629         IronGate Fire         10.0         2019  Siskiyou  2019-06-16
# 1630             Cana Fire         10.0         2019     Butte  2019-04-30
# 1632             Long Fire          2.0         2019    Nevada  2019-06-28
# 1633           Cashe Fire           NaN         2019      Yolo  2019-11-25
#
#      Extinguished   Latitude   Longitude  Fatalities  Injuries  \
# 0      2013-09-06  37.857000 -120.086000         NaN       NaN
# 3      2013-08-30  39.120000 -120.650000         NaN       NaN
# 5      2013-09-24  37.279000 -119.318000         NaN       NaN
# 7      2013-08-31  41.320000 -123.176000         NaN       NaN
# 8      2013-08-12  41.035000 -123.488000         NaN       NaN
# ...           ...        ...         ...         ...       ...
# 1628          nan  39.423833 -121.579738         NaN       NaN
# 1629   2019-06-21  41.946220 -122.401570         NaN       NaN
# 1630   2019-05-08  39.839580 -121.957000         NaN       NaN
# 1632   2019-06-28  39.409722 -121.000556         NaN       NaN
# 1633          nan  38.734634 -121.729691         NaN       NaN
#
#       StructuresDamaged  StructuresDestroyed  StructuresEvacuated  \
# 0                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 5                   NaN                  NaN                  NaN
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 1628                NaN                  NaN                  NaN
# 1629                NaN                  NaN                  NaN
# 1630                NaN                  NaN                  NaN
# 1632                NaN                  NaN                  NaN
# 1633                NaN                  NaN                  NaN
#
#       StructuresThreatened                                           Location
# 0                      NaN            3 miles east of Groveland along Hwy 120
# 3                      NaN            Deadwood Ridge, northeast of Foresthill
# 5                      NaN                     Seven miles north of Big Creek
# 7                      NaN  North Fork of the Salmon River, West of Sawyer...
# 8                      NaN   Tish Tang Ridge east of Hoopa Valley Reservation
# ...                    ...                                                ...
# 1628                   NaN  Off Moms Lane and Lone Tree Road, South of Orv...
# 1629                   NaN         Deer Run Road, east of Iron Gate Reservoir
# 1630                   NaN  Off Hamilton Nord Cana Hwy & Cana Hwy, northea...
# 1632                   NaN  Off of  Long Point Road and Old Mill Road, Sou...
# 1633                   NaN  County Road 102 and County Road 17, North of W...
#
# [844 rows x 15 columns]

# %%
#looking through the data
grfire = Nfire.groupby(['Name','Counties','Started', "Extinguished"]).mean().sort_values(by ='AcresBurned',ascending = False)
grfire.to_csv('../GroupedFire.csv')
grfire
# Out:
#                                                                   AcresBurned  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04       410203.0
#                                Colusa    2018-07-27 2019-01-04       410203.0
#                                Glenn     2018-07-27 2019-01-04       410203.0
#                                Lake      2018-07-27 2019-01-04       410203.0
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06       257314.0
# ...                                                                       ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04            0.0
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14            0.0
# Grape Fire                     Humboldt  2018-04-24 2019-01-03            0.0
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09            0.0
# Cashe Fire                     Yolo      2019-11-25 nan                   NaN
#
#                                                                   ArchiveYear  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04           2018
#                                Colusa    2018-07-27 2019-01-04           2018
#                                Glenn     2018-07-27 2019-01-04           2018
#                                Lake      2018-07-27 2019-01-04           2018
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06           2013
# ...                                                                       ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04           2018
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14           2014
# Grape Fire                     Humboldt  2018-04-24 2019-01-03           2018
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09           2017
# Cashe Fire                     Yolo      2019-11-25 nan                  2019
#
#                                                                    Latitude  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04    39.243283
#                                Colusa    2018-07-27 2019-01-04    39.243283
#                                Glenn     2018-07-27 2019-01-04    39.243283
#                                Lake      2018-07-27 2019-01-04    39.243283
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06    37.857000
# ...                                                                     ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04    39.712170
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14    41.796000
# Grape Fire                     Humboldt  2018-04-24 2019-01-03    40.702580
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09    37.735960
# Cashe Fire                     Yolo      2019-11-25 nan           38.734634
#
#                                                                    Longitude  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04   -123.103367
#                                Colusa    2018-07-27 2019-01-04   -123.103367
#                                Glenn     2018-07-27 2019-01-04   -123.103367
#                                Lake      2018-07-27 2019-01-04   -123.103367
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06   -120.086000
# ...                                                                      ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04   -121.773850
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14   -123.374000
# Grape Fire                     Humboldt  2018-04-24 2019-01-03   -123.550120
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09   -119.782560
# Cashe Fire                     Yolo      2019-11-25 nan          -121.729691
#
#                                                                   Fatalities  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04           1.0
#                                Colusa    2018-07-27 2019-01-04           1.0
#                                Glenn     2018-07-27 2019-01-04           1.0
#                                Lake      2018-07-27 2019-01-04           1.0
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06           NaN
# ...                                                                      ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04           NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14           NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03           NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09           NaN
# Cashe Fire                     Yolo      2019-11-25 nan                  NaN
#
#                                                                   Injuries  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04         3.0
#                                Colusa    2018-07-27 2019-01-04         3.0
#                                Glenn     2018-07-27 2019-01-04         3.0
#                                Lake      2018-07-27 2019-01-04         3.0
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06         NaN
# ...                                                                    ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04         NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14         NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03         NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09         NaN
# Cashe Fire                     Yolo      2019-11-25 nan                NaN
#
#                                                                   StructuresDamaged  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04                  NaN
#                                Colusa    2018-07-27 2019-01-04                  NaN
#                                Glenn     2018-07-27 2019-01-04                  NaN
#                                Lake      2018-07-27 2019-01-04                  NaN
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06                  NaN
# ...                                                                             ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04                  NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14                  NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03                  NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09                  NaN
# Cashe Fire                     Yolo      2019-11-25 nan                         NaN
#
#                                                                   StructuresDestroyed  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04                  246.0
#                                Colusa    2018-07-27 2019-01-04                  246.0
#                                Glenn     2018-07-27 2019-01-04                  246.0
#                                Lake      2018-07-27 2019-01-04                  246.0
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06                    NaN
# ...                                                                               ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04                    NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14                    NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03                    NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09                    NaN
# Cashe Fire                     Yolo      2019-11-25 nan                           NaN
#
#                                                                   StructuresEvacuated  \
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04                    NaN
#                                Colusa    2018-07-27 2019-01-04                    NaN
#                                Glenn     2018-07-27 2019-01-04                    NaN
#                                Lake      2018-07-27 2019-01-04                    NaN
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06                    NaN
# ...                                                                               ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04                    NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14                    NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03                    NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09                    NaN
# Cashe Fire                     Yolo      2019-11-25 nan                           NaN
#
#                                                                   StructuresThreatened
# Name                           Counties  Started    Extinguished
# Ranch Fire (Mendocino Complex) Mendocino 2018-07-27 2019-01-04                  1050.0
#                                Colusa    2018-07-27 2019-01-04                  1050.0
#                                Glenn     2018-07-27 2019-01-04                  1050.0
#                                Lake      2018-07-27 2019-01-04                  1050.0
# Rim Fire                       Tuolumne  2013-08-17 2013-09-06                     NaN
# ...                                                                                ...
# Honey Flooding                 Butte     2018-11-29 2019-01-04                     NaN
# Happy Camp Complex             Siskiyou  2014-08-11 2014-08-14                     NaN
# Grape Fire                     Humboldt  2018-04-24 2019-01-03                     NaN
# Rattlesnake Fire               Mariposa  2017-09-07 2018-01-09                     NaN
# Cashe Fire                     Yolo      2019-11-25 nan                            NaN
#
# [842 rows x 10 columns]

# %%
#usinging only the cities in California
SingleCCal = clsinglecity.loc[clsinglecity['StateName'] =='CA']
SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  2012-12-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    450942.0
# 8                       San Diego-Carlsbad      San Diego County    474020.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    588222.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    824245.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    174266.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County    129791.0
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 8        480412.0  ...    725853.0    727571.0    730853.0    734733.0
# 11       599714.0  ...   1020573.0   1024151.0   1027883.0   1034380.0
# 14       841667.0  ...   1505519.0   1511407.0   1519514.0   1531203.0
# 30       177728.0  ...    350842.0    353592.0    356618.0    358601.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    610914.0    613382.0    613047.0    613266.0
# 26406         NaN  ...     34627.0     34688.0     34687.0     34614.0
# 26435    130369.0  ...    211217.0    213588.0    215080.0    215313.0
# 26466         NaN  ...    672166.0    680526.0    688958.0    698685.0
# 26472         NaN  ...     48902.0     48826.0     48758.0     48704.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 8        740112.0    744208.0    748744.0    751096.0    753893.0    754223.0
# 11      1046264.0   1057397.0   1068942.0   1074703.0   1080058.0   1088749.0
# 14      1535710.0   1539101.0   1535882.0   1533941.0   1523778.0   1511653.0
# 30       360857.0    362724.0    365194.0    366583.0    366772.0    366198.0
# ...           ...         ...         ...         ...         ...         ...
# 26401    611159.0    610241.0    611718.0    615934.0    623633.0    631555.0
# 26406     34465.0     34328.0     34042.0     33631.0     33159.0     32578.0
# 26435    215703.0    214733.0    212881.0    211004.0    208809.0    205041.0
# 26466    707643.0    720505.0    733777.0    749997.0    767960.0    792172.0
# 26472     48665.0     48617.0     48550.0     48529.0     48557.0     48661.0
#
# [1108 rows x 99 columns]

# %%
#retrieving a list of the city names from the Single family owned homes
Single_City_Cal_List = SingleCCal['RegionName']
Single_City_Cal_List
# Out:
# 1          Los Angeles
# 8            San Diego
# 11            San Jose
# 14       San Francisco
# 30          Sacramento
#              ...
# 26401         Lockwood
# 26406           Tecopa
# 26435        Challenge
# 26466         Honeydew
# 26472           Darwin
# Name: RegionName, Length: 1108, dtype: object

# %%
#Creating lata and lng columns in the Single Family owned homes
SingleCCal['Latitude'] = ""
SingleCCal['Longitude'] =""
#creating lists to store the data of failed cities 
failedindex = []
failedcity = []
Lcounter = 0
#create a for loop to find the lat and lng of the cities 
SingleCCal = pd.DataFrame(SingleCCal)
for index, row in SingleCCal.iterrows():
    #connect to the Weather API to get latitude and longitude for the cities 
    target_city = f"{row[2]}, {row[7]}, California"
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
    gapi = requests.get(target_url)
    gapi
    Lcounter +=1

    #create a try and fail to not break the code if the information isnt found
    try:
        #grabbing the data from the API and loading it onto the DF
        SingleCCal.loc[index,'Longitude'] = gapi.json()["results"][0]["geometry"]["location"]["lng"]
        SingleCCal.loc[index,'Latitude']  = gapi.json()["results"][0]["geometry"]["location"]["lat"]
        #print successful
        print(f'{Lcounter} Found {row[2]} in Google IPA, and Adding Latitude and Longitude')
    except:
        #print Failure
        print(f'{Lcounter} Failed at finding Latitude and Longitude for {row[2]}')
        #store city information
        failedcity.append(row[2])
        failedindex.append(index)
# Out:
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 1 Found Los Angeles in weather IPA, and Adding Latitude and Longitude
# 2 Found San Diego in weather IPA, and Adding Latitude and Longitude
# 3 Found San Jose in weather IPA, and Adding Latitude and Longitude
# 4 Found San Francisco in weather IPA, and Adding Latitude and Longitude
# 5 Found Sacramento in weather IPA, and Adding Latitude and Longitude
# 6 Found Fresno in weather IPA, and Adding Latitude and Longitude
# 7 Found Long Beach in weather IPA, and Adding Latitude and Longitude
# 8 Found Oakland in weather IPA, and Adding Latitude and Longitude
# 9 Found Riverside in weather IPA, and Adding Latitude and Longitude
# 10 Found Bakersfield in weather IPA, and Adding Latitude and Longitude
# 11 Found Anaheim in weather IPA, and Adding Latitude and Longitude
# 12 Found Santa Ana in weather IPA, and Adding Latitude and Longitude
# 13 Found Stockton in weather IPA, and Adding Latitude and Longitude
# 14 Found Modesto in weather IPA, and Adding Latitude and Longitude
# 15 Found San Bernardino in weather IPA, and Adding Latitude and Longitude
# 16 Found Chula Vista in weather IPA, and Adding Latitude and Longitude
# 17 Found Irvine in weather IPA, and Adding Latitude and Longitude
# 18 Found Fremont in weather IPA, and Adding Latitude and Longitude
# 19 Found Santa Clarita in weather IPA, and Adding Latitude and Longitude
# 20 Found Fontana in weather IPA, and Adding Latitude and Longitude
# 21 Found Santa Rosa in weather IPA, and Adding Latitude and Longitude
# 22 Found Oxnard in weather IPA, and Adding Latitude and Longitude
# 23 Found Corona in weather IPA, and Adding Latitude and Longitude
# 24 Found Oceanside in weather IPA, and Adding Latitude and Longitude
# 25 Found Glendale in weather IPA, and Adding Latitude and Longitude
# 26 Found Moreno Valley in weather IPA, and Adding Latitude and Longitude
# 27 Found Huntington Beach in weather IPA, and Adding Latitude and Longitude
# 28 Found Salinas in weather IPA, and Adding Latitude and Longitude
# 29 Found Hayward in weather IPA, and Adding Latitude and Longitude
# 30 Found Lancaster in weather IPA, and Adding Latitude and Longitude
# 31 Found Garden Grove in weather IPA, and Adding Latitude and Longitude
# 32 Found Escondido in weather IPA, and Adding Latitude and Longitude
# 33 Found Ontario in weather IPA, and Adding Latitude and Longitude
# 34 Found Rancho Cucamonga in weather IPA, and Adding Latitude and Longitude
# 35 Found Palmdale in weather IPA, and Adding Latitude and Longitude
# 36 Found El Cajon in weather IPA, and Adding Latitude and Longitude
# 37 Found Elk Grove in weather IPA, and Adding Latitude and Longitude
# 38 Found Pomona in weather IPA, and Adding Latitude and Longitude
# 39 Found Visalia in weather IPA, and Adding Latitude and Longitude
# 40 Found Whittier in weather IPA, and Adding Latitude and Longitude
# 41 Found Sunnyvale in weather IPA, and Adding Latitude and Longitude
# 42 Found Pasadena in weather IPA, and Adding Latitude and Longitude
# 43 Found Santa Maria in weather IPA, and Adding Latitude and Longitude
# 44 Found Torrance in weather IPA, and Adding Latitude and Longitude
# 45 Found Fullerton in weather IPA, and Adding Latitude and Longitude
# 46 Found Orange in weather IPA, and Adding Latitude and Longitude
# 47 Found Compton in weather IPA, and Adding Latitude and Longitude
# 48 Found Inglewood in weather IPA, and Adding Latitude and Longitude
# 49 Found Concord in weather IPA, and Adding Latitude and Longitude
# 50 Found Thousand Oaks in weather IPA, and Adding Latitude and Longitude
# 51 Found Victorville in weather IPA, and Adding Latitude and Longitude
# 52 Found Roseville in weather IPA, and Adding Latitude and Longitude
# 53 Found Simi Valley in weather IPA, and Adding Latitude and Longitude
# 54 Found Murrieta in weather IPA, and Adding Latitude and Longitude
# 55 Found Temecula in weather IPA, and Adding Latitude and Longitude
# 56 Found Hemet in weather IPA, and Adding Latitude and Longitude
# 57 Found East Los Angeles in weather IPA, and Adding Latitude and Longitude
# 58 Found Vallejo in weather IPA, and Adding Latitude and Longitude
# 59 Found Santa Clara in weather IPA, and Adding Latitude and Longitude
# 60 Found Berkeley in weather IPA, and Adding Latitude and Longitude
# 61 Found Clovis in weather IPA, and Adding Latitude and Longitude
# 62 Found Vista in weather IPA, and Adding Latitude and Longitude
# 63 Found Richmond in weather IPA, and Adding Latitude and Longitude
# 64 Found Costa Mesa in weather IPA, and Adding Latitude and Longitude
# 65 Found El Monte in weather IPA, and Adding Latitude and Longitude
# 66 Found Chico in weather IPA, and Adding Latitude and Longitude
# 67 Found Downey in weather IPA, and Adding Latitude and Longitude
# 68 Found Tracy in weather IPA, and Adding Latitude and Longitude
# 69 Found Ventura in weather IPA, and Adding Latitude and Longitude
# 70 Found West Covina in weather IPA, and Adding Latitude and Longitude
# 71 Found Redding in weather IPA, and Adding Latitude and Longitude
# 72 Found Carlsbad in weather IPA, and Adding Latitude and Longitude
# 73 Found Santa Barbara in weather IPA, and Adding Latitude and Longitude
# 74 Found Norwalk in weather IPA, and Adding Latitude and Longitude
# 75 Found Antioch in weather IPA, and Adding Latitude and Longitude
# 76 Found Perris in weather IPA, and Adding Latitude and Longitude
# 77 Found Fairfield in weather IPA, and Adding Latitude and Longitude
# 78 Found San Leandro in weather IPA, and Adding Latitude and Longitude
# 79 Found Burbank in weather IPA, and Adding Latitude and Longitude
# 80 Found Vacaville in weather IPA, and Adding Latitude and Longitude
# 81 Found Madera in weather IPA, and Adding Latitude and Longitude
# 82 Found Hesperia in weather IPA, and Adding Latitude and Longitude
# 83 Found San Mateo in weather IPA, and Adding Latitude and Longitude
# 84 Found Merced in weather IPA, and Adding Latitude and Longitude
# 85 Found Santa Cruz in weather IPA, and Adding Latitude and Longitude
# 86 Found Daly City in weather IPA, and Adding Latitude and Longitude
# 87 Found Rialto in weather IPA, and Adding Latitude and Longitude
# 88 Found Napa in weather IPA, and Adding Latitude and Longitude
# 89 Found Mission Viejo in weather IPA, and Adding Latitude and Longitude
# 90 Found Livermore in weather IPA, and Adding Latitude and Longitude
# 91 Found South Gate in weather IPA, and Adding Latitude and Longitude
# 92 Found Hawthorne in weather IPA, and Adding Latitude and Longitude
# 93 Found Indio in weather IPA, and Adding Latitude and Longitude
# 94 Found Santa Monica in weather IPA, and Adding Latitude and Longitude
# 95 Found Westminster in weather IPA, and Adding Latitude and Longitude
# 96 Found Menifee in weather IPA, and Adding Latitude and Longitude
# 97 Found San Marcos in weather IPA, and Adding Latitude and Longitude
# 98 Found Chino in weather IPA, and Adding Latitude and Longitude
# 99 Found Redwood City in weather IPA, and Adding Latitude and Longitude
# 100 Found Pittsburg in weather IPA, and Adding Latitude and Longitude
# 101 Found Newport Beach in weather IPA, and Adding Latitude and Longitude
# 102 Found Arden-Arcade in weather IPA, and Adding Latitude and Longitude
# 103 Found Tustin in weather IPA, and Adding Latitude and Longitude
# 104 Found Citrus Heights in weather IPA, and Adding Latitude and Longitude
# 105 Found Walnut Creek in weather IPA, and Adding Latitude and Longitude
# 106 Found Buena Park in weather IPA, and Adding Latitude and Longitude
# 107 Found Alhambra in weather IPA, and Adding Latitude and Longitude
# 108 Found Watsonville in weather IPA, and Adding Latitude and Longitude
# 109 Found Manteca in weather IPA, and Adding Latitude and Longitude
# 110 Found Camarillo in weather IPA, and Adding Latitude and Longitude
# 111 Found Apple Valley in weather IPA, and Adding Latitude and Longitude
# 112 Found Lakewood in weather IPA, and Adding Latitude and Longitude
# 113 Found Covina in weather IPA, and Adding Latitude and Longitude
# 114 Found Upland in weather IPA, and Adding Latitude and Longitude
# 115 Found Carson in weather IPA, and Adding Latitude and Longitude
# 116 Found Porterville in weather IPA, and Adding Latitude and Longitude
# 117 Found Mountain View in weather IPA, and Adding Latitude and Longitude
# 118 Found Turlock in weather IPA, and Adding Latitude and Longitude
# 119 Found Bellflower in weather IPA, and Adding Latitude and Longitude
# 120 Found Lodi in weather IPA, and Adding Latitude and Longitude
# 121 Found Rancho Cordova in weather IPA, and Adding Latitude and Longitude
# 122 Found Baldwin Park in weather IPA, and Adding Latitude and Longitude
# 123 Found Spring Valley in weather IPA, and Adding Latitude and Longitude
# 124 Found San Ramon in weather IPA, and Adding Latitude and Longitude
# 125 Found Redlands in weather IPA, and Adding Latitude and Longitude
# 126 Found Folsom in weather IPA, and Adding Latitude and Longitude
# 127 Found Huntington Park in weather IPA, and Adding Latitude and Longitude
# 128 Found Petaluma in weather IPA, and Adding Latitude and Longitude
# 129 Found La Mesa in weather IPA, and Adding Latitude and Longitude
# 130 Found Lake Forest in weather IPA, and Adding Latitude and Longitude
# 131 Found Milpitas in weather IPA, and Adding Latitude and Longitude
# 132 Found Pleasanton in weather IPA, and Adding Latitude and Longitude
# 133 Found Tulare in weather IPA, and Adding Latitude and Longitude
# 134 Found Chino Hills in weather IPA, and Adding Latitude and Longitude
# 135 Found Lake Elsinore in weather IPA, and Adding Latitude and Longitude
# 136 Found San Rafael in weather IPA, and Adding Latitude and Longitude
# 137 Found Yuba City in weather IPA, and Adding Latitude and Longitude
# 138 Found Yorba Linda in weather IPA, and Adding Latitude and Longitude
# 139 Found Redondo Beach in weather IPA, and Adding Latitude and Longitude
# 140 Found Lynwood in weather IPA, and Adding Latitude and Longitude
# 141 Found Union City in weather IPA, and Adding Latitude and Longitude
# 142 Found Davis in weather IPA, and Adding Latitude and Longitude
# 143 Found Brentwood in weather IPA, and Adding Latitude and Longitude
# 144 Found Alameda in weather IPA, and Adding Latitude and Longitude
# 145 Found Hanford in weather IPA, and Adding Latitude and Longitude
# 146 Found Palo Alto in weather IPA, and Adding Latitude and Longitude
# 147 Found Arcadia in weather IPA, and Adding Latitude and Longitude
# 148 Found San Luis Obispo in weather IPA, and Adding Latitude and Longitude
# 149 Found Pico Rivera in weather IPA, and Adding Latitude and Longitude
# 150 Found Laguna Niguel in weather IPA, and Adding Latitude and Longitude
# 151 Found Rosemead in weather IPA, and Adding Latitude and Longitude
# 152 Found South San Francisco in weather IPA, and Adding Latitude and Longitude
# 153 Found San Gabriel in weather IPA, and Adding Latitude and Longitude
# 154 Found Montebello in weather IPA, and Adding Latitude and Longitude
# 155 Found Woodland in weather IPA, and Adding Latitude and Longitude
# 156 Found San Clemente in weather IPA, and Adding Latitude and Longitude
# 157 Found Novato in weather IPA, and Adding Latitude and Longitude
# 158 Found Florence-Graham in weather IPA, and Adding Latitude and Longitude
# 159 Found Encinitas in weather IPA, and Adding Latitude and Longitude
# 160 Found La Habra in weather IPA, and Adding Latitude and Longitude
# 161 Found Monterey Park in weather IPA, and Adding Latitude and Longitude
# 162 Found Gilroy in weather IPA, and Adding Latitude and Longitude
# 163 Found National City in weather IPA, and Adding Latitude and Longitude
# 164 Found Azusa in weather IPA, and Adding Latitude and Longitude
# 165 Found Gardena in weather IPA, and Adding Latitude and Longitude
# 166 Found Cupertino in weather IPA, and Adding Latitude and Longitude
# 167 Found Carmichael in weather IPA, and Adding Latitude and Longitude
# 168 Found Lompoc in weather IPA, and Adding Latitude and Longitude
# 169 Found Fountain Valley in weather IPA, and Adding Latitude and Longitude
# 170 Found South Whittier in weather IPA, and Adding Latitude and Longitude
# 171 Found Rocklin in weather IPA, and Adding Latitude and Longitude
# 172 Found Colton in weather IPA, and Adding Latitude and Longitude
# 173 Found El Centro in weather IPA, and Adding Latitude and Longitude
# 174 Found Santee in weather IPA, and Adding Latitude and Longitude
# 175 Found Paramount in weather IPA, and Adding Latitude and Longitude
# 176 Found Glendora in weather IPA, and Adding Latitude and Longitude
# 177 Found Danville in weather IPA, and Adding Latitude and Longitude
# 178 Found Palm Desert in weather IPA, and Adding Latitude and Longitude
# 179 Found Delano in weather IPA, and Adding Latitude and Longitude
# 180 Found Castro Valley in weather IPA, and Adding Latitude and Longitude
# 181 Found Lincoln in weather IPA, and Adding Latitude and Longitude
# 182 Found Hacienda Heights in weather IPA, and Adding Latitude and Longitude
# 183 Found West Sacramento in weather IPA, and Adding Latitude and Longitude
# 184 Found Yucaipa in weather IPA, and Adding Latitude and Longitude
# 185 Found Oroville in weather IPA, and Adding Latitude and Longitude
# 186 Found Placentia in weather IPA, and Adding Latitude and Longitude
# 187 Found Hollister in weather IPA, and Adding Latitude and Longitude
# 188 Found Poway in weather IPA, and Adding Latitude and Longitude
# 189 Found Fallbrook in weather IPA, and Adding Latitude and Longitude
# 190 Found Cathedral City in weather IPA, and Adding Latitude and Longitude
# 191 Found Palm Springs in weather IPA, and Adding Latitude and Longitude
# 192 Found La Mirada in weather IPA, and Adding Latitude and Longitude
# 193 Found Cypress in weather IPA, and Adding Latitude and Longitude
# 194 Found Cerritos in weather IPA, and Adding Latitude and Longitude
# 195 Found Eastvale in weather IPA, and Adding Latitude and Longitude
# 196 Found San Jacinto in weather IPA, and Adding Latitude and Longitude
# 197 Found Aliso Viejo in weather IPA, and Adding Latitude and Longitude
# 198 Found Diamond Bar in weather IPA, and Adding Latitude and Longitude
# 199 Found Martinez in weather IPA, and Adding Latitude and Longitude
# 200 Found Dublin in weather IPA, and Adding Latitude and Longitude
# 201 Found Highland in weather IPA, and Adding Latitude and Longitude
# 202 Found Morgan Hill in weather IPA, and Adding Latitude and Longitude
# 203 Found Eureka in weather IPA, and Adding Latitude and Longitude
# 204 Found Brea in weather IPA, and Adding Latitude and Longitude
# 205 Found Auburn in weather IPA, and Adding Latitude and Longitude
# 206 Found Desert Hot Springs in weather IPA, and Adding Latitude and Longitude
# 207 Found Grass Valley in weather IPA, and Adding Latitude and Longitude
# 208 Found Beaumont in weather IPA, and Adding Latitude and Longitude
# 209 Found Coachella in weather IPA, and Adding Latitude and Longitude
# 210 Found Rowland Heights in weather IPA, and Adding Latitude and Longitude
# 211 Found Lakeside in weather IPA, and Adding Latitude and Longitude
# 212 Found Newark in weather IPA, and Adding Latitude and Longitude
# 213 Found Fair Oaks in weather IPA, and Adding Latitude and Longitude
# 214 Found Monrovia in weather IPA, and Adding Latitude and Longitude
# 215 Found Bell Gardens in weather IPA, and Adding Latitude and Longitude
# 216 Found Rancho Santa Margarita in weather IPA, and Adding Latitude and Longitude
# 217 Found Campbell in weather IPA, and Adding Latitude and Longitude
# 218 Found Menlo Park in weather IPA, and Adding Latitude and Longitude
# 219 Found San Bruno in weather IPA, and Adding Latitude and Longitude
# 220 Found Paso Robles in weather IPA, and Adding Latitude and Longitude
# 221 Found San Pablo in weather IPA, and Adding Latitude and Longitude
# 222 Found La Puente in weather IPA, and Adding Latitude and Longitude
# 223 Found Ceres in weather IPA, and Adding Latitude and Longitude
# 224 Found Rancho Palos Verdes in weather IPA, and Adding Latitude and Longitude
# 225 Found Los Banos in weather IPA, and Adding Latitude and Longitude
# 226 Found Oakley in weather IPA, and Adding Latitude and Longitude
# 227 Found Culver City in weather IPA, and Adding Latitude and Longitude
# 228 Found Ramona in weather IPA, and Adding Latitude and Longitude
# 229 Found La Quinta in weather IPA, and Adding Latitude and Longitude
# 230 Found Montclair in weather IPA, and Adding Latitude and Longitude
# 231 Found Pacifica in weather IPA, and Adding Latitude and Longitude
# 232 Found El Dorado Hills in weather IPA, and Adding Latitude and Longitude
# 233 Found Atwater in weather IPA, and Adding Latitude and Longitude
# 234 Found Rohnert Park in weather IPA, and Adding Latitude and Longitude
# 235 Found Moorpark in weather IPA, and Adding Latitude and Longitude
# 236 Found Claremont in weather IPA, and Adding Latitude and Longitude
# 237 Found Altadena in weather IPA, and Adding Latitude and Longitude
# 238 Found Lemoore in weather IPA, and Adding Latitude and Longitude
# 239 Found San Juan Capistrano in weather IPA, and Adding Latitude and Longitude
# 240 Found Sonoma in weather IPA, and Adding Latitude and Longitude
# 241 Found Wildomar in weather IPA, and Adding Latitude and Longitude
# 242 Found West Hollywood in weather IPA, and Adding Latitude and Longitude
# 243 Found Bell in weather IPA, and Adding Latitude and Longitude
# 244 Found Santa Paula in weather IPA, and Adding Latitude and Longitude
# 245 Found Placerville in weather IPA, and Adding Latitude and Longitude
# 246 Found Temple City in weather IPA, and Adding Latitude and Longitude
# 247 Found Calexico in weather IPA, and Adding Latitude and Longitude
# 248 Found Los Gatos in weather IPA, and Adding Latitude and Longitude
# 249 Found Barstow in weather IPA, and Adding Latitude and Longitude
# 250 Found Rubidoux in weather IPA, and Adding Latitude and Longitude
# 251 Found Beverly Hills in weather IPA, and Adding Latitude and Longitude
# 252 Found Pleasant Hill in weather IPA, and Adding Latitude and Longitude
# 253 Found Marysville in weather IPA, and Adding Latitude and Longitude
# 254 Found Manhattan Beach in weather IPA, and Adding Latitude and Longitude
# 255 Found Sanger in weather IPA, and Adding Latitude and Longitude
# 256 Found Dana Point in weather IPA, and Adding Latitude and Longitude
# 257 Found Shingle Springs in weather IPA, and Adding Latitude and Longitude
# 258 Found Ridgecrest in weather IPA, and Adding Latitude and Longitude
# 259 Found Galt in weather IPA, and Adding Latitude and Longitude
# 260 Found Adelanto in weather IPA, and Adding Latitude and Longitude
# 261 Found San Dimas in weather IPA, and Adding Latitude and Longitude
# 262 Found La Verne in weather IPA, and Adding Latitude and Longitude
# 263 Found Oakdale in weather IPA, and Adding Latitude and Longitude
# 264 Found Banning in weather IPA, and Adding Latitude and Longitude
# 265 Found Tehachapi in weather IPA, and Adding Latitude and Longitude
# 266 Found Reedley in weather IPA, and Adding Latitude and Longitude
# 267 Found Lawndale in weather IPA, and Adding Latitude and Longitude
# 268 Found Los Altos in weather IPA, and Adding Latitude and Longitude
# 269 Found Foster City in weather IPA, and Adding Latitude and Longitude
# 270 Found Dinuba in weather IPA, and Adding Latitude and Longitude
# 271 Found Atascadero in weather IPA, and Adding Latitude and Longitude
# 272 Found Westmont in weather IPA, and Adding Latitude and Longitude
# 273 Found Saratoga in weather IPA, and Adding Latitude and Longitude
# 274 Found Winchester in weather IPA, and Adding Latitude and Longitude
# 275 Found Ukiah in weather IPA, and Adding Latitude and Longitude
# 276 Found Orangevale in weather IPA, and Adding Latitude and Longitude
# 277 Found Burlingame in weather IPA, and Adding Latitude and Longitude
# 278 Found Seaside in weather IPA, and Adding Latitude and Longitude
# 279 Found Monterey in weather IPA, and Adding Latitude and Longitude
# 280 Found Laguna Hills in weather IPA, and Adding Latitude and Longitude
# 281 Found Walnut in weather IPA, and Adding Latitude and Longitude
# 282 Found Selma in weather IPA, and Adding Latitude and Longitude
# 283 Found San Carlos in weather IPA, and Adding Latitude and Longitude
# 284 Found Lafayette in weather IPA, and Adding Latitude and Longitude
# 285 Found Sebastopol in weather IPA, and Adding Latitude and Longitude
# 286 Found San Lorenzo in weather IPA, and Adding Latitude and Longitude
# 287 Found Arroyo Grande in weather IPA, and Adding Latitude and Longitude
# 288 Found South Lake Tahoe in weather IPA, and Adding Latitude and Longitude
# 289 Found Florin in weather IPA, and Adding Latitude and Longitude
# 290 Found Mill Valley in weather IPA, and Adding Latitude and Longitude
# 291 Found Norco in weather IPA, and Adding Latitude and Longitude
# 292 Found Red Bluff in weather IPA, and Adding Latitude and Longitude
# 293 Found Olivehurst in weather IPA, and Adding Latitude and Longitude
# 294 Found Goleta in weather IPA, and Adding Latitude and Longitude
# 295 Found Sonora in weather IPA, and Adding Latitude and Longitude
# 296 Found Stanton in weather IPA, and Adding Latitude and Longitude
# 297 Found Wasco in weather IPA, and Adding Latitude and Longitude
# 298 Found Suisun City in weather IPA, and Adding Latitude and Longitude
# 299 Found Ladera Ranch in weather IPA, and Adding Latitude and Longitude
# 300 Found Windsor in weather IPA, and Adding Latitude and Longitude
# 301 Found East Palo Alto in weather IPA, and Adding Latitude and Longitude
# 302 Found Imperial Beach in weather IPA, and Adding Latitude and Longitude
# 303 Found Belmont in weather IPA, and Adding Latitude and Longitude
# 304 Found Maywood in weather IPA, and Adding Latitude and Longitude
# 305 Found Isla Vista in weather IPA, and Adding Latitude and Longitude
# 306 Found Corcoran in weather IPA, and Adding Latitude and Longitude
# 307 Found South Pasadena in weather IPA, and Adding Latitude and Longitude
# 308 Found Lemon Grove in weather IPA, and Adding Latitude and Longitude
# 309 Found Soledad in weather IPA, and Adding Latitude and Longitude
# 310 Found Benicia in weather IPA, and Adding Latitude and Longitude
# 311 Found Paradise in weather IPA, and Adding Latitude and Longitude
# 312 Found Patterson in weather IPA, and Adding Latitude and Longitude
# 313 Found Aptos in weather IPA, and Adding Latitude and Longitude
# 314 Found Yucca Valley in weather IPA, and Adding Latitude and Longitude
# 315 Found Oildale in weather IPA, and Adding Latitude and Longitude
# 316 Found Cudahy in weather IPA, and Adding Latitude and Longitude
# 317 Found Seal Beach in weather IPA, and Adding Latitude and Longitude
# 318 Found El Cerrito in weather IPA, and Adding Latitude and Longitude
# 319 Found San Fernando in weather IPA, and Adding Latitude and Longitude
# 320 Found Anderson in weather IPA, and Adding Latitude and Longitude
# 321 Found Agoura Hills in weather IPA, and Adding Latitude and Longitude
# 322 Found Mira Loma in weather IPA, and Adding Latitude and Longitude
# 323 Found Coronado in weather IPA, and Adding Latitude and Longitude
# 324 Found Rosemont in weather IPA, and Adding Latitude and Longitude
# 325 Found North Tustin in weather IPA, and Adding Latitude and Longitude
# 326 Found Calabasas in weather IPA, and Adding Latitude and Longitude
# 327 Found Granite Bay in weather IPA, and Adding Latitude and Longitude
# 328 Found Port Hueneme in weather IPA, and Adding Latitude and Longitude
# 329 Found Dixon in weather IPA, and Adding Latitude and Longitude
# 330 Found Castaic in weather IPA, and Adding Latitude and Longitude
# 331 Found Millbrae in weather IPA, and Adding Latitude and Longitude
# 332 Found Chowchilla in weather IPA, and Adding Latitude and Longitude
# 333 Found Valley Center in weather IPA, and Adding Latitude and Longitude
# 334 Found American Canyon in weather IPA, and Adding Latitude and Longitude
# 335 Found Phelan in weather IPA, and Adding Latitude and Longitude
# 336 Found West Carson in weather IPA, and Adding Latitude and Longitude
# 337 Found Duarte in weather IPA, and Adding Latitude and Longitude
# 338 Found Loma Linda in weather IPA, and Adding Latitude and Longitude
# 339 Found Valinda in weather IPA, and Adding Latitude and Longitude
# 340 Found Marina in weather IPA, and Adding Latitude and Longitude
# 341 Found Willowbrook in weather IPA, and Adding Latitude and Longitude
# 342 Found Hercules in weather IPA, and Adding Latitude and Longitude
# 343 Found Los Alamitos in weather IPA, and Adding Latitude and Longitude
# 344 Found Blythe in weather IPA, and Adding Latitude and Longitude
# 345 Found Twentynine Palms in weather IPA, and Adding Latitude and Longitude
# 346 Found La Canada Flintridge in weather IPA, and Adding Latitude and Longitude
# 347 Found West Puente Valley in weather IPA, and Adding Latitude and Longitude
# 348 Found Susanville in weather IPA, and Adding Latitude and Longitude
# 349 Found Kerman in weather IPA, and Adding Latitude and Longitude
# 350 Found Rosamond in weather IPA, and Adding Latitude and Longitude
# 351 Found South El Monte in weather IPA, and Adding Latitude and Longitude
# 352 Found Brawley in weather IPA, and Adding Latitude and Longitude
# 353 Found Shafter in weather IPA, and Adding Latitude and Longitude
# 354 Found Crescent City in weather IPA, and Adding Latitude and Longitude
# 355 Found Greenfield in weather IPA, and Adding Latitude and Longitude
# 356 Found Arcata in weather IPA, and Adding Latitude and Longitude
# 357 Found Healdsburg in weather IPA, and Adding Latitude and Longitude
# 358 Found Arvin in weather IPA, and Adding Latitude and Longitude
# 359 Found Lomita in weather IPA, and Adding Latitude and Longitude
# 360 Found Ojai in weather IPA, and Adding Latitude and Longitude
# 361 Found Coalinga in weather IPA, and Adding Latitude and Longitude
# 362 Found Lathrop in weather IPA, and Adding Latitude and Longitude
# 363 Found Laguna Beach in weather IPA, and Adding Latitude and Longitude
# 364 Found Bloomington in weather IPA, and Adding Latitude and Longitude
# 365 Found Albany in weather IPA, and Adding Latitude and Longitude
# 366 Found Nipomo in weather IPA, and Adding Latitude and Longitude
# 367 Found La Crescenta-Montrose in weather IPA, and Adding Latitude and Longitude
# 368 Found Nevada City in weather IPA, and Adding Latitude and Longitude
# 369 Found Lindsay in weather IPA, and Adding Latitude and Longitude
# 370 Found Pinole in weather IPA, and Adding Latitude and Longitude
# 371 Found Truckee in weather IPA, and Adding Latitude and Longitude
# 372 Found Malibu in weather IPA, and Adding Latitude and Longitude
# 373 Found Alpine in weather IPA, and Adding Latitude and Longitude
# 374 Found Hermosa Beach in weather IPA, and Adding Latitude and Longitude
# 375 Found McKinleyville in weather IPA, and Adding Latitude and Longitude
# 376 Found Fillmore in weather IPA, and Adding Latitude and Longitude
# 377 Found Santa Fe Springs in weather IPA, and Adding Latitude and Longitude
# 378 Found Orinda in weather IPA, and Adding Latitude and Longitude
# 379 Found Taft in weather IPA, and Adding Latitude and Longitude
# 380 Found Ripon in weather IPA, and Adding Latitude and Longitude
# 381 Found Rosedale in weather IPA, and Adding Latitude and Longitude
# 382 Found South San Jose Hills in weather IPA, and Adding Latitude and Longitude
# 383 Found Thermal in weather IPA, and Adding Latitude and Longitude
# 384 Found Riverbank in weather IPA, and Adding Latitude and Longitude
# 385 Found Alamo in weather IPA, and Adding Latitude and Longitude
# 386 Found Rancho Mirage in weather IPA, and Adding Latitude and Longitude
# 387 Found Moraga in weather IPA, and Adding Latitude and Longitude
# 388 Found Artesia in weather IPA, and Adding Latitude and Longitude
# 389 Found El Segundo in weather IPA, and Adding Latitude and Longitude
# 390 Found Bonita in weather IPA, and Adding Latitude and Longitude
# 391 Found Kingsburg in weather IPA, and Adding Latitude and Longitude
# 392 Found Carpinteria in weather IPA, and Adding Latitude and Longitude
# 393 Found Exeter in weather IPA, and Adding Latitude and Longitude
# 394 Found Livingston in weather IPA, and Adding Latitude and Longitude
# 395 Found Laguna Woods in weather IPA, and Adding Latitude and Longitude
# 396 Found Nuevo in weather IPA, and Adding Latitude and Longitude
# 397 Found Mc Farland in weather IPA, and Adding Latitude and Longitude
# 398 Found La Palma in weather IPA, and Adding Latitude and Longitude
# 399 Found Parlier in weather IPA, and Adding Latitude and Longitude
# 400 Found Winton in weather IPA, and Adding Latitude and Longitude
# 401 Found Glen Avon in weather IPA, and Adding Latitude and Longitude
# 402 Found Half Moon Bay in weather IPA, and Adding Latitude and Longitude
# 403 Found Orland in weather IPA, and Adding Latitude and Longitude
# 404 Found San Anselmo in weather IPA, and Adding Latitude and Longitude
# 405 Found Corning in weather IPA, and Adding Latitude and Longitude
# 406 Found Loomis in weather IPA, and Adding Latitude and Longitude
# 407 Found King City in weather IPA, and Adding Latitude and Longitude
# 408 Found Cottonwood in weather IPA, and Adding Latitude and Longitude
# 409 Found Firebaugh in weather IPA, and Adding Latitude and Longitude
# 410 Found Pacific Grove in weather IPA, and Adding Latitude and Longitude
# 411 Found Rio Linda in weather IPA, and Adding Latitude and Longitude
# 412 Found Littlerock in weather IPA, and Adding Latitude and Longitude
# 413 Found Oak Park in weather IPA, and Adding Latitude and Longitude
# 414 Found Carmel-by-the-Sea in weather IPA, and Adding Latitude and Longitude
# 415 Found Los Osos in weather IPA, and Adding Latitude and Longitude
# 416 Found Scotts Valley in weather IPA, and Adding Latitude and Longitude
# 417 Found Stanford in weather IPA, and Adding Latitude and Longitude
# 418 Found Clearlake in weather IPA, and Adding Latitude and Longitude
# 419 Found Imperial in weather IPA, and Adding Latitude and Longitude
# 420 Found Hawaiian Gardens in weather IPA, and Adding Latitude and Longitude
# 421 Found Coto de Caza in weather IPA, and Adding Latitude and Longitude
# 422 Found Hughson in weather IPA, and Adding Latitude and Longitude
# 423 Found Westlake Village in weather IPA, and Adding Latitude and Longitude
# 424 Found Alum Rock in weather IPA, and Adding Latitude and Longitude
# 425 Found Willits in weather IPA, and Adding Latitude and Longitude
# 426 Found Avenal in weather IPA, and Adding Latitude and Longitude
# 427 Found Holtville in weather IPA, and Adding Latitude and Longitude
# 428 Found Grover Beach in weather IPA, and Adding Latitude and Longitude
# 429 Found Fort Bragg in weather IPA, and Adding Latitude and Longitude
# 430 Found Bishop in weather IPA, and Adding Latitude and Longitude
# 431 Found Clayton in weather IPA, and Adding Latitude and Longitude
# 432 Found Commerce in weather IPA, and Adding Latitude and Longitude
# 433 Found San Marino in weather IPA, and Adding Latitude and Longitude
# 434 Found Avocado Heights in weather IPA, and Adding Latitude and Longitude
# 435 Found Valley Springs in weather IPA, and Adding Latitude and Longitude
# 436 Found Pedley in weather IPA, and Adding Latitude and Longitude
# 437 Found Escalon in weather IPA, and Adding Latitude and Longitude
# 438 Found Fortuna in weather IPA, and Adding Latitude and Longitude
# 439 Found Newman in weather IPA, and Adding Latitude and Longitude
# 440 Found Lamont in weather IPA, and Adding Latitude and Longitude
# 441 Found Palos Verdes Estates in weather IPA, and Adding Latitude and Longitude
# 442 Found Sausalito in weather IPA, and Adding Latitude and Longitude
# 443 Found Delhi in weather IPA, and Adding Latitude and Longitude
# 444 Found Calimesa in weather IPA, and Adding Latitude and Longitude
# 445 Found Canyon Lake in weather IPA, and Adding Latitude and Longitude
# 446 Found Mecca in weather IPA, and Adding Latitude and Longitude
# 447 Found Grand Terrace in weather IPA, and Adding Latitude and Longitude
# 448 Found Gridley in weather IPA, and Adding Latitude and Longitude
# 449 Found View Park-Windsor Hills in weather IPA, and Adding Latitude and Longitude
# 450 Found Coarsegold in weather IPA, and Adding Latitude and Longitude
# 451 Found El Sobrante in weather IPA, and Adding Latitude and Longitude
# 452 Found Piedmont in weather IPA, and Adding Latitude and Longitude
# 453 Found Solana Beach in weather IPA, and Adding Latitude and Longitude
# 454 Found Big Bear City in weather IPA, and Adding Latitude and Longitude
# 455 Found Kelseyville in weather IPA, and Adding Latitude and Longitude
# 456 Found Magalia in weather IPA, and Adding Latitude and Longitude
# 457 Found Orosi in weather IPA, and Adding Latitude and Longitude
# 458 Found Signal Hill in weather IPA, and Adding Latitude and Longitude
# 459 Found Live Oak in weather IPA, and Adding Latitude and Longitude
# 460 Found Garden Acres in weather IPA, and Adding Latitude and Longitude
# 461 Found Hillsborough in weather IPA, and Adding Latitude and Longitude
# 462 Found Sierra Madre in weather IPA, and Adding Latitude and Longitude
# 463 Found Newport Coast in weather IPA, and Adding Latitude and Longitude
# 464 Found California City in weather IPA, and Adding Latitude and Longitude
# 465 Found Dos Palos in weather IPA, and Adding Latitude and Longitude
# 466 Found Lakeport in weather IPA, and Adding Latitude and Longitude
# 467 Found Cotati in weather IPA, and Adding Latitude and Longitude
# 468 Found Woodside in weather IPA, and Adding Latitude and Longitude
# 469 Found Lake Arrowhead in weather IPA, and Adding Latitude and Longitude
# 470 Found Tiburon in weather IPA, and Adding Latitude and Longitude
# 471 Found East La Mirada in weather IPA, and Adding Latitude and Longitude
# 472 Found North Fair Oaks in weather IPA, and Adding Latitude and Longitude
# 473 Found Morro Bay in weather IPA, and Adding Latitude and Longitude
# 474 Found Jamul in weather IPA, and Adding Latitude and Longitude
# 475 Found Emeryville in weather IPA, and Adding Latitude and Longitude
# 476 Found Soquel in weather IPA, and Adding Latitude and Longitude
# 477 Found Shasta Lake in weather IPA, and Adding Latitude and Longitude
# 478 Found Rancho Santa Fe in weather IPA, and Adding Latitude and Longitude
# 479 Found Cloverdale in weather IPA, and Adding Latitude and Longitude
# 480 Found Mariposa in weather IPA, and Adding Latitude and Longitude
# 481 Found Corte Madera in weather IPA, and Adding Latitude and Longitude
# 482 Found Rodeo in weather IPA, and Adding Latitude and Longitude
# 483 Found Muscoy in weather IPA, and Adding Latitude and Longitude
# 484 Found Rolling Hills Estates in weather IPA, and Adding Latitude and Longitude
# 485 Found Colfax in weather IPA, and Adding Latitude and Longitude
# 486 Found Marina del Rey in weather IPA, and Adding Latitude and Longitude
# 487 Found Woodlake in weather IPA, and Adding Latitude and Longitude
# 488 Found Pollock Pines in weather IPA, and Adding Latitude and Longitude
# 489 Found Earlimart in weather IPA, and Adding Latitude and Longitude
# 490 Found La Riviera in weather IPA, and Adding Latitude and Longitude
# 491 Found Penn Valley in weather IPA, and Adding Latitude and Longitude
# 492 Found Boulder Creek in weather IPA, and Adding Latitude and Longitude
# 493 Found Joshua Tree in weather IPA, and Adding Latitude and Longitude
# 494 Found Orange Cove in weather IPA, and Adding Latitude and Longitude
# 495 Found Salida in weather IPA, and Adding Latitude and Longitude
# 496 Found Discovery Bay in weather IPA, and Adding Latitude and Longitude
# 497 Found Waterford in weather IPA, and Adding Latitude and Longitude
# 498 Found Capitola in weather IPA, and Adding Latitude and Longitude
# 499 Found Gonzales in weather IPA, and Adding Latitude and Longitude
# 500 Found Winters in weather IPA, and Adding Latitude and Longitude
# 501 Found Ladera Heights in weather IPA, and Adding Latitude and Longitude
# 502 Found East Foothills in weather IPA, and Adding Latitude and Longitude
# 503 Found Saint Helena in weather IPA, and Adding Latitude and Longitude
# 504 Found Yreka in weather IPA, and Adding Latitude and Longitude
# 505 Found Templeton in weather IPA, and Adding Latitude and Longitude
# 506 Found Indian Wells in weather IPA, and Adding Latitude and Longitude
# 507 Found Gustine in weather IPA, and Adding Latitude and Longitude
# 508 Found Fairfax in weather IPA, and Adding Latitude and Longitude
# 509 Found Castroville in weather IPA, and Adding Latitude and Longitude
# 510 Found Jamestown in weather IPA, and Adding Latitude and Longitude
# 511 Found Willows in weather IPA, and Adding Latitude and Longitude
# 512 Found Mentone in weather IPA, and Adding Latitude and Longitude
# 513 Found Riverdale in weather IPA, and Adding Latitude and Longitude
# 514 Found Mendota in weather IPA, and Adding Latitude and Longitude
# 515 Found Oceano in weather IPA, and Adding Latitude and Longitude
# 516 Found Los Altos Hills in weather IPA, and Adding Latitude and Longitude
# 517 Found West Athens in weather IPA, and Adding Latitude and Longitude
# 518 Found Mammoth Lakes in weather IPA, and Adding Latitude and Longitude
# 519 Found Colusa in weather IPA, and Adding Latitude and Longitude
# 520 Found Thousand Palms in weather IPA, and Adding Latitude and Longitude
# 521 Found Crestline in weather IPA, and Adding Latitude and Longitude
# 522 Found Acton in weather IPA, and Adding Latitude and Longitude
# 523 Found Calistoga in weather IPA, and Adding Latitude and Longitude
# 524 Found Solvang in weather IPA, and Adding Latitude and Longitude
# 525 Found Felton in weather IPA, and Adding Latitude and Longitude
# 526 Found Alondra Park in weather IPA, and Adding Latitude and Longitude
# 527 Found Lucerne Valley in weather IPA, and Adding Latitude and Longitude
# 528 Found Hilmar in weather IPA, and Adding Latitude and Longitude
# 529 Found August in weather IPA, and Adding Latitude and Longitude
# 530 Found Newcastle in weather IPA, and Adding Latitude and Longitude
# 531 Found Atherton in weather IPA, and Adding Latitude and Longitude
# 532 Found Montecito in weather IPA, and Adding Latitude and Longitude
# 533 Found Denair in weather IPA, and Adding Latitude and Longitude
# 534 Found Calipatria in weather IPA, and Adding Latitude and Longitude
# 535 Found Farmersville in weather IPA, and Adding Latitude and Longitude
# 536 Found Heber in weather IPA, and Adding Latitude and Longitude
# 537 Found Jackson in weather IPA, and Adding Latitude and Longitude
# 538 Found Guadalupe in weather IPA, and Adding Latitude and Longitude
# 539 Found Elverta in weather IPA, and Adding Latitude and Longitude
# 540 Found Acampo in weather IPA, and Adding Latitude and Longitude
# 541 Found Rio Vista in weather IPA, and Adding Latitude and Longitude
# 542 Found Kentfield in weather IPA, and Adding Latitude and Longitude
# 543 Found Freedom in weather IPA, and Adding Latitude and Longitude
# 544 Found La Habra Heights in weather IPA, and Adding Latitude and Longitude
# 545 Found Mojave in weather IPA, and Adding Latitude and Longitude
# 546 Found Fowler in weather IPA, and Adding Latitude and Longitude
# 547 Found San Miguel in weather IPA, and Adding Latitude and Longitude
# 548 Found Silverado in weather IPA, and Adding Latitude and Longitude
# 549 Found Topanga in weather IPA, and Adding Latitude and Longitude
# 550 Found Larkspur in weather IPA, and Adding Latitude and Longitude
# 551 Found Redwood Valley in weather IPA, and Adding Latitude and Longitude
# 552 Found French Camp in weather IPA, and Adding Latitude and Longitude
# 553 Found Oak View in weather IPA, and Adding Latitude and Longitude
# 554 Found Strathmore in weather IPA, and Adding Latitude and Longitude
# 555 Found Cutler in weather IPA, and Adding Latitude and Longitude
# 556 Found Pixley in weather IPA, and Adding Latitude and Longitude
# 557 Found Sloughhouse in weather IPA, and Adding Latitude and Longitude
# 558 Found Ben Lomond in weather IPA, and Adding Latitude and Longitude
# 559 Found Quincy in weather IPA, and Adding Latitude and Longitude
# 560 Found Carmel Valley in weather IPA, and Adding Latitude and Longitude
# 561 Found Huron in weather IPA, and Adding Latitude and Longitude
# 562 Found Lake Isabella in weather IPA, and Adding Latitude and Longitude
# 563 Found Homeland in weather IPA, and Adding Latitude and Longitude
# 564 Found San Martin in weather IPA, and Adding Latitude and Longitude
# 565 Found Williams in weather IPA, and Adding Latitude and Longitude
# 566 Found Villa Park in weather IPA, and Adding Latitude and Longitude
# 567 Found Caruthers in weather IPA, and Adding Latitude and Longitude
# 568 Found Terra Bella in weather IPA, and Adding Latitude and Longitude
# 569 Found Montague in weather IPA, and Adding Latitude and Longitude
# 570 Found Oakhurst in weather IPA, and Adding Latitude and Longitude
# 571 Found Pismo Beach in weather IPA, and Adding Latitude and Longitude
# 572 Found Kensington in weather IPA, and Adding Latitude and Longitude
# 573 Found Foresthill in weather IPA, and Adding Latitude and Longitude
# 574 Found Buellton in weather IPA, and Adding Latitude and Longitude
# 575 Found Santa Ynez in weather IPA, and Adding Latitude and Longitude
# 576 Found Forestville in weather IPA, and Adding Latitude and Longitude
# 577 Found Linden in weather IPA, and Adding Latitude and Longitude
# 578 Found East Pasadena in weather IPA, and Adding Latitude and Longitude
# 579 Found Helendale in weather IPA, and Adding Latitude and Longitude
# 580 Found Cambria in weather IPA, and Adding Latitude and Longitude
# 581 Found Murphys in weather IPA, and Adding Latitude and Longitude
# 582 Found Moss Landing in weather IPA, and Adding Latitude and Longitude
# 583 Found South Yuba City in weather IPA, and Adding Latitude and Longitude
# 584 Found Pioneer in weather IPA, and Adding Latitude and Longitude
# 585 Found Arbuckle in weather IPA, and Adding Latitude and Longitude
# 586 Found Pine Grove in weather IPA, and Adding Latitude and Longitude
# 587 Found Weed in weather IPA, and Adding Latitude and Longitude
# 588 Found Big Bear Lake in weather IPA, and Adding Latitude and Longitude
# 589 Found Mount Shasta in weather IPA, and Adding Latitude and Longitude
# 590 Found Pinon Hills in weather IPA, and Adding Latitude and Longitude
# 591 Found Wilton in weather IPA, and Adding Latitude and Longitude
# 592 Found San Joaquin in weather IPA, and Adding Latitude and Longitude
# 593 Found Diamond Springs in weather IPA, and Adding Latitude and Longitude
# 594 Found Camino in weather IPA, and Adding Latitude and Longitude
# 595 Found San Juan Bautista in weather IPA, and Adding Latitude and Longitude
# 596 Found Hidden Valley Lake in weather IPA, and Adding Latitude and Longitude
# 597 Found Kennedy in weather IPA, and Adding Latitude and Longitude
# 598 Found Rescue in weather IPA, and Adding Latitude and Longitude
# 599 Found Cool in weather IPA, and Adding Latitude and Longitude
# 600 Found Keyes in weather IPA, and Adding Latitude and Longitude
# 601 Found Frazier Park in weather IPA, and Adding Latitude and Longitude
# 602 Found San Andreas in weather IPA, and Adding Latitude and Longitude
# 603 Found Bonsall in weather IPA, and Adding Latitude and Longitude
# 604 Found Penngrove in weather IPA, and Adding Latitude and Longitude
# 605 Found Morongo Valley in weather IPA, and Adding Latitude and Longitude
# 606 Found Del Monte Forest in weather IPA, and Adding Latitude and Longitude
# 607 Found Guerneville in weather IPA, and Adding Latitude and Longitude
# 608 Found Wheatland in weather IPA, and Adding Latitude and Longitude
# 609 Found Morada in weather IPA, and Adding Latitude and Longitude
# 610 Found Brisbane in weather IPA, and Adding Latitude and Longitude
# 611 Found Clearlake Oaks in weather IPA, and Adding Latitude and Longitude
# 612 Found Needles in weather IPA, and Adding Latitude and Longitude
# 613 Found Aromas in weather IPA, and Adding Latitude and Longitude
# 614 Found Meadow Vista in weather IPA, and Adding Latitude and Longitude
# 615 Found Lower Lake in weather IPA, and Adding Latitude and Longitude
# 616 Found Middletown in weather IPA, and Adding Latitude and Longitude
# 617 Found Twain Harte in weather IPA, and Adding Latitude and Longitude
# 618 Found Glen Ellen in weather IPA, and Adding Latitude and Longitude
# 619 Found Lincoln Village in weather IPA, and Adding Latitude and Longitude
# 620 Found Mather in weather IPA, and Adding Latitude and Longitude
# 621 Found Esparto in weather IPA, and Adding Latitude and Longitude
# 622 Found Portola Valley in weather IPA, and Adding Latitude and Longitude
# 623 Found Angwin in weather IPA, and Adding Latitude and Longitude
# 624 Found Alturas in weather IPA, and Adding Latitude and Longitude
# 625 Found Highlands-Baywood Park in weather IPA, and Adding Latitude and Longitude
# 626 Found Garden Valley in weather IPA, and Adding Latitude and Longitude
# 627 Found Le Grand in weather IPA, and Adding Latitude and Longitude
# 628 Found Descanso in weather IPA, and Adding Latitude and Longitude
# 629 Found Palo Cedro in weather IPA, and Adding Latitude and Longitude
# 630 Found Tipton in weather IPA, and Adding Latitude and Longitude
# 631 Found Wrightwood in weather IPA, and Adding Latitude and Longitude
# 632 Found Garberville in weather IPA, and Adding Latitude and Longitude
# 633 Found Campo in weather IPA, and Adding Latitude and Longitude
# 634 Found Shandon in weather IPA, and Adding Latitude and Longitude
# 635 Found Shingletown in weather IPA, and Adding Latitude and Longitude
# 636 Found Laton in weather IPA, and Adding Latitude and Longitude
# 637 Found Del Mar in weather IPA, and Adding Latitude and Longitude
# 638 Found Durham in weather IPA, and Adding Latitude and Longitude
# 639 Found Burney in weather IPA, and Adding Latitude and Longitude
# 640 Found El Dorado in weather IPA, and Adding Latitude and Longitude
# 641 Found Lake Hughes in weather IPA, and Adding Latitude and Longitude
# 642 Found Del Rey in weather IPA, and Adding Latitude and Longitude
# 643 Found Cambrian Park in weather IPA, and Adding Latitude and Longitude
# 644 Found Emerald Lake Hills in weather IPA, and Adding Latitude and Longitude
# 645 Found Running Springs in weather IPA, and Adding Latitude and Longitude
# 646 Found Landers in weather IPA, and Adding Latitude and Longitude
# 647 Found Avalon in weather IPA, and Adding Latitude and Longitude
# 648 Found Janesville in weather IPA, and Adding Latitude and Longitude
# 649 Found Plymouth in weather IPA, and Adding Latitude and Longitude
# 650 Found Tuolumne in weather IPA, and Adding Latitude and Longitude
# 651 Found Gerber in weather IPA, and Adding Latitude and Longitude
# 652 Found Portola in weather IPA, and Adding Latitude and Longitude
# 653 Found Agua Dulce in weather IPA, and Adding Latitude and Longitude
# 654 Found Groveland in weather IPA, and Adding Latitude and Longitude
# 655 Found Ivanhoe in weather IPA, and Adding Latitude and Longitude
# 656 Found Boron in weather IPA, and Adding Latitude and Longitude
# 657 Found Ferndale in weather IPA, and Adding Latitude and Longitude
# 658 Found Aguanga in weather IPA, and Adding Latitude and Longitude
# 659 Found Cressey in weather IPA, and Adding Latitude and Longitude
# 660 Found North Fork in weather IPA, and Adding Latitude and Longitude
# 661 Found Buttonwillow in weather IPA, and Adding Latitude and Longitude
# 662 Found Farmington in weather IPA, and Adding Latitude and Longitude
# 663 Found Weaverville in weather IPA, and Adding Latitude and Longitude
# 664 Found Monte Sereno in weather IPA, and Adding Latitude and Longitude
# 665 Found Lockeford in weather IPA, and Adding Latitude and Longitude
# 666 Found Lucerne in weather IPA, and Adding Latitude and Longitude
# 667 Found Llano in weather IPA, and Adding Latitude and Longitude
# 668 Found Sunnyslope in weather IPA, and Adding Latitude and Longitude
# 669 Found Rio Dell in weather IPA, and Adding Latitude and Longitude
# 670 Found Planada in weather IPA, and Adding Latitude and Longitude
# 671 Found Moss Beach in weather IPA, and Adding Latitude and Longitude
# 672 Found Auberry in weather IPA, and Adding Latitude and Longitude
# ...
# 882 Found Dillon Beach in weather IPA, and Adding Latitude and Longitude
# 883 Found Ranchita in weather IPA, and Adding Latitude and Longitude
# 884 Found Pine Valley in weather IPA, and Adding Latitude and Longitude
# 885 Found Lakeshore in weather IPA, and Adding Latitude and Longitude
# 886 Found Hornbrook in weather IPA, and Adding Latitude and Longitude
# 887 Found Oregon House in weather IPA, and Adding Latitude and Longitude
# 888 Found Glenhaven in weather IPA, and Adding Latitude and Longitude
# 889 Found Dorris in weather IPA, and Adding Latitude and Longitude
# 890 Found Albion in weather IPA, and Adding Latitude and Longitude
# 891 Found Westmorland in weather IPA, and Adding Latitude and Longitude
# 892 Found Cantua Creek in weather IPA, and Adding Latitude and Longitude
# 893 Found Maxwell in weather IPA, and Adding Latitude and Longitude
# 894 Found Onyx in weather IPA, and Adding Latitude and Longitude
# 895 Found Green Valley Lake in weather IPA, and Adding Latitude and Longitude
# 896 Found The Sea Ranch in weather IPA, and Adding Latitude and Longitude
# 897 Found Shaver Lake in weather IPA, and Adding Latitude and Longitude
# 898 Found Applegate in weather IPA, and Adding Latitude and Longitude
# 899 Found Salyer in weather IPA, and Adding Latitude and Longitude
# 900 Found Mc Kittrick in weather IPA, and Adding Latitude and Longitude
# 901 Found Lotus in weather IPA, and Adding Latitude and Longitude
# 902 Found Sunol-Midtown in weather IPA, and Adding Latitude and Longitude
# 903 Found Catheys Valley in weather IPA, and Adding Latitude and Longitude
# 904 Found Jenner in weather IPA, and Adding Latitude and Longitude
# 905 Found Birds Landing in weather IPA, and Adding Latitude and Longitude
# 906 Found Markleeville in weather IPA, and Adding Latitude and Longitude
# 907 Found Whitethorn in weather IPA, and Adding Latitude and Longitude
# 908 Found Bass Lake in weather IPA, and Adding Latitude and Longitude
# 909 Found McArthur in weather IPA, and Adding Latitude and Longitude
# 910 Found Litchfield in weather IPA, and Adding Latitude and Longitude
# 911 Found Petrolia in weather IPA, and Adding Latitude and Longitude
# 912 Found Lewiston in weather IPA, and Adding Latitude and Longitude
# 913 Found Wendel in weather IPA, and Adding Latitude and Longitude
# 914 Found Potrero in weather IPA, and Adding Latitude and Longitude
# 915 Found Wallace in weather IPA, and Adding Latitude and Longitude
# 916 Found Inverness in weather IPA, and Adding Latitude and Longitude
# 917 Found El Nido in weather IPA, and Adding Latitude and Longitude
# 918 Found Graton in weather IPA, and Adding Latitude and Longitude
# 919 Found Hyampom in weather IPA, and Adding Latitude and Longitude
# 920 Found Old Station in weather IPA, and Adding Latitude and Longitude
# 921 Found French Gulch in weather IPA, and Adding Latitude and Longitude
# 922 Found Carnelian Bay in weather IPA, and Adding Latitude and Longitude
# 923 Found Ione in weather IPA, and Adding Latitude and Longitude
# 924 Found Lebec in weather IPA, and Adding Latitude and Longitude
# 925 Found San Ardo in weather IPA, and Adding Latitude and Longitude
# 926 Found Junction City in weather IPA, and Adding Latitude and Longitude
# 927 Found Korbel in weather IPA, and Adding Latitude and Longitude
# 928 Found Stirling City in weather IPA, and Adding Latitude and Longitude
# 929 Found Independence in weather IPA, and Adding Latitude and Longitude
# 930 Found Redcrest in weather IPA, and Adding Latitude and Longitude
# 931 Found Port Costa in weather IPA, and Adding Latitude and Longitude
# 932 Found Bangor in weather IPA, and Adding Latitude and Longitude
# 933 Found Hat Creek in weather IPA, and Adding Latitude and Longitude
# 934 Found Montgomery Creek in weather IPA, and Adding Latitude and Longitude
# 935 Found Alta in weather IPA, and Adding Latitude and Longitude
# 936 Found Ducor in weather IPA, and Adding Latitude and Longitude
# 937 Found O Neals in weather IPA, and Adding Latitude and Longitude
# 938 Found Sugarloaf in weather IPA, and Adding Latitude and Longitude
# 939 Found Strawberry in weather IPA, and Adding Latitude and Longitude
# 940 Found Bella Vista in weather IPA, and Adding Latitude and Longitude
# 941 Found San Simeon in weather IPA, and Adding Latitude and Longitude
# 942 Found Vernon in weather IPA, and Adding Latitude and Longitude
# 943 Found Vallecito in weather IPA, and Adding Latitude and Longitude
# 944 Found San Geronimo in weather IPA, and Adding Latitude and Longitude
# 945 Found Caspar in weather IPA, and Adding Latitude and Longitude
# 946 Found Gold Run in weather IPA, and Adding Latitude and Longitude
# 947 Found Montara in weather IPA, and Adding Latitude and Longitude
# 948 Found Annapolis in weather IPA, and Adding Latitude and Longitude
# 949 Found Pope Valley in weather IPA, and Adding Latitude and Longitude
# 950 Found Armona in weather IPA, and Adding Latitude and Longitude
# 951 Found Kettleman City in weather IPA, and Adding Latitude and Longitude
# 952 Found Fiddletown in weather IPA, and Adding Latitude and Longitude
# 953 Found Marshall in weather IPA, and Adding Latitude and Longitude
# 954 Found Paskenta in weather IPA, and Adding Latitude and Longitude
# 955 Found Miramonte in weather IPA, and Adding Latitude and Longitude
# 956 Found Stinson Beach in weather IPA, and Adding Latitude and Longitude
# 957 Found Sutter Creek in weather IPA, and Adding Latitude and Longitude
# 958 Found Forest Falls in weather IPA, and Adding Latitude and Longitude
# 959 Found Butte City in weather IPA, and Adding Latitude and Longitude
# 960 Found Cedarville in weather IPA, and Adding Latitude and Longitude
# 961 Found Madeline in weather IPA, and Adding Latitude and Longitude
# 962 Found Termo in weather IPA, and Adding Latitude and Longitude
# 963 Found Comptche in weather IPA, and Adding Latitude and Longitude
# 964 Found Orick in weather IPA, and Adding Latitude and Longitude
# 965 Found Burnt Ranch in weather IPA, and Adding Latitude and Longitude
# 966 Found Badger in weather IPA, and Adding Latitude and Longitude
# 967 Found Blocksburg in weather IPA, and Adding Latitude and Longitude
# 968 Found Tomales in weather IPA, and Adding Latitude and Longitude
# 969 Found Grenada in weather IPA, and Adding Latitude and Longitude
# 970 Found Camptonville in weather IPA, and Adding Latitude and Longitude
# 971 Found Bridgeville in weather IPA, and Adding Latitude and Longitude
# 972 Found Pinecrest in weather IPA, and Adding Latitude and Longitude
# 973 Found Bodega in weather IPA, and Adding Latitude and Longitude
# 974 Found Campo Seco in weather IPA, and Adding Latitude and Longitude
# 975 Found Harmony in weather IPA, and Adding Latitude and Longitude
# 976 Found Homewood in weather IPA, and Adding Latitude and Longitude
# 977 Found Taylorsville in weather IPA, and Adding Latitude and Longitude
# 978 Found Green Valley in weather IPA, and Adding Latitude and Longitude
# 979 Found Elk Creek in weather IPA, and Adding Latitude and Longitude
# 980 Found Leggett in weather IPA, and Adding Latitude and Longitude
# 981 Found Piru in weather IPA, and Adding Latitude and Longitude
# 982 Found Nubieber in weather IPA, and Adding Latitude and Longitude
# 983 Found San Gregorio in weather IPA, and Adding Latitude and Longitude
# 984 Found Chilcoot in weather IPA, and Adding Latitude and Longitude
# 985 Found Big Bar in weather IPA, and Adding Latitude and Longitude
# 986 Found Round Mountain in weather IPA, and Adding Latitude and Longitude
# 987 Found Lee Vining in weather IPA, and Adding Latitude and Longitude
# 988 Found Brooks in weather IPA, and Adding Latitude and Longitude
# 989 Found Manchester in weather IPA, and Adding Latitude and Longitude
# 990 Found Fish Camp in weather IPA, and Adding Latitude and Longitude
# 991 Found Westport in weather IPA, and Adding Latitude and Longitude
# 992 Found Vina in weather IPA, and Adding Latitude and Longitude
# 993 Found Essex in weather IPA, and Adding Latitude and Longitude
# 994 Found Canby in weather IPA, and Adding Latitude and Longitude
# 995 Found Los Alamos in weather IPA, and Adding Latitude and Longitude
# 996 Found Adin in weather IPA, and Adding Latitude and Longitude
# 997 Found Callahan in weather IPA, and Adding Latitude and Longitude
# 998 Found Fort Bidwell in weather IPA, and Adding Latitude and Longitude
# 999 Found Orleans in weather IPA, and Adding Latitude and Longitude
# 1000 Found Jacumba in weather IPA, and Adding Latitude and Longitude
# 1001 Found Paynes Creek in weather IPA, and Adding Latitude and Longitude
# 1002 Found Seiad Valley in weather IPA, and Adding Latitude and Longitude
# 1003 Found Davis Creek in weather IPA, and Adding Latitude and Longitude
# 1004 Found Big Creek in weather IPA, and Adding Latitude and Longitude
# 1005 Found Westley in weather IPA, and Adding Latitude and Longitude
# 1006 Found Valley Ford in weather IPA, and Adding Latitude and Longitude
# 1007 Found Willow Creek in weather IPA, and Adding Latitude and Longitude
# 1008 Found Graeagle in weather IPA, and Adding Latitude and Longitude
# 1009 Found Mill Creek in weather IPA, and Adding Latitude and Longitude
# 1010 Found Big Bend in weather IPA, and Adding Latitude and Longitude
# 1011 Found June Lake in weather IPA, and Adding Latitude and Longitude
# 1012 Found Manton in weather IPA, and Adding Latitude and Longitude
# 1013 Found Likely in weather IPA, and Adding Latitude and Longitude
# 1014 Found Downieville in weather IPA, and Adding Latitude and Longitude
# 1015 Found Zenia in weather IPA, and Adding Latitude and Longitude
# 1016 Found Branscomb in weather IPA, and Adding Latitude and Longitude
# 1017 Found Wilseyville in weather IPA, and Adding Latitude and Longitude
# 1018 Found Glencoe in weather IPA, and Adding Latitude and Longitude
# 1019 Found El Portal in weather IPA, and Adding Latitude and Longitude
# 1020 Found Casmalia in weather IPA, and Adding Latitude and Longitude
# 1021 Found Yermo in weather IPA, and Adding Latitude and Longitude
# 1022 Found Castella in weather IPA, and Adding Latitude and Longitude
# 1023 Found Avery in weather IPA, and Adding Latitude and Longitude
# 1024 Found Sierra City in weather IPA, and Adding Latitude and Longitude
# 1025 Found Keene in weather IPA, and Adding Latitude and Longitude
# 1026 Found Grimes in weather IPA, and Adding Latitude and Longitude
# 1027 Found Daggett in weather IPA, and Adding Latitude and Longitude
# 1028 Found Bieber in weather IPA, and Adding Latitude and Longitude
# 1029 Found New Pine Creek in weather IPA, and Adding Latitude and Longitude
# 1030 Found Clio in weather IPA, and Adding Latitude and Longitude
# 1031 Found Raisin City in weather IPA, and Adding Latitude and Longitude
# 1032 Found Lookout in weather IPA, and Adding Latitude and Longitude
# 1033 Found Nipton in weather IPA, and Adding Latitude and Longitude
# 1034 Found Forbestown in weather IPA, and Adding Latitude and Longitude
# 1035 Found Clipper Mills in weather IPA, and Adding Latitude and Longitude
# 1036 Found Dutch Flat in weather IPA, and Adding Latitude and Longitude
# 1037 Found Lemon Cove in weather IPA, and Adding Latitude and Longitude
# 1038 Found Topaz in weather IPA, and Adding Latitude and Longitude
# 1039 Found Mad River in weather IPA, and Adding Latitude and Longitude
# 1040 Found Alderpoint in weather IPA, and Adding Latitude and Longitude
# 1041 Found Standish in weather IPA, and Adding Latitude and Longitude
# 1042 Found Hornitos in weather IPA, and Adding Latitude and Longitude
# 1043 Found Olancha in weather IPA, and Adding Latitude and Longitude
# 1044 Found Woody in weather IPA, and Adding Latitude and Longitude
# 1045 Found Calpine in weather IPA, and Adding Latitude and Longitude
# 1046 Found Eagleville in weather IPA, and Adding Latitude and Longitude
# 1047 Found Milford in weather IPA, and Adding Latitude and Longitude
# 1048 Found Hume in weather IPA, and Adding Latitude and Longitude
# 1049 Found Rackerby in weather IPA, and Adding Latitude and Longitude
# 1050 Found Princeton in weather IPA, and Adding Latitude and Longitude
# 1051 Found Lake City in weather IPA, and Adding Latitude and Longitude
# 1052 Found Benton in weather IPA, and Adding Latitude and Longitude
# 1053 Found Strawberry Valley in weather IPA, and Adding Latitude and Longitude
# 1054 Found Emigrant Gap in weather IPA, and Adding Latitude and Longitude
# 1055 Found Palomar Mountain in weather IPA, and Adding Latitude and Longitude
# 1056 Found Ravendale in weather IPA, and Adding Latitude and Longitude
# 1057 Found Clements in weather IPA, and Adding Latitude and Longitude
# 1058 Found Valyermo in weather IPA, and Adding Latitude and Longitude
# 1059 Found Canyon Dam in weather IPA, and Adding Latitude and Longitude
# 1060 Found Somes Bar in weather IPA, and Adding Latitude and Longitude
# 1061 Found Beckwourth in weather IPA, and Adding Latitude and Longitude
# 1062 Found Duncans Mills in weather IPA, and Adding Latitude and Longitude
# 1063 Found Thornton in weather IPA, and Adding Latitude and Longitude
# 1064 Found Deer Park in weather IPA, and Adding Latitude and Longitude
# 1065 Found Glennville in weather IPA, and Adding Latitude and Longitude
# 1066 Found Sierraville in weather IPA, and Adding Latitude and Longitude
# 1067 Found Twain in weather IPA, and Adding Latitude and Longitude
# 1068 Found Loma Mar in weather IPA, and Adding Latitude and Longitude
# 1069 Found Elmira in weather IPA, and Adding Latitude and Longitude
# 1070 Found Crescent Mills in weather IPA, and Adding Latitude and Longitude
# 1071 Found Zamora in weather IPA, and Adding Latitude and Longitude
# 1072 Found Long Barn in weather IPA, and Adding Latitude and Longitude
# 1073 Found Fawnskin in weather IPA, and Adding Latitude and Longitude
# 1074 Found Soda Springs in weather IPA, and Adding Latitude and Longitude
# 1075 Found Kyburz in weather IPA, and Adding Latitude and Longitude
# 1076 Found Twin Bridges in weather IPA, and Adding Latitude and Longitude
# 1077 Found Echo Lake in weather IPA, and Adding Latitude and Longitude
# 1078 Found Tehama in weather IPA, and Adding Latitude and Longitude
# 1079 Found Nelson in weather IPA, and Adding Latitude and Longitude
# 1080 Found Big Oak Flat in weather IPA, and Adding Latitude and Longitude
# 1081 Found Miranda in weather IPA, and Adding Latitude and Longitude
# 1082 Found Madison in weather IPA, and Adding Latitude and Longitude
# 1083 Found Camp Meeker in weather IPA, and Adding Latitude and Longitude
# 1084 Found Bear Valley in weather IPA, and Adding Latitude and Longitude
# 1085 Found Guinda in weather IPA, and Adding Latitude and Longitude
# 1086 Found Meadow Valley in weather IPA, and Adding Latitude and Longitude
# 1087 Found Keeler in weather IPA, and Adding Latitude and Longitude
# 1088 Found Washington in weather IPA, and Adding Latitude and Longitude
# 1089 Found Little Grass Valley in weather IPA, and Adding Latitude and Longitude
# 1090 Found Shasta in weather IPA, and Adding Latitude and Longitude
# 1091 Found Biola in weather IPA, and Adding Latitude and Longitude
# 1092 Found Cassel in weather IPA, and Adding Latitude and Longitude
# 1093 Found Amador City in weather IPA, and Adding Latitude and Longitude
# 1094 Found Kirkwood in weather IPA, and Adding Latitude and Longitude
# 1095 Found San Lucas in weather IPA, and Adding Latitude and Longitude
# 1096 Found Empire in weather IPA, and Adding Latitude and Longitude
# 1097 Found Goodyears Bar in weather IPA, and Adding Latitude and Longitude
# 1098 Found River Pines in weather IPA, and Adding Latitude and Longitude
# 1099 Found McCloud in weather IPA, and Adding Latitude and Longitude
# 1100 Found Mount Baldy in weather IPA, and Adding Latitude and Longitude
# 1101 Found Mettler in weather IPA, and Adding Latitude and Longitude
# 1102 Found North Palm Springs in weather IPA, and Adding Latitude and Longitude
# 1103 Found Fields Landing in weather IPA, and Adding Latitude and Longitude
# 1104 Found Lockwood in weather IPA, and Adding Latitude and Longitude
# 1105 Found Tecopa in weather IPA, and Adding Latitude and Longitude
# 1106 Found Challenge in weather IPA, and Adding Latitude and Longitude
# 1107 Found Honeydew in weather IPA, and Adding Latitude and Longitude
# 1108 Found Darwin in weather IPA, and Adding Latitude and Longitude

# %%
#print count of cities that failed and the names
print(len(failedcity))
print((failedcity))
# Out:
# 0
# []

# %%
#Show the new DF
SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  2012-12-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    450942.0
# 8                       San Diego-Carlsbad      San Diego County    474020.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    588222.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    824245.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    174266.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County    129791.0
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 8        480412.0  ...    725853.0    727571.0    730853.0    734733.0
# 11       599714.0  ...   1020573.0   1024151.0   1027883.0   1034380.0
# 14       841667.0  ...   1505519.0   1511407.0   1519514.0   1531203.0
# 30       177728.0  ...    350842.0    353592.0    356618.0    358601.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    610914.0    613382.0    613047.0    613266.0
# 26406         NaN  ...     34627.0     34688.0     34687.0     34614.0
# 26435    130369.0  ...    211217.0    213588.0    215080.0    215313.0
# 26466         NaN  ...    672166.0    680526.0    688958.0    698685.0
# 26472         NaN  ...     48902.0     48826.0     48758.0     48704.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 8        740112.0    744208.0    748744.0    751096.0    753893.0    754223.0
# 11      1046264.0   1057397.0   1068942.0   1074703.0   1080058.0   1088749.0
# 14      1535710.0   1539101.0   1535882.0   1533941.0   1523778.0   1511653.0
# 30       360857.0    362724.0    365194.0    366583.0    366772.0    366198.0
# ...           ...         ...         ...         ...         ...         ...
# 26401    611159.0    610241.0    611718.0    615934.0    623633.0    631555.0
# 26406     34465.0     34328.0     34042.0     33631.0     33159.0     32578.0
# 26435    215703.0    214733.0    212881.0    211004.0    208809.0    205041.0
# 26466    707643.0    720505.0    733777.0    749997.0    767960.0    792172.0
# 26472     48665.0     48617.0     48550.0     48529.0     48557.0     48661.0
#
# [1108 rows x 99 columns]

# %%
#Converting column values to numbers
SingleCCal['Latitude']  = pd.to_numeric(SingleCCal['Latitude'],errors = 'coerce')
SingleCCal['Longitude']  = pd.to_numeric(SingleCCal['Longitude'],errors = 'coerce')
#Creating a DF for just Northern California
SingleNCity  = SingleCCal.loc[SingleCCal['Latitude'].gt(37)==True]
SingleNCity
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-5c47867d56cb> in <module>
#       1 #Converting column values to numbers
# ----> 2 SingleCCal['Latitude']  = pd.to_numeric(SingleCCal['Latitude'],errors = 'coerce')
#       3 SingleCCal['Longitude']  = pd.to_numeric(SingleCCal['Longitude'],errors = 'coerce')
#       4 #Creating a DF for just Northern California
#       5 SingleNCity  = SingleCCal.loc[SingleCCal['Latitude'].gt(37)==True]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'

# %%
#Declairing a function and setting 4 variable  Max and min on  Longitude and latitude 
def singlecity(latMin, latMax, lngMin, lngMax):  
    #Create a copy of the DF of fire and single city
    SingleFire = Nfire.copy()
    #create a box of latitude and longitude using the DFs
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMin))==True]
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMax))==False]

    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMin))==False]
    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMax))==True]
    
    
    SingleCity = SingleNCity.copy()
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMin))==True]
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMax))==False]

    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMin))==False]
    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMax))==True]
    #return the DF into a list
    return [SingleCity, SingleFire]

# %%
#Create a list to hold the DF MODESTO
OneSingleCity_Fire = []
#choose the Lat and Long
OneSingleCity_Fire =singlecity(37,38,-118,-120)
print(f'There are {OneSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {OneSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show
OneSingleCity_Fire[0].head()
# Out:
# There are 23 Cities
# There are 49 Fires
#       RegionID  SizeRank     RegionName RegionType StateName State   Metro  \
# 4045     23717      4214         Bishop       City        CA    CA     NaN
# 4547     44661      4747     Coarsegold       City        CA    CA  Madera
# 5074     19207      5312       Mariposa       City        CA    CA     NaN
# 5911     35858      6215  Mammoth Lakes       City        CA    CA     NaN
# 7364     13070      7798       Oakhurst       City        CA    CA  Madera
#
#            CountyName  2012-12-31  2013-01-31  ...  2019-11-30  2019-12-31  \
# 4045      Inyo County    273489.0    276950.0  ...    428489.0    427864.0
# 4547    Madera County    199369.0    201608.0  ...    303735.0    305076.0
# 5074  Mariposa County    210470.0    211974.0  ...    307772.0    307829.0
# 5911      Mono County    558224.0    564053.0  ...    785180.0    785724.0
# 7364    Madera County    210073.0    212235.0  ...    306139.0    307197.0
#
#       2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# 4045    427637.0    427227.0    426893.0    426367.0    425207.0    423626.0
# 4547    307052.0    308750.0    310050.0    311201.0    311894.0    312873.0
# 5074    307935.0    307984.0    307635.0    307033.0    306186.0    305309.0
# 5911    786616.0    787233.0    788172.0    787610.0    787095.0    784957.0
# 7364    308957.0    310308.0    311776.0    313090.0    313593.0    314633.0
#
#        Latitude   Longitude
# 4045  37.361424 -118.399664
# 4547  37.262169 -119.700983
# 5074  37.484938 -119.966284
# 5911  37.648546 -118.972079
# 7364  37.328000 -119.649315
#
# [5 rows x 101 columns]

# %%
#Create a list to hold the DF CHICO/PARADISE
TwoSingleCity_Fire = []
#choose the Lat and Long
TwoSingleCity_Fire =singlecity(39.5,40.5,-120,-122)
print(f'There are {TwoSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {TwoSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show

#cleaning the City Data
TwoCityLines = TwoSingleCity_Fire[0]
TwoCityLines = TwoCityLines[["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 
TwoCityLines = TwoCityLines.dropna(how='any')
TwoCityLines

TwoFireLines = TwoSingleCity_Fire[1]
TwoFireLines = TwoFireLines[['Name','AcresBurned','ArchiveYear','Started','Extinguished']]
TwoFireLines = TwoFireLines.dropna(how= 'any')
TwoFireLines = TwoFireLines.drop_duplicates(subset = 'Name')
TwoFireLines = TwoFireLines.sort_values(by ='AcresBurned',ascending = False)

TwoFireYears = TwoFireLines[['Name','ArchiveYear']]
TwoFireYears.head(10)
# Out:
# There are 69 Cities
# There are 110 Fires
#                              Name  ArchiveYear
# 1060                    Camp Fire         2018
# 3                   American Fire         2013
# 644   Cascade Fire (Wind Complex)         2017
# 647                 Cherokee Fire         2017
# 653   LaPorte Fire (Wind Complex)         2017
# 656                     Wall Fire         2017
# 660                  Minerva Fire         2017
# 662                Ponderosa Fire         2017
# 667                   Eureka Fire         2017
# 19                    Swedes Fire         2013

# %%
heatcity = TwoSingleCity_Fire[0]
heatcity = heatcity[['RegionName','Latitude',"Longitude"]]
heatcity
locationsheatcity = heatcity[['Latitude',"Longitude"]]

fig = gmaps.figure()
info_box_template = """
<dl>
<dt>City</dt><dd>{RegionName}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
cityinfo = [info_box_template.format(**row) for index, row in heatcity.iterrows()]
marker = gmaps.marker_layer(locationsheatcity, info_box_content = cityinfo) 
fig.add_layer(marker)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a list to hold the DF SACRAMENTO
ThreeSingleCity_Fire = []
#choose the Lat and Long
ThreeSingleCity_Fire =singlecity(38,39,-120,-122)
print(f'There are {ThreeSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {ThreeSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show
ThreeSingleCity_Fire[0].head()
# Out:
# There are 106 Cities
# There are 95 Fires
#      RegionID  SizeRank  RegionName RegionType StateName State  \
# 30      20288        30  Sacramento       City        CA    CA
# 186     17950       189   Elk Grove       City        CA    CA
# 266     13594       272   Roseville       City        CA    CA
# 358     16780       364     Antioch       City        CA    CA
# 371     41446       377   Vacaville       City        CA    CA
#
#                                    Metro           CountyName  2012-12-31  \
# 30   Sacramento--Roseville--Arden-Arcade    Sacramento County    174266.0
# 186  Sacramento--Roseville--Arden-Arcade    Sacramento County    243638.0
# 266  Sacramento--Roseville--Arden-Arcade        Placer County    293837.0
# 358        San Francisco-Oakland-Hayward  Contra Costa County    272221.0
# 371                    Vallejo-Fairfield        Solano County    244137.0
#
#      2013-01-31  ...  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 30     177728.0  ...    356618.0    358601.0    360857.0    362724.0
# 186    248550.0  ...    460534.0    462581.0    465064.0    467159.0
# 266    300274.0  ...    490782.0    492002.0    493138.0    495473.0
# 358    272365.0  ...    512845.0    514236.0    513612.0    513154.0
# 371    252125.0  ...    471950.0    472435.0    475051.0    477299.0
#
#      2020-03-31  2020-04-30  2020-05-31  2020-06-30   Latitude   Longitude
# 30     365194.0    366583.0    366772.0    366198.0  38.581572 -121.494400
# 186    469947.0    471546.0    471630.0    470570.0  38.408799 -121.371618
# 266    497482.0    499081.0    498951.0    500076.0  38.752124 -121.288006
# 358    514271.0    516565.0    515776.0    514384.0  38.004921 -121.805789
# 371    479976.0    481169.0    482998.0    484279.0  38.356577 -121.987744
#
# [5 rows x 101 columns]

# %%
#Create a list to hold the DF REDDING
FourSingleCity_Fire = []
#choose the Lat and Long
FourSingleCity_Fire =singlecity(40,41,-121,-123)
print(f'There are {FourSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {FourSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show
FourSingleCity_Fire[1]
# Out:
# There are 36 Cities
# There are 107 Fires
#                                        Name  AcresBurned  ArchiveYear  \
# 9                                 Deer Fire      11429.0         2013
# 10                              Clover Fire       8073.0         2013
# 12                             Panther Fire       6965.0         2013
# 60                                Vina Fire        200.0         2013
# 61    Burney Lightning Series (Warner Fire)        196.0         2013
# ...                                     ...          ...          ...
# 1565                            Plains Fire         42.0         2019
# 1577                           Gilbert Fire         30.0         2019
# 1578                             Ranch Fire         30.0         2019
# 1612                               Cow Fire         16.0         2019
# 1621                             Dales Fire         11.0         2019
#
#      Counties     Started Extinguished   Latitude   Longitude  Fatalities  \
# 9      Tehama  2013-08-23   2013-08-29  40.042630 -121.853970         NaN
# 10     Shasta  2013-09-09   2013-09-15  40.498332 -122.535496         NaN
# 12     Tehama  2013-05-01   2013-05-09  40.190062 -121.595555         NaN
# 60     Tehama  2013-07-04   2013-07-04  40.012398 -122.079871         NaN
# 61     Shasta  2013-08-19   2013-08-23  40.544500 -121.375400         NaN
# ...       ...         ...          ...        ...         ...         ...
# 1565   Shasta  2019-10-10   2019-10-10  40.498800 -122.199110         NaN
# 1577   Shasta  2019-08-04          nan  40.559240 -122.254090         NaN
# 1578   Shasta  2019-07-05   2019-07-06  40.417410 -122.767256         NaN
# 1612   Shasta  2019-09-24   2019-09-24  40.612556 -122.039167         NaN
# 1621   Tehama  2019-10-07   2019-10-07  40.314187 -122.070055         NaN
#
#       Injuries  StructuresDamaged  StructuresDestroyed  StructuresEvacuated  \
# 9          5.0                NaN                  NaN                  NaN
# 10         6.0               10.0                201.0                  NaN
# 12         6.0                NaN                  NaN                  NaN
# 60         NaN                NaN                  NaN                  NaN
# 61         NaN                NaN                  NaN                  NaN
# ...        ...                ...                  ...                  ...
# 1565       NaN                NaN                  NaN                  NaN
# 1577       NaN                NaN                  NaN                  NaN
# 1578       NaN                NaN                  NaN                  NaN
# 1612       NaN                NaN                  NaN                  NaN
# 1621       NaN                NaN                  NaN                  NaN
#
#       StructuresThreatened                                           Location
# 9                      NaN    Near Deer Creek, 12 miles east of Los Molinos.
# 10                     NaN    Community of Igo, 10 miles southwest of Redding
# 12                     NaN     140K3 Line, 8 miles northwest of Butte Meadows
# 60                     NaN         Tehama-Vina Rd and Sherman Rd, Los Molinos
# 61                     NaN                Fall River Mills and McAruther area
# ...                    ...                                                ...
# 1565                   NaN  Millville Plains Road and Sprig Road in Millville
# 1577                   NaN  Highway 44 and Gilbert Drive, Palo Cedro, East...
# 1578                   NaN         Near Yolla Bolla Rd & Roaring Creek in Igo
# 1612                   NaN  at Whitmore Road and Cow Creek Ranch Road in M...
# 1621                   NaN  Highway 36E east of Dales Station and Manton Road
#
# [107 rows x 15 columns]

# %%
TwoCityLine = TwoCityLine[["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 

TwoCityLine = TwoCityLine.set_index('RegionName')
TwoCityLine = TwoCityLine.T
TwoCityLine

TwoCityLine.plot()
TwoCityLine.plot(figsize=(50,50))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-fa3040cb18ce> in <module>
# ----> 1 TwoCityLine = TwoCityLine[["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']]
#       2
#       3 TwoCityLine = TwoCityLine.set_index('RegionName')
#       4 TwoCityLine = TwoCityLine.T
#       5 TwoCityLine
#
# NameError: name 'TwoCityLine' is not defined

# %%
TwoLine
# Out:
# RegionName     Chico  Yuba City  Oroville  Grass Valley  Marysville  \
# 2012-12-31  254203.0   190512.0  124950.0      255690.0    158156.0
# 2013-01-31  256077.0   192615.0  126492.0      255281.0    159857.0
# 2013-02-28  258285.0   194850.0  128336.0      256884.0    161648.0
# 2013-03-31  261401.0   196972.0  130940.0      261268.0    163499.0
# 2013-04-30  266180.0   199407.0  133652.0      267587.0    165570.0
# ...              ...        ...       ...           ...         ...
# 2020-02-29  403508.0   326154.0  254228.0      427430.0    278375.0
# 2020-03-31  399562.0   328499.0  251759.0      426706.0    280133.0
# 2020-04-30  397298.0   331182.0  250033.0      425071.0    281482.0
# 2020-05-31  395221.0   334072.0  248549.0      424166.0    282833.0
# 2020-06-30  392400.0   335017.0  246958.0      425820.0    283845.0
#
# RegionName  Olivehurst  Paradise  Nevada City   Truckee   Gridley  ...  \
# 2012-12-31    162085.0  183582.0     307155.0  469610.0  116982.0  ...
# 2013-01-31    163933.0  184916.0     304818.0  472895.0  117592.0  ...
# 2013-02-28    165890.0  186184.0     305192.0  478350.0  118705.0  ...
# 2013-03-31    167953.0  188274.0     309475.0  486722.0  120911.0  ...
# 2013-04-30    170077.0  191329.0     316624.0  495293.0  123359.0  ...
# ...                ...       ...          ...       ...       ...  ...
# 2020-02-29    295185.0  295738.0     471906.0  695126.0  261456.0  ...
# 2020-03-31    297054.0  290497.0     471217.0  694173.0  260617.0  ...
# 2020-04-30    298460.0  286170.0     469423.0  690985.0  261047.0  ...
# 2020-05-31    299908.0  282288.0     468105.0  688601.0  261569.0  ...
# 2020-06-30    301199.0  279111.0     469688.0  690602.0  262281.0  ...
#
# RegionName  Emigrant Gap  Beckwourth  Sierraville  Soda Springs    Nelson  \
# 2012-12-31      217522.0    200259.0     215125.0      427845.0       NaN
# 2013-01-31      216390.0    202450.0     215408.0      431492.0       NaN
# 2013-02-28      218638.0    205245.0     216050.0      438119.0       NaN
# 2013-03-31      223283.0    208258.0     217592.0      442729.0       NaN
# 2013-04-30      227963.0    210049.0     220178.0      445197.0       NaN
# ...                  ...         ...          ...           ...       ...
# 2020-02-29      365704.0    259837.0     286821.0      563272.0  300904.0
# 2020-03-31      363857.0    259830.0     288119.0      563869.0  295249.0
# 2020-04-30      359180.0    258918.0     290010.0      561747.0  286970.0
# 2020-05-31      352261.0    257197.0     292471.0      559858.0  277520.0
# 2020-06-30      344591.0    254743.0     295125.0      558444.0  267473.0
#
# RegionName  Meadow Valley  Washington  Little Grass Valley  Goodyears Bar  \
# 2012-12-31       181620.0    230831.0             168952.0            NaN
# 2013-01-31       181667.0    230975.0             170867.0            NaN
# 2013-02-28       182243.0    230941.0             173116.0            NaN
# 2013-03-31       183185.0    231690.0             175509.0            NaN
# 2013-04-30       186078.0    234821.0             177989.0            NaN
# ...                   ...         ...                  ...            ...
# 2020-02-29       235697.0    340541.0             271702.0       258134.0
# 2020-03-31       234440.0    337231.0             271010.0       259356.0
# 2020-04-30       233786.0    334324.0             271515.0       260206.0
# 2020-05-31       232806.0    331845.0             271721.0       260661.0
# 2020-06-30       231668.0    332395.0             271183.0       261569.0
#
# RegionName  Challenge
# 2012-12-31   129791.0
# 2013-01-31   130369.0
# 2013-02-28   132133.0
# 2013-03-31   133861.0
# 2013-04-30   134329.0
# ...               ...
# 2020-02-29   214733.0
# 2020-03-31   212881.0
# 2020-04-30   211004.0
# 2020-05-31   208809.0
# 2020-06-30   205041.0
#
# [91 rows x 69 columns]
