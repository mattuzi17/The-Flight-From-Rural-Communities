# %%
#import all libraries needed 
import os
import pandas as pd

# from api_keys import wkey
from api_keys import gkey
import gmaps
import gmaps.datasets
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress

from ipywidgets.embed import embed_minimal_html

# %%
#Get Path to get to the Datasets
firepath = os.path.join('Data Sets', 'California_Fire_Incidents.csv')
singlepath = os.path.join('Data Sets','City_zhvi_single_family.csv')

#read the files 
fire = pd.read_csv(firepath)
singlecity = pd.read_csv(singlepath)

# %% [markdown]
# # Cleaning Data Sets

# %%
#Collecting only the columns we want from Fire dataset 
clfire = fire[['Name','AcresBurned','ArchiveYear','Counties','Started','Extinguished', 'Latitude',
       'Longitude','Fatalities','Injuries','StructuresDamaged', 'StructuresDestroyed',
       'StructuresEvacuated', 'StructuresThreatened','Location', 'CanonicalUrl']]
#sort the columns by Acres Burned
clfire.sort_values(by ='AcresBurned',ascending = False)
# Out:
#                                 Name  AcresBurned  ArchiveYear     Counties  \
# 1055  Ranch Fire (Mendocino Complex)     410203.0         2018        Glenn
# 1054  Ranch Fire (Mendocino Complex)     410203.0         2018       Colusa
# 1056  Ranch Fire (Mendocino Complex)     410203.0         2018         Lake
# 1057  Ranch Fire (Mendocino Complex)     410203.0         2018    Mendocino
# 617                      Thomas Fire     281893.0         2017      Ventura
# ...                              ...          ...          ...          ...
# 1043                Rattlesnake Fire          0.0         2017     Mariposa
# 613                         Old Fire          0.0         2016  Los Angeles
# 1633                     Cashe Fire           NaN         2019         Yolo
# 1634                        Oak Fire          NaN         2019    San Diego
# 1635                   Johnson Fire           NaN         2019    Riverside
#
#                    Started          Extinguished   Latitude   Longitude  \
# 1055  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1054  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1056  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 1057  2018-07-27T12:05:00Z  2019-01-04T09:33:00Z  39.243283 -123.103367
# 617   2017-12-04T18:28:00Z  2019-03-14T11:24:00Z  34.415210 -119.091240
# ...                    ...                   ...        ...         ...
# 1043  2017-09-07T15:00:00Z  2018-01-09T13:19:00Z  37.735960 -119.782560
# 613   2016-06-04T16:09:00Z  2016-06-13T12:30:00Z   0.000000    0.000000
# 1633  2019-11-25T12:02:02Z                   NaN  38.734634 -121.729691
# 1634  2019-10-22T19:20:44Z                   NaN  33.351145 -117.403719
# 1635  2019-10-14T15:32:20Z                   NaN  33.451480 -116.058980
#
#       Fatalities  Injuries  StructuresDamaged  StructuresDestroyed  \
# 1055         1.0       3.0                NaN                246.0
# 1054         1.0       3.0                NaN                246.0
# 1056         1.0       3.0                NaN                246.0
# 1057         1.0       3.0                NaN                246.0
# 617          NaN       NaN              280.0               1063.0
# ...          ...       ...                ...                  ...
# 1043         NaN       NaN                NaN                  NaN
# 613          NaN       NaN                NaN                  NaN
# 1633         NaN       NaN                NaN                  NaN
# 1634         NaN       NaN                NaN                  NaN
# 1635         NaN       NaN                NaN                  NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 1055                  NaN                1050.0
# 1054                  NaN                1050.0
# 1056                  NaN                1050.0
# 1057                  NaN                1050.0
# 617                   NaN                   NaN
# ...                   ...                   ...
# 1043                  NaN                   NaN
# 613                   NaN                   NaN
# 1633                  NaN                   NaN
# 1634                  NaN                   NaN
# 1635                  NaN                   NaN
#
#                                                Location  \
# 1055  off Highway 20 near Potter Valley, northeast o...
# 1054  off Highway 20 near Potter Valley, northeast o...
# 1056  off Highway 20 near Potter Valley, northeast o...
# 1057  off Highway 20 near Potter Valley, northeast o...
# 617          Hwy 150 and Hwy 126, north of Santa Paula
# ...                                                 ...
# 1043         Hwy 120 and Big Oak Flat Road near Foresta
# 613   off of Old Topanga Canyon Road and Mulholland ...
# 1633  County Road 102 and County Road 17, North of W...
# 1634  Near Basilone Road and Las Pulgas Road, near C...
# 1635                          Johnson Street and Ave 82
#
#                                            CanonicalUrl
# 1055  /incidents/2018/7/27/ranch-fire-mendocino-comp...
# 1054  /incidents/2018/7/27/ranch-fire-mendocino-comp...
# 1056  /incidents/2018/7/27/ranch-fire-mendocino-comp...
# 1057  /incidents/2018/7/27/ranch-fire-mendocino-comp...
# 617                   /incidents/2017/12/4/thomas-fire/
# ...                                                 ...
# 1043              /incidents/2017/9/7/rattlesnake-fire/
# 613                       /incidents/2016/6/4/old-fire/
# 1633                  /incidents/2019/11/25/cashe-fire/
# 1634                    /incidents/2019/10/22/oak-fire/
# 1635                /incidents/2019/10/14/johnson-fire/
#
# [1636 rows x 16 columns]

# %%
#Graph 5 
fires_dropped = clfire.drop_duplicates(subset=['CanonicalUrl'])
graph_df = fires_dropped.groupby(["ArchiveYear"]).sum()
graph5_df = graph_df[["AcresBurned"]]

graph5_df
graph5_df.plot.bar(y = "AcresBurned", figsize = (7,5), title = "California Wildfires 2013-2019")
plt.savefig('CaliforniaAcresBurned.png')
plt.show()

# %%
#selecting the columns we want from Singles homes city Zillow Data set
clsinglecity = singlecity[["RegionID","SizeRank","RegionName","RegionType","StateName","State","Metro","CountyName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 

clsinglecity
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 26492     51821     29449  Eastabuchie       City        MS    MS
# 26493    232607     29449         Dean       City        TX    TX
# 26494      6638     29449      Pulaski       City        GA    GA
# 26495     33089     29449    New Paris       City        PA    PA
# 26496     11693     30967  Great Lakes       City        IL    IL
#
#                                   Metro          CountyName  2012-12-31  \
# 0           New York-Newark-Jersey City       Queens County    456770.0
# 1        Los Angeles-Long Beach-Anaheim  Los Angeles County    450942.0
# 2      Houston-The Woodlands-Sugar Land       Harris County    123220.0
# 3              Chicago-Naperville-Elgin         Cook County    157394.0
# 4             San Antonio-New Braunfels        Bexar County    125317.0
# ...                                 ...                 ...         ...
# 26492                            Laurel        Jones County     64854.0
# 26493                     Wichita Falls         Clay County    124149.0
# 26494                               NaN      Candler County     63066.0
# 26495                               NaN      Bedford County         NaN
# 26496          Chicago-Naperville-Elgin         Cook County    249843.0
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 0        457813.0  ...    672936.0    672209.0    671450.0    671253.0
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 2        124046.0  ...    192561.0    193168.0    193616.0    194133.0
# 3        158940.0  ...    228316.0    228191.0    228145.0    228217.0
# 4        126125.0  ...    186918.0    187543.0    188271.0    188410.0
# ...           ...  ...         ...         ...         ...         ...
# 26492     65194.0  ...     81352.0     81091.0     81224.0     81612.0
# 26493    124473.0  ...    181453.0    181941.0    182497.0    182893.0
# 26494     63485.0  ...     97205.0     97299.0     97627.0     97836.0
# 26495         NaN  ...    151755.0    152421.0    153723.0    154705.0
# 26496    248164.0  ...    270495.0    269721.0    269156.0    267781.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 0        671526.0    671719.0    671601.0    672261.0    672389.0    673213.0
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 2        194270.0    194724.0    195586.0    196630.0    197445.0    197941.0
# 3        228561.0    229004.0    229648.0    230000.0    230383.0    230957.0
# 4        188913.0    189028.0    189564.0    189684.0    189929.0    190068.0
# ...           ...         ...         ...         ...         ...         ...
# 26492     82230.0     83016.0     83265.0     83905.0     84212.0     84165.0
# 26493    183317.0    183288.0    183121.0    182587.0    181882.0    181599.0
# 26494     98273.0     98746.0     99501.0    100522.0    101658.0    102356.0
# 26495    155025.0    155328.0    155871.0    156029.0    155906.0    154597.0
# 26496    267119.0    266509.0    264543.0    261258.0    260245.0    260579.0
#
# [26497 rows x 99 columns]

# %%
#Grabbing fires in Northern California only
Nfire = clfire.loc[clfire['Latitude'].gt(37)==True]
Nfire.sort_values(by ='AcresBurned',ascending = False)
Nfire = pd.DataFrame(Nfire)
Nfire['Extinguished'] = Nfire['Extinguished'].astype(str)
Nfire = pd.DataFrame(Nfire)

#Standardizing the Started Data by getting rid of the time 
for index, row in Nfire.iterrows():
    start= row[4]
    finish = row[5]
    Nfire.loc[index,'Started'] = start.split("T")[0]
    Nfire.loc[index,'Extinguished'] = finish.split('T')[0]

    
#Standardizing the Started Data  by converting the Date format to match that of the City Data Year-Month-Day(number of days in month)
for index, row in Nfire.iterrows():
    date =""
    month = row[4].split('-')[1]
    year = row[4].split('-')[0]
    if month == "01" or month == "03" or month == "05" or month == "07"or month == "08"or  month == "10" or month == "12":
        Nfire.loc[index,'Started'] = f"{year}-{month}-31"
    elif month == "04" or month == "06" or month == "09" or month == "11":
        Nfire.loc[index,'Started'] = f"{year}-{month}-30"
    elif month == "02" :
        Nfire.loc[index,'Started'] = f"{year}-{month}-28"

Nfire
# Out:
#                       Name  AcresBurned  ArchiveYear  Counties     Started  \
# 0                 Rim Fire     257314.0         2013  Tuolumne  2013-08-31
# 3            American Fire      27440.0         2013    Placer  2013-08-31
# 5               Aspen Fire      22992.0         2013    Fresno  2013-07-31
# 7     Salmon River Complex      14754.0         2013  Siskiyou  2013-07-31
# 8           Corral Complex      12503.0         2013  Humboldt  2013-08-31
# ...                    ...          ...          ...       ...         ...
# 1628            Moms Fire          10.0         2019     Butte  2019-07-31
# 1629         IronGate Fire         10.0         2019  Siskiyou  2019-06-30
# 1630             Cana Fire         10.0         2019     Butte  2019-04-30
# 1632             Long Fire          2.0         2019    Nevada  2019-06-30
# 1633           Cashe Fire           NaN         2019      Yolo  2019-11-30
#
#      Extinguished   Latitude   Longitude  Fatalities  Injuries  \
# 0      2013-09-06  37.857000 -120.086000         NaN       NaN
# 3      2013-08-30  39.120000 -120.650000         NaN       NaN
# 5      2013-09-24  37.279000 -119.318000         NaN       NaN
# 7      2013-08-31  41.320000 -123.176000         NaN       NaN
# 8      2013-08-12  41.035000 -123.488000         NaN       NaN
# ...           ...        ...         ...         ...       ...
# 1628          nan  39.423833 -121.579738         NaN       NaN
# 1629   2019-06-21  41.946220 -122.401570         NaN       NaN
# 1630   2019-05-08  39.839580 -121.957000         NaN       NaN
# 1632   2019-06-28  39.409722 -121.000556         NaN       NaN
# 1633          nan  38.734634 -121.729691         NaN       NaN
#
#       StructuresDamaged  StructuresDestroyed  StructuresEvacuated  \
# 0                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 5                   NaN                  NaN                  NaN
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 1628                NaN                  NaN                  NaN
# 1629                NaN                  NaN                  NaN
# 1630                NaN                  NaN                  NaN
# 1632                NaN                  NaN                  NaN
# 1633                NaN                  NaN                  NaN
#
#       StructuresThreatened                                           Location  \
# 0                      NaN            3 miles east of Groveland along Hwy 120
# 3                      NaN            Deadwood Ridge, northeast of Foresthill
# 5                      NaN                     Seven miles north of Big Creek
# 7                      NaN  North Fork of the Salmon River, West of Sawyer...
# 8                      NaN   Tish Tang Ridge east of Hoopa Valley Reservation
# ...                    ...                                                ...
# 1628                   NaN  Off Moms Lane and Lone Tree Road, South of Orv...
# 1629                   NaN         Deer Run Road, east of Iron Gate Reservoir
# 1630                   NaN  Off Hamilton Nord Cana Hwy & Cana Hwy, northea...
# 1632                   NaN  Off of  Long Point Road and Old Mill Road, Sou...
# 1633                   NaN  County Road 102 and County Road 17, North of W...
#
#                                     CanonicalUrl
# 0                 /incidents/2013/8/17/rim-fire/
# 3            /incidents/2013/8/10/american-fire/
# 5               /incidents/2013/7/22/aspen-fire/
# 7     /incidents/2013/7/31/salmon-river-complex/
# 8           /incidents/2013/8/10/corral-complex/
# ...                                          ...
# 1628             /incidents/2019/7/23/moms-fire/
# 1629         /incidents/2019/6/16/irongate-fire/
# 1630             /incidents/2019/4/30/cana-fire/
# 1632             /incidents/2019/6/28/long-fire/
# 1633           /incidents/2019/11/25/cashe-fire/
#
# [844 rows x 16 columns]

# %%
#using only the cities in California
SingleCCal = clsinglecity.loc[clsinglecity['StateName'] =='CA']
SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  2012-12-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    450942.0
# 8                       San Diego-Carlsbad      San Diego County    474020.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    588222.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    824245.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    174266.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County    129791.0
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        2013-01-31  ...  2019-09-30  2019-10-31  2019-11-30  2019-12-31  \
# 1        456335.0  ...    759513.0    763224.0    766002.0    770182.0
# 8        480412.0  ...    725853.0    727571.0    730853.0    734733.0
# 11       599714.0  ...   1020573.0   1024151.0   1027883.0   1034380.0
# 14       841667.0  ...   1505519.0   1511407.0   1519514.0   1531203.0
# 30       177728.0  ...    350842.0    353592.0    356618.0    358601.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    610914.0    613382.0    613047.0    613266.0
# 26406         NaN  ...     34627.0     34688.0     34687.0     34614.0
# 26435    130369.0  ...    211217.0    213588.0    215080.0    215313.0
# 26466         NaN  ...    672166.0    680526.0    688958.0    698685.0
# 26472         NaN  ...     48902.0     48826.0     48758.0     48704.0
#
#        2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30
# 1        774078.0    780205.0    785793.0    789989.0    790037.0    788920.0
# 8        740112.0    744208.0    748744.0    751096.0    753893.0    754223.0
# 11      1046264.0   1057397.0   1068942.0   1074703.0   1080058.0   1088749.0
# 14      1535710.0   1539101.0   1535882.0   1533941.0   1523778.0   1511653.0
# 30       360857.0    362724.0    365194.0    366583.0    366772.0    366198.0
# ...           ...         ...         ...         ...         ...         ...
# 26401    611159.0    610241.0    611718.0    615934.0    623633.0    631555.0
# 26406     34465.0     34328.0     34042.0     33631.0     33159.0     32578.0
# 26435    215703.0    214733.0    212881.0    211004.0    208809.0    205041.0
# 26466    707643.0    720505.0    733777.0    749997.0    767960.0    792172.0
# 26472     48665.0     48617.0     48550.0     48529.0     48557.0     48661.0
#
# [1108 rows x 99 columns]

# %%
county_unique = SingleCCal.CountyName.unique()
county_unique
# Out:
# array(['Los Angeles County', 'San Diego County', 'Santa Clara County',
#        'San Francisco County', 'Sacramento County', 'Fresno County',
#        'Alameda County', 'Riverside County', 'Kern County',
#        'Orange County', 'San Joaquin County', 'Stanislaus County',
#        'San Bernardino County', 'Sonoma County', 'Ventura County',
#        'Monterey County', 'Tulare County', 'Santa Barbara County',
#        'Contra Costa County', 'Placer County', 'Solano County',
#        'Butte County', 'Shasta County', 'Madera County',
#        'San Mateo County', 'Merced County', 'Santa Cruz County',
#        'Napa County', 'Marin County', 'Sutter County', 'Yolo County',
#        'Kings County', 'San Luis Obispo County', 'Imperial County',
#        'San Benito County', 'Humboldt County', 'Nevada County',
#        'El Dorado County', 'Yuba County', 'Mendocino County',
#        'Tehama County', 'Tuolumne County', 'Lassen County',
#        'Del Norte County', 'Glenn County', 'Lake County', 'Inyo County',
#        'Calaveras County', 'Mariposa County', 'Siskiyou County',
#        'Mono County', 'Colusa County', 'Amador County', 'Plumas County',
#        'Modoc County', 'Trinity County', 'Sierra County', 'Alpine County'],
#       dtype=object)

# %%
rural_county_list = ["Alpine County", "Amador County", "Calaveras County", "Colusa County", "Glenn County", "Humboldt County", "Inyo County", " Lake County", " Lassen County", "Mariposa County", "Mendocino County", "Modoc County", "Mono County", "Nevada County", "Plumas County","Del Norte County", "Sierra County","Siskiyou County", "Tehama County", "Trinity County", "Tuolumne County"]

rural_df = SingleCCal[SingleCCal.CountyName.isin(rural_county_list)]


rural_df2 = rural_df.drop(columns=['RegionID', 'SizeRank'])

rural_df2.mean().plot.line(figsize = (10,5), title = "Rural California - Mean Single Home Value Index")

plt.savefig('RuralCalSingleHomeValues.png')
plt.show()

# %%
rural_county_list = ["Alpine County", "Amador County", "Calaveras County", "Colusa County", "Glenn County", "Humboldt County", "Inyo County", " Lake County", " Lassen County", "Mariposa County", "Mendocino County", "Modoc County", "Mono County", "Nevada County", "Plumas County","Del Norte County", "Sierra County","Siskiyou County", "Tehama County", "Trinity County", "Tuolumne County"]

metro_df = SingleCCal[~SingleCCal.CountyName.isin(rural_county_list)]


metro_df2 = metro_df.drop(columns=['RegionID', 'SizeRank'])

metro_df2.mean().plot.line(figsize = (10,5), title = "Metro California - Mean Single Home Value Index")
plt.savefig('MetroCalSingleHomeValues.png')
plt.show()

# %%
#retrieving a list of the city names from the Single family owned homes
Single_City_Cal_List = SingleCCal['RegionName']
Single_City_Cal_List
# Out:
# 1          Los Angeles
# 8            San Diego
# 11            San Jose
# 14       San Francisco
# 30          Sacramento
#              ...
# 26401         Lockwood
# 26406           Tecopa
# 26435        Challenge
# 26466         Honeydew
# 26472           Darwin
# Name: RegionName, Length: 1108, dtype: object

# %%
##HIGHLIGHT THIS -NATHAN-
#Creating lata and lng columns in the Single Family owned homes
SingleCCal['Latitude'] = ""
SingleCCal['Longitude'] =""
#creating lists to store the data of failed cities 
failedindex = []
failedcity = []
Lcounter = 0
SingleCCal = pd.DataFrame(SingleCCal)
#create a for loop to find the lat and lng of the cities 
for index, row in SingleCCal.iterrows():
    #connect to the Weather API to get latitude and longitude for the cities 
    target_city = f"{row[2]}, {row[7]}, California"
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
    gapi = requests.get(target_url)
    gapi
    Lcounter +=1

    #create a try and fail to not break the code if the information isnt found
    try:
        #grabbing the data from the API and loading it onto the DF
        SingleCCal.loc[index,'Longitude'] = gapi.json()["results"][0]["geometry"]["location"]["lng"]
        SingleCCal.loc[index,'Latitude']  = gapi.json()["results"][0]["geometry"]["location"]["lat"]
        #print successful
        print(f'{Lcounter} Found {row[2]} in Google IPA, and Adding Latitude and Longitude')
    except:
        #print Failure
        print(f'{Lcounter} Failed at finding Latitude and Longitude for {row[2]}')
        #store city information
        failedcity.append(row[2])
        failedindex.append(index)
# Out:
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Lenny Ovo\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 1 Found Los Angeles in Google IPA, and Adding Latitude and Longitude
# 2 Found San Diego in Google IPA, and Adding Latitude and Longitude
# 3 Found San Jose in Google IPA, and Adding Latitude and Longitude
# 4 Found San Francisco in Google IPA, and Adding Latitude and Longitude
# 5 Found Sacramento in Google IPA, and Adding Latitude and Longitude
# 6 Found Fresno in Google IPA, and Adding Latitude and Longitude
# 7 Found Long Beach in Google IPA, and Adding Latitude and Longitude
# 8 Found Oakland in Google IPA, and Adding Latitude and Longitude
# 9 Found Riverside in Google IPA, and Adding Latitude and Longitude
# 10 Found Bakersfield in Google IPA, and Adding Latitude and Longitude
# 11 Found Anaheim in Google IPA, and Adding Latitude and Longitude
# 12 Found Santa Ana in Google IPA, and Adding Latitude and Longitude
# 13 Found Stockton in Google IPA, and Adding Latitude and Longitude
# 14 Found Modesto in Google IPA, and Adding Latitude and Longitude
# 15 Found San Bernardino in Google IPA, and Adding Latitude and Longitude
# 16 Found Chula Vista in Google IPA, and Adding Latitude and Longitude
# 17 Found Irvine in Google IPA, and Adding Latitude and Longitude
# 18 Found Fremont in Google IPA, and Adding Latitude and Longitude
# 19 Found Santa Clarita in Google IPA, and Adding Latitude and Longitude
# 20 Found Fontana in Google IPA, and Adding Latitude and Longitude
# 21 Found Santa Rosa in Google IPA, and Adding Latitude and Longitude
# 22 Found Oxnard in Google IPA, and Adding Latitude and Longitude
# 23 Found Corona in Google IPA, and Adding Latitude and Longitude
# 24 Found Oceanside in Google IPA, and Adding Latitude and Longitude
# 25 Found Glendale in Google IPA, and Adding Latitude and Longitude
# 26 Found Moreno Valley in Google IPA, and Adding Latitude and Longitude
# 27 Found Huntington Beach in Google IPA, and Adding Latitude and Longitude
# 28 Found Salinas in Google IPA, and Adding Latitude and Longitude
# 29 Found Hayward in Google IPA, and Adding Latitude and Longitude
# 30 Found Lancaster in Google IPA, and Adding Latitude and Longitude
# 31 Found Garden Grove in Google IPA, and Adding Latitude and Longitude
# 32 Found Escondido in Google IPA, and Adding Latitude and Longitude
# 33 Found Ontario in Google IPA, and Adding Latitude and Longitude
# 34 Found Rancho Cucamonga in Google IPA, and Adding Latitude and Longitude
# 35 Found Palmdale in Google IPA, and Adding Latitude and Longitude
# 36 Found El Cajon in Google IPA, and Adding Latitude and Longitude
# 37 Found Elk Grove in Google IPA, and Adding Latitude and Longitude
# 38 Found Pomona in Google IPA, and Adding Latitude and Longitude
# 39 Found Visalia in Google IPA, and Adding Latitude and Longitude
# 40 Found Whittier in Google IPA, and Adding Latitude and Longitude
# 41 Found Sunnyvale in Google IPA, and Adding Latitude and Longitude
# 42 Found Pasadena in Google IPA, and Adding Latitude and Longitude
# 43 Found Santa Maria in Google IPA, and Adding Latitude and Longitude
# 44 Found Torrance in Google IPA, and Adding Latitude and Longitude
# 45 Found Fullerton in Google IPA, and Adding Latitude and Longitude
# 46 Found Orange in Google IPA, and Adding Latitude and Longitude
# 47 Found Compton in Google IPA, and Adding Latitude and Longitude
# 48 Found Inglewood in Google IPA, and Adding Latitude and Longitude
# 49 Found Concord in Google IPA, and Adding Latitude and Longitude
# 50 Found Thousand Oaks in Google IPA, and Adding Latitude and Longitude
# 51 Found Victorville in Google IPA, and Adding Latitude and Longitude
# 52 Found Roseville in Google IPA, and Adding Latitude and Longitude
# 53 Found Simi Valley in Google IPA, and Adding Latitude and Longitude
# 54 Found Murrieta in Google IPA, and Adding Latitude and Longitude
# 55 Found Temecula in Google IPA, and Adding Latitude and Longitude
# 56 Found Hemet in Google IPA, and Adding Latitude and Longitude
# 57 Found East Los Angeles in Google IPA, and Adding Latitude and Longitude
# 58 Found Vallejo in Google IPA, and Adding Latitude and Longitude
# 59 Found Santa Clara in Google IPA, and Adding Latitude and Longitude
# 60 Found Berkeley in Google IPA, and Adding Latitude and Longitude
# 61 Found Clovis in Google IPA, and Adding Latitude and Longitude
# 62 Found Vista in Google IPA, and Adding Latitude and Longitude
# 63 Found Richmond in Google IPA, and Adding Latitude and Longitude
# 64 Found Costa Mesa in Google IPA, and Adding Latitude and Longitude
# 65 Found El Monte in Google IPA, and Adding Latitude and Longitude
# 66 Found Chico in Google IPA, and Adding Latitude and Longitude
# 67 Found Downey in Google IPA, and Adding Latitude and Longitude
# 68 Found Tracy in Google IPA, and Adding Latitude and Longitude
# 69 Found Ventura in Google IPA, and Adding Latitude and Longitude
# 70 Found West Covina in Google IPA, and Adding Latitude and Longitude
# 71 Found Redding in Google IPA, and Adding Latitude and Longitude
# 72 Found Carlsbad in Google IPA, and Adding Latitude and Longitude
# 73 Found Santa Barbara in Google IPA, and Adding Latitude and Longitude
# 74 Found Norwalk in Google IPA, and Adding Latitude and Longitude
# 75 Found Antioch in Google IPA, and Adding Latitude and Longitude
# 76 Found Perris in Google IPA, and Adding Latitude and Longitude
# 77 Found Fairfield in Google IPA, and Adding Latitude and Longitude
# 78 Found San Leandro in Google IPA, and Adding Latitude and Longitude
# 79 Found Burbank in Google IPA, and Adding Latitude and Longitude
# 80 Found Vacaville in Google IPA, and Adding Latitude and Longitude
# 81 Found Madera in Google IPA, and Adding Latitude and Longitude
# 82 Found Hesperia in Google IPA, and Adding Latitude and Longitude
# 83 Found San Mateo in Google IPA, and Adding Latitude and Longitude
# 84 Found Merced in Google IPA, and Adding Latitude and Longitude
# 85 Found Santa Cruz in Google IPA, and Adding Latitude and Longitude
# 86 Found Daly City in Google IPA, and Adding Latitude and Longitude
# 87 Found Rialto in Google IPA, and Adding Latitude and Longitude
# 88 Found Napa in Google IPA, and Adding Latitude and Longitude
# 89 Found Mission Viejo in Google IPA, and Adding Latitude and Longitude
# 90 Found Livermore in Google IPA, and Adding Latitude and Longitude
# 91 Found South Gate in Google IPA, and Adding Latitude and Longitude
# 92 Found Hawthorne in Google IPA, and Adding Latitude and Longitude
# 93 Found Indio in Google IPA, and Adding Latitude and Longitude
# 94 Found Santa Monica in Google IPA, and Adding Latitude and Longitude
# 95 Found Westminster in Google IPA, and Adding Latitude and Longitude
# 96 Found Menifee in Google IPA, and Adding Latitude and Longitude
# 97 Found San Marcos in Google IPA, and Adding Latitude and Longitude
# 98 Found Chino in Google IPA, and Adding Latitude and Longitude
# 99 Found Redwood City in Google IPA, and Adding Latitude and Longitude
# 100 Found Pittsburg in Google IPA, and Adding Latitude and Longitude
# 101 Found Newport Beach in Google IPA, and Adding Latitude and Longitude
# 102 Found Arden-Arcade in Google IPA, and Adding Latitude and Longitude
# 103 Found Tustin in Google IPA, and Adding Latitude and Longitude
# 104 Found Citrus Heights in Google IPA, and Adding Latitude and Longitude
# 105 Found Walnut Creek in Google IPA, and Adding Latitude and Longitude
# 106 Found Buena Park in Google IPA, and Adding Latitude and Longitude
# 107 Found Alhambra in Google IPA, and Adding Latitude and Longitude
# 108 Found Watsonville in Google IPA, and Adding Latitude and Longitude
# 109 Found Manteca in Google IPA, and Adding Latitude and Longitude
# 110 Found Camarillo in Google IPA, and Adding Latitude and Longitude
# 111 Found Apple Valley in Google IPA, and Adding Latitude and Longitude
# 112 Found Lakewood in Google IPA, and Adding Latitude and Longitude
# 113 Found Covina in Google IPA, and Adding Latitude and Longitude
# 114 Found Upland in Google IPA, and Adding Latitude and Longitude
# 115 Found Carson in Google IPA, and Adding Latitude and Longitude
# 116 Found Porterville in Google IPA, and Adding Latitude and Longitude
# 117 Found Mountain View in Google IPA, and Adding Latitude and Longitude
# 118 Found Turlock in Google IPA, and Adding Latitude and Longitude
# 119 Found Bellflower in Google IPA, and Adding Latitude and Longitude
# 120 Found Lodi in Google IPA, and Adding Latitude and Longitude
# 121 Found Rancho Cordova in Google IPA, and Adding Latitude and Longitude
# 122 Found Baldwin Park in Google IPA, and Adding Latitude and Longitude
# 123 Found Spring Valley in Google IPA, and Adding Latitude and Longitude
# 124 Found San Ramon in Google IPA, and Adding Latitude and Longitude
# 125 Found Redlands in Google IPA, and Adding Latitude and Longitude
# 126 Found Folsom in Google IPA, and Adding Latitude and Longitude
# 127 Found Huntington Park in Google IPA, and Adding Latitude and Longitude
# 128 Found Petaluma in Google IPA, and Adding Latitude and Longitude
# 129 Found La Mesa in Google IPA, and Adding Latitude and Longitude
# 130 Found Lake Forest in Google IPA, and Adding Latitude and Longitude
# 131 Found Milpitas in Google IPA, and Adding Latitude and Longitude
# 132 Found Pleasanton in Google IPA, and Adding Latitude and Longitude
# 133 Found Tulare in Google IPA, and Adding Latitude and Longitude
# 134 Found Chino Hills in Google IPA, and Adding Latitude and Longitude
# 135 Found Lake Elsinore in Google IPA, and Adding Latitude and Longitude
# 136 Found San Rafael in Google IPA, and Adding Latitude and Longitude
# 137 Found Yuba City in Google IPA, and Adding Latitude and Longitude
# 138 Found Yorba Linda in Google IPA, and Adding Latitude and Longitude
# 139 Found Redondo Beach in Google IPA, and Adding Latitude and Longitude
# 140 Found Lynwood in Google IPA, and Adding Latitude and Longitude
# 141 Found Union City in Google IPA, and Adding Latitude and Longitude
# 142 Found Davis in Google IPA, and Adding Latitude and Longitude
# 143 Found Brentwood in Google IPA, and Adding Latitude and Longitude
# 144 Found Alameda in Google IPA, and Adding Latitude and Longitude
# 145 Found Hanford in Google IPA, and Adding Latitude and Longitude
# 146 Found Palo Alto in Google IPA, and Adding Latitude and Longitude
# 147 Found Arcadia in Google IPA, and Adding Latitude and Longitude
# 148 Found San Luis Obispo in Google IPA, and Adding Latitude and Longitude
# 149 Found Pico Rivera in Google IPA, and Adding Latitude and Longitude
# 150 Found Laguna Niguel in Google IPA, and Adding Latitude and Longitude
# 151 Found Rosemead in Google IPA, and Adding Latitude and Longitude
# 152 Found South San Francisco in Google IPA, and Adding Latitude and Longitude
# 153 Found San Gabriel in Google IPA, and Adding Latitude and Longitude
# 154 Found Montebello in Google IPA, and Adding Latitude and Longitude
# 155 Found Woodland in Google IPA, and Adding Latitude and Longitude
# 156 Found San Clemente in Google IPA, and Adding Latitude and Longitude
# 157 Found Novato in Google IPA, and Adding Latitude and Longitude
# 158 Found Florence-Graham in Google IPA, and Adding Latitude and Longitude
# 159 Found Encinitas in Google IPA, and Adding Latitude and Longitude
# 160 Found La Habra in Google IPA, and Adding Latitude and Longitude
# 161 Found Monterey Park in Google IPA, and Adding Latitude and Longitude
# 162 Found Gilroy in Google IPA, and Adding Latitude and Longitude
# 163 Found National City in Google IPA, and Adding Latitude and Longitude
# 164 Found Azusa in Google IPA, and Adding Latitude and Longitude
# 165 Found Gardena in Google IPA, and Adding Latitude and Longitude
# 166 Found Cupertino in Google IPA, and Adding Latitude and Longitude
# 167 Found Carmichael in Google IPA, and Adding Latitude and Longitude
# 168 Found Lompoc in Google IPA, and Adding Latitude and Longitude
# 169 Found Fountain Valley in Google IPA, and Adding Latitude and Longitude
# 170 Found South Whittier in Google IPA, and Adding Latitude and Longitude
# 171 Found Rocklin in Google IPA, and Adding Latitude and Longitude
# 172 Found Colton in Google IPA, and Adding Latitude and Longitude
# 173 Found El Centro in Google IPA, and Adding Latitude and Longitude
# 174 Found Santee in Google IPA, and Adding Latitude and Longitude
# 175 Found Paramount in Google IPA, and Adding Latitude and Longitude
# 176 Found Glendora in Google IPA, and Adding Latitude and Longitude
# 177 Found Danville in Google IPA, and Adding Latitude and Longitude
# 178 Found Palm Desert in Google IPA, and Adding Latitude and Longitude
# 179 Found Delano in Google IPA, and Adding Latitude and Longitude
# 180 Found Castro Valley in Google IPA, and Adding Latitude and Longitude
# 181 Found Lincoln in Google IPA, and Adding Latitude and Longitude
# 182 Found Hacienda Heights in Google IPA, and Adding Latitude and Longitude
# 183 Found West Sacramento in Google IPA, and Adding Latitude and Longitude
# 184 Found Yucaipa in Google IPA, and Adding Latitude and Longitude
# 185 Found Oroville in Google IPA, and Adding Latitude and Longitude
# 186 Found Placentia in Google IPA, and Adding Latitude and Longitude
# 187 Found Hollister in Google IPA, and Adding Latitude and Longitude
# 188 Found Poway in Google IPA, and Adding Latitude and Longitude
# 189 Found Fallbrook in Google IPA, and Adding Latitude and Longitude
# 190 Found Cathedral City in Google IPA, and Adding Latitude and Longitude
# 191 Found Palm Springs in Google IPA, and Adding Latitude and Longitude
# 192 Found La Mirada in Google IPA, and Adding Latitude and Longitude
# 193 Found Cypress in Google IPA, and Adding Latitude and Longitude
# 194 Found Cerritos in Google IPA, and Adding Latitude and Longitude
# 195 Found Eastvale in Google IPA, and Adding Latitude and Longitude
# 196 Found San Jacinto in Google IPA, and Adding Latitude and Longitude
# 197 Found Aliso Viejo in Google IPA, and Adding Latitude and Longitude
# 198 Found Diamond Bar in Google IPA, and Adding Latitude and Longitude
# 199 Found Martinez in Google IPA, and Adding Latitude and Longitude
# 200 Found Dublin in Google IPA, and Adding Latitude and Longitude
# 201 Found Highland in Google IPA, and Adding Latitude and Longitude
# 202 Found Morgan Hill in Google IPA, and Adding Latitude and Longitude
# 203 Found Eureka in Google IPA, and Adding Latitude and Longitude
# 204 Found Brea in Google IPA, and Adding Latitude and Longitude
# 205 Found Auburn in Google IPA, and Adding Latitude and Longitude
# 206 Found Desert Hot Springs in Google IPA, and Adding Latitude and Longitude
# 207 Found Grass Valley in Google IPA, and Adding Latitude and Longitude
# 208 Found Beaumont in Google IPA, and Adding Latitude and Longitude
# 209 Found Coachella in Google IPA, and Adding Latitude and Longitude
# 210 Found Rowland Heights in Google IPA, and Adding Latitude and Longitude
# 211 Found Lakeside in Google IPA, and Adding Latitude and Longitude
# 212 Found Newark in Google IPA, and Adding Latitude and Longitude
# 213 Found Fair Oaks in Google IPA, and Adding Latitude and Longitude
# 214 Found Monrovia in Google IPA, and Adding Latitude and Longitude
# 215 Found Bell Gardens in Google IPA, and Adding Latitude and Longitude
# 216 Found Rancho Santa Margarita in Google IPA, and Adding Latitude and Longitude
# 217 Found Campbell in Google IPA, and Adding Latitude and Longitude
# 218 Found Menlo Park in Google IPA, and Adding Latitude and Longitude
# 219 Found San Bruno in Google IPA, and Adding Latitude and Longitude
# 220 Found Paso Robles in Google IPA, and Adding Latitude and Longitude
# 221 Found San Pablo in Google IPA, and Adding Latitude and Longitude
# 222 Found La Puente in Google IPA, and Adding Latitude and Longitude
# 223 Found Ceres in Google IPA, and Adding Latitude and Longitude
# 224 Found Rancho Palos Verdes in Google IPA, and Adding Latitude and Longitude
# 225 Found Los Banos in Google IPA, and Adding Latitude and Longitude
# 226 Found Oakley in Google IPA, and Adding Latitude and Longitude
# 227 Found Culver City in Google IPA, and Adding Latitude and Longitude
# 228 Found Ramona in Google IPA, and Adding Latitude and Longitude
# 229 Found La Quinta in Google IPA, and Adding Latitude and Longitude
# 230 Found Montclair in Google IPA, and Adding Latitude and Longitude
# 231 Found Pacifica in Google IPA, and Adding Latitude and Longitude
# 232 Found El Dorado Hills in Google IPA, and Adding Latitude and Longitude
# 233 Found Atwater in Google IPA, and Adding Latitude and Longitude
# 234 Found Rohnert Park in Google IPA, and Adding Latitude and Longitude
# 235 Found Moorpark in Google IPA, and Adding Latitude and Longitude
# 236 Found Claremont in Google IPA, and Adding Latitude and Longitude
# 237 Found Altadena in Google IPA, and Adding Latitude and Longitude
# 238 Found Lemoore in Google IPA, and Adding Latitude and Longitude
# 239 Found San Juan Capistrano in Google IPA, and Adding Latitude and Longitude
# 240 Found Sonoma in Google IPA, and Adding Latitude and Longitude
# 241 Found Wildomar in Google IPA, and Adding Latitude and Longitude
# 242 Found West Hollywood in Google IPA, and Adding Latitude and Longitude
# 243 Found Bell in Google IPA, and Adding Latitude and Longitude
# 244 Found Santa Paula in Google IPA, and Adding Latitude and Longitude
# 245 Found Placerville in Google IPA, and Adding Latitude and Longitude
# 246 Found Temple City in Google IPA, and Adding Latitude and Longitude
# 247 Found Calexico in Google IPA, and Adding Latitude and Longitude
# 248 Found Los Gatos in Google IPA, and Adding Latitude and Longitude
# 249 Found Barstow in Google IPA, and Adding Latitude and Longitude
# 250 Found Rubidoux in Google IPA, and Adding Latitude and Longitude
# 251 Found Beverly Hills in Google IPA, and Adding Latitude and Longitude
# 252 Found Pleasant Hill in Google IPA, and Adding Latitude and Longitude
# 253 Found Marysville in Google IPA, and Adding Latitude and Longitude
# 254 Found Manhattan Beach in Google IPA, and Adding Latitude and Longitude
# 255 Found Sanger in Google IPA, and Adding Latitude and Longitude
# 256 Found Dana Point in Google IPA, and Adding Latitude and Longitude
# 257 Found Shingle Springs in Google IPA, and Adding Latitude and Longitude
# 258 Found Ridgecrest in Google IPA, and Adding Latitude and Longitude
# 259 Found Galt in Google IPA, and Adding Latitude and Longitude
# 260 Found Adelanto in Google IPA, and Adding Latitude and Longitude
# 261 Found San Dimas in Google IPA, and Adding Latitude and Longitude
# 262 Found La Verne in Google IPA, and Adding Latitude and Longitude
# 263 Found Oakdale in Google IPA, and Adding Latitude and Longitude
# 264 Found Banning in Google IPA, and Adding Latitude and Longitude
# 265 Found Tehachapi in Google IPA, and Adding Latitude and Longitude
# 266 Found Reedley in Google IPA, and Adding Latitude and Longitude
# 267 Found Lawndale in Google IPA, and Adding Latitude and Longitude
# 268 Found Los Altos in Google IPA, and Adding Latitude and Longitude
# 269 Found Foster City in Google IPA, and Adding Latitude and Longitude
# 270 Found Dinuba in Google IPA, and Adding Latitude and Longitude
# 271 Found Atascadero in Google IPA, and Adding Latitude and Longitude
# 272 Found Westmont in Google IPA, and Adding Latitude and Longitude
# 273 Found Saratoga in Google IPA, and Adding Latitude and Longitude
# 274 Found Winchester in Google IPA, and Adding Latitude and Longitude
# 275 Found Ukiah in Google IPA, and Adding Latitude and Longitude
# 276 Found Orangevale in Google IPA, and Adding Latitude and Longitude
# 277 Found Burlingame in Google IPA, and Adding Latitude and Longitude
# 278 Found Seaside in Google IPA, and Adding Latitude and Longitude
# 279 Found Monterey in Google IPA, and Adding Latitude and Longitude
# 280 Found Laguna Hills in Google IPA, and Adding Latitude and Longitude
# 281 Found Walnut in Google IPA, and Adding Latitude and Longitude
# 282 Found Selma in Google IPA, and Adding Latitude and Longitude
# 283 Found San Carlos in Google IPA, and Adding Latitude and Longitude
# 284 Found Lafayette in Google IPA, and Adding Latitude and Longitude
# 285 Found Sebastopol in Google IPA, and Adding Latitude and Longitude
# 286 Found San Lorenzo in Google IPA, and Adding Latitude and Longitude
# 287 Found Arroyo Grande in Google IPA, and Adding Latitude and Longitude
# 288 Found South Lake Tahoe in Google IPA, and Adding Latitude and Longitude
# 289 Found Florin in Google IPA, and Adding Latitude and Longitude
# 290 Found Mill Valley in Google IPA, and Adding Latitude and Longitude
# 291 Found Norco in Google IPA, and Adding Latitude and Longitude
# 292 Found Red Bluff in Google IPA, and Adding Latitude and Longitude
# 293 Found Olivehurst in Google IPA, and Adding Latitude and Longitude
# 294 Found Goleta in Google IPA, and Adding Latitude and Longitude
# 295 Found Sonora in Google IPA, and Adding Latitude and Longitude
# 296 Found Stanton in Google IPA, and Adding Latitude and Longitude
# 297 Found Wasco in Google IPA, and Adding Latitude and Longitude
# 298 Found Suisun City in Google IPA, and Adding Latitude and Longitude
# 299 Found Ladera Ranch in Google IPA, and Adding Latitude and Longitude
# 300 Found Windsor in Google IPA, and Adding Latitude and Longitude
# 301 Found East Palo Alto in Google IPA, and Adding Latitude and Longitude
# 302 Found Imperial Beach in Google IPA, and Adding Latitude and Longitude
# 303 Found Belmont in Google IPA, and Adding Latitude and Longitude
# 304 Found Maywood in Google IPA, and Adding Latitude and Longitude
# 305 Found Isla Vista in Google IPA, and Adding Latitude and Longitude
# 306 Found Corcoran in Google IPA, and Adding Latitude and Longitude
# 307 Found South Pasadena in Google IPA, and Adding Latitude and Longitude
# 308 Found Lemon Grove in Google IPA, and Adding Latitude and Longitude
# 309 Found Soledad in Google IPA, and Adding Latitude and Longitude
# 310 Found Benicia in Google IPA, and Adding Latitude and Longitude
# 311 Found Paradise in Google IPA, and Adding Latitude and Longitude
# 312 Found Patterson in Google IPA, and Adding Latitude and Longitude
# 313 Found Aptos in Google IPA, and Adding Latitude and Longitude
# 314 Found Yucca Valley in Google IPA, and Adding Latitude and Longitude
# 315 Found Oildale in Google IPA, and Adding Latitude and Longitude
# 316 Found Cudahy in Google IPA, and Adding Latitude and Longitude
# 317 Found Seal Beach in Google IPA, and Adding Latitude and Longitude
# 318 Found El Cerrito in Google IPA, and Adding Latitude and Longitude
# 319 Found San Fernando in Google IPA, and Adding Latitude and Longitude
# 320 Found Anderson in Google IPA, and Adding Latitude and Longitude
# 321 Found Agoura Hills in Google IPA, and Adding Latitude and Longitude
# 322 Found Mira Loma in Google IPA, and Adding Latitude and Longitude
# 323 Found Coronado in Google IPA, and Adding Latitude and Longitude
# 324 Found Rosemont in Google IPA, and Adding Latitude and Longitude
# 325 Found North Tustin in Google IPA, and Adding Latitude and Longitude
# 326 Found Calabasas in Google IPA, and Adding Latitude and Longitude
# 327 Found Granite Bay in Google IPA, and Adding Latitude and Longitude
# 328 Found Port Hueneme in Google IPA, and Adding Latitude and Longitude
# 329 Found Dixon in Google IPA, and Adding Latitude and Longitude
# 330 Found Castaic in Google IPA, and Adding Latitude and Longitude
# 331 Found Millbrae in Google IPA, and Adding Latitude and Longitude
# 332 Found Chowchilla in Google IPA, and Adding Latitude and Longitude
# 333 Found Valley Center in Google IPA, and Adding Latitude and Longitude
# 334 Found American Canyon in Google IPA, and Adding Latitude and Longitude
# 335 Found Phelan in Google IPA, and Adding Latitude and Longitude
# 336 Found West Carson in Google IPA, and Adding Latitude and Longitude
# 337 Found Duarte in Google IPA, and Adding Latitude and Longitude
# 338 Found Loma Linda in Google IPA, and Adding Latitude and Longitude
# 339 Found Valinda in Google IPA, and Adding Latitude and Longitude
# 340 Found Marina in Google IPA, and Adding Latitude and Longitude
# 341 Found Willowbrook in Google IPA, and Adding Latitude and Longitude
# 342 Found Hercules in Google IPA, and Adding Latitude and Longitude
# 343 Found Los Alamitos in Google IPA, and Adding Latitude and Longitude
# 344 Found Blythe in Google IPA, and Adding Latitude and Longitude
# 345 Found Twentynine Palms in Google IPA, and Adding Latitude and Longitude
# 346 Found La Canada Flintridge in Google IPA, and Adding Latitude and Longitude
# 347 Found West Puente Valley in Google IPA, and Adding Latitude and Longitude
# 348 Found Susanville in Google IPA, and Adding Latitude and Longitude
# 349 Found Kerman in Google IPA, and Adding Latitude and Longitude
# 350 Found Rosamond in Google IPA, and Adding Latitude and Longitude
# 351 Found South El Monte in Google IPA, and Adding Latitude and Longitude
# 352 Found Brawley in Google IPA, and Adding Latitude and Longitude
# 353 Found Shafter in Google IPA, and Adding Latitude and Longitude
# 354 Found Crescent City in Google IPA, and Adding Latitude and Longitude
# 355 Found Greenfield in Google IPA, and Adding Latitude and Longitude
# 356 Found Arcata in Google IPA, and Adding Latitude and Longitude
# 357 Found Healdsburg in Google IPA, and Adding Latitude and Longitude
# 358 Found Arvin in Google IPA, and Adding Latitude and Longitude
# 359 Found Lomita in Google IPA, and Adding Latitude and Longitude
# 360 Found Ojai in Google IPA, and Adding Latitude and Longitude
# 361 Found Coalinga in Google IPA, and Adding Latitude and Longitude
# 362 Found Lathrop in Google IPA, and Adding Latitude and Longitude
# 363 Found Laguna Beach in Google IPA, and Adding Latitude and Longitude
# 364 Found Bloomington in Google IPA, and Adding Latitude and Longitude
# 365 Found Albany in Google IPA, and Adding Latitude and Longitude
# 366 Found Nipomo in Google IPA, and Adding Latitude and Longitude
# 367 Found La Crescenta-Montrose in Google IPA, and Adding Latitude and Longitude
# 368 Found Nevada City in Google IPA, and Adding Latitude and Longitude
# 369 Found Lindsay in Google IPA, and Adding Latitude and Longitude
# 370 Found Pinole in Google IPA, and Adding Latitude and Longitude
# 371 Found Truckee in Google IPA, and Adding Latitude and Longitude
# 372 Found Malibu in Google IPA, and Adding Latitude and Longitude
# 373 Found Alpine in Google IPA, and Adding Latitude and Longitude
# 374 Found Hermosa Beach in Google IPA, and Adding Latitude and Longitude
# 375 Found McKinleyville in Google IPA, and Adding Latitude and Longitude
# 376 Found Fillmore in Google IPA, and Adding Latitude and Longitude
# 377 Found Santa Fe Springs in Google IPA, and Adding Latitude and Longitude
# 378 Found Orinda in Google IPA, and Adding Latitude and Longitude
# 379 Found Taft in Google IPA, and Adding Latitude and Longitude
# 380 Found Ripon in Google IPA, and Adding Latitude and Longitude
# 381 Found Rosedale in Google IPA, and Adding Latitude and Longitude
# 382 Found South San Jose Hills in Google IPA, and Adding Latitude and Longitude
# 383 Found Thermal in Google IPA, and Adding Latitude and Longitude
# 384 Found Riverbank in Google IPA, and Adding Latitude and Longitude
# 385 Found Alamo in Google IPA, and Adding Latitude and Longitude
# 386 Found Rancho Mirage in Google IPA, and Adding Latitude and Longitude
# 387 Found Moraga in Google IPA, and Adding Latitude and Longitude
# 388 Found Artesia in Google IPA, and Adding Latitude and Longitude
# 389 Found El Segundo in Google IPA, and Adding Latitude and Longitude
# 390 Found Bonita in Google IPA, and Adding Latitude and Longitude
# 391 Found Kingsburg in Google IPA, and Adding Latitude and Longitude
# 392 Found Carpinteria in Google IPA, and Adding Latitude and Longitude
# 393 Found Exeter in Google IPA, and Adding Latitude and Longitude
# 394 Found Livingston in Google IPA, and Adding Latitude and Longitude
# 395 Found Laguna Woods in Google IPA, and Adding Latitude and Longitude
# 396 Found Nuevo in Google IPA, and Adding Latitude and Longitude
# 397 Found Mc Farland in Google IPA, and Adding Latitude and Longitude
# 398 Found La Palma in Google IPA, and Adding Latitude and Longitude
# 399 Found Parlier in Google IPA, and Adding Latitude and Longitude
# 400 Found Winton in Google IPA, and Adding Latitude and Longitude
# 401 Found Glen Avon in Google IPA, and Adding Latitude and Longitude
# 402 Found Half Moon Bay in Google IPA, and Adding Latitude and Longitude
# 403 Found Orland in Google IPA, and Adding Latitude and Longitude
# 404 Found San Anselmo in Google IPA, and Adding Latitude and Longitude
# 405 Found Corning in Google IPA, and Adding Latitude and Longitude
# 406 Found Loomis in Google IPA, and Adding Latitude and Longitude
# 407 Found King City in Google IPA, and Adding Latitude and Longitude
# 408 Found Cottonwood in Google IPA, and Adding Latitude and Longitude
# 409 Found Firebaugh in Google IPA, and Adding Latitude and Longitude
# 410 Found Pacific Grove in Google IPA, and Adding Latitude and Longitude
# 411 Found Rio Linda in Google IPA, and Adding Latitude and Longitude
# 412 Found Littlerock in Google IPA, and Adding Latitude and Longitude
# 413 Found Oak Park in Google IPA, and Adding Latitude and Longitude
# 414 Found Carmel-by-the-Sea in Google IPA, and Adding Latitude and Longitude
# 415 Found Los Osos in Google IPA, and Adding Latitude and Longitude
# 416 Found Scotts Valley in Google IPA, and Adding Latitude and Longitude
# 417 Found Stanford in Google IPA, and Adding Latitude and Longitude
# 418 Found Clearlake in Google IPA, and Adding Latitude and Longitude
# 419 Found Imperial in Google IPA, and Adding Latitude and Longitude
# 420 Found Hawaiian Gardens in Google IPA, and Adding Latitude and Longitude
# 421 Found Coto de Caza in Google IPA, and Adding Latitude and Longitude
# 422 Found Hughson in Google IPA, and Adding Latitude and Longitude
# 423 Found Westlake Village in Google IPA, and Adding Latitude and Longitude
# 424 Found Alum Rock in Google IPA, and Adding Latitude and Longitude
# 425 Found Willits in Google IPA, and Adding Latitude and Longitude
# 426 Found Avenal in Google IPA, and Adding Latitude and Longitude
# 427 Found Holtville in Google IPA, and Adding Latitude and Longitude
# 428 Found Grover Beach in Google IPA, and Adding Latitude and Longitude
# 429 Found Fort Bragg in Google IPA, and Adding Latitude and Longitude
# 430 Found Bishop in Google IPA, and Adding Latitude and Longitude
# 431 Found Clayton in Google IPA, and Adding Latitude and Longitude
# 432 Found Commerce in Google IPA, and Adding Latitude and Longitude
# 433 Found San Marino in Google IPA, and Adding Latitude and Longitude
# 434 Found Avocado Heights in Google IPA, and Adding Latitude and Longitude
# 435 Found Valley Springs in Google IPA, and Adding Latitude and Longitude
# 436 Found Pedley in Google IPA, and Adding Latitude and Longitude
# 437 Found Escalon in Google IPA, and Adding Latitude and Longitude
# 438 Found Fortuna in Google IPA, and Adding Latitude and Longitude
# 439 Found Newman in Google IPA, and Adding Latitude and Longitude
# 440 Found Lamont in Google IPA, and Adding Latitude and Longitude
# 441 Found Palos Verdes Estates in Google IPA, and Adding Latitude and Longitude
# 442 Found Sausalito in Google IPA, and Adding Latitude and Longitude
# 443 Found Delhi in Google IPA, and Adding Latitude and Longitude
# 444 Found Calimesa in Google IPA, and Adding Latitude and Longitude
# 445 Found Canyon Lake in Google IPA, and Adding Latitude and Longitude
# 446 Found Mecca in Google IPA, and Adding Latitude and Longitude
# 447 Found Grand Terrace in Google IPA, and Adding Latitude and Longitude
# 448 Found Gridley in Google IPA, and Adding Latitude and Longitude
# 449 Found View Park-Windsor Hills in Google IPA, and Adding Latitude and Longitude
# 450 Found Coarsegold in Google IPA, and Adding Latitude and Longitude
# 451 Found El Sobrante in Google IPA, and Adding Latitude and Longitude
# 452 Found Piedmont in Google IPA, and Adding Latitude and Longitude
# 453 Found Solana Beach in Google IPA, and Adding Latitude and Longitude
# 454 Found Big Bear City in Google IPA, and Adding Latitude and Longitude
# 455 Found Kelseyville in Google IPA, and Adding Latitude and Longitude
# 456 Found Magalia in Google IPA, and Adding Latitude and Longitude
# 457 Found Orosi in Google IPA, and Adding Latitude and Longitude
# 458 Found Signal Hill in Google IPA, and Adding Latitude and Longitude
# 459 Found Live Oak in Google IPA, and Adding Latitude and Longitude
# 460 Found Garden Acres in Google IPA, and Adding Latitude and Longitude
# 461 Found Hillsborough in Google IPA, and Adding Latitude and Longitude
# 462 Found Sierra Madre in Google IPA, and Adding Latitude and Longitude
# 463 Found Newport Coast in Google IPA, and Adding Latitude and Longitude
# 464 Found California City in Google IPA, and Adding Latitude and Longitude
# 465 Found Dos Palos in Google IPA, and Adding Latitude and Longitude
# 466 Found Lakeport in Google IPA, and Adding Latitude and Longitude
# 467 Found Cotati in Google IPA, and Adding Latitude and Longitude
# 468 Found Woodside in Google IPA, and Adding Latitude and Longitude
# 469 Found Lake Arrowhead in Google IPA, and Adding Latitude and Longitude
# 470 Found Tiburon in Google IPA, and Adding Latitude and Longitude
# 471 Found East La Mirada in Google IPA, and Adding Latitude and Longitude
# 472 Found North Fair Oaks in Google IPA, and Adding Latitude and Longitude
# 473 Found Morro Bay in Google IPA, and Adding Latitude and Longitude
# 474 Found Jamul in Google IPA, and Adding Latitude and Longitude
# 475 Found Emeryville in Google IPA, and Adding Latitude and Longitude
# 476 Found Soquel in Google IPA, and Adding Latitude and Longitude
# 477 Found Shasta Lake in Google IPA, and Adding Latitude and Longitude
# 478 Found Rancho Santa Fe in Google IPA, and Adding Latitude and Longitude
# 479 Found Cloverdale in Google IPA, and Adding Latitude and Longitude
# 480 Found Mariposa in Google IPA, and Adding Latitude and Longitude
# 481 Found Corte Madera in Google IPA, and Adding Latitude and Longitude
# 482 Found Rodeo in Google IPA, and Adding Latitude and Longitude
# 483 Found Muscoy in Google IPA, and Adding Latitude and Longitude
# 484 Found Rolling Hills Estates in Google IPA, and Adding Latitude and Longitude
# 485 Found Colfax in Google IPA, and Adding Latitude and Longitude
# 486 Found Marina del Rey in Google IPA, and Adding Latitude and Longitude
# 487 Found Woodlake in Google IPA, and Adding Latitude and Longitude
# 488 Found Pollock Pines in Google IPA, and Adding Latitude and Longitude
# 489 Found Earlimart in Google IPA, and Adding Latitude and Longitude
# 490 Found La Riviera in Google IPA, and Adding Latitude and Longitude
# 491 Found Penn Valley in Google IPA, and Adding Latitude and Longitude
# 492 Found Boulder Creek in Google IPA, and Adding Latitude and Longitude
# 493 Found Joshua Tree in Google IPA, and Adding Latitude and Longitude
# 494 Found Orange Cove in Google IPA, and Adding Latitude and Longitude
# 495 Found Salida in Google IPA, and Adding Latitude and Longitude
# 496 Found Discovery Bay in Google IPA, and Adding Latitude and Longitude
# 497 Found Waterford in Google IPA, and Adding Latitude and Longitude
# 498 Found Capitola in Google IPA, and Adding Latitude and Longitude
# 499 Found Gonzales in Google IPA, and Adding Latitude and Longitude
# 500 Found Winters in Google IPA, and Adding Latitude and Longitude
# 501 Found Ladera Heights in Google IPA, and Adding Latitude and Longitude
# 502 Found East Foothills in Google IPA, and Adding Latitude and Longitude
# 503 Found Saint Helena in Google IPA, and Adding Latitude and Longitude
# 504 Found Yreka in Google IPA, and Adding Latitude and Longitude
# 505 Found Templeton in Google IPA, and Adding Latitude and Longitude
# 506 Found Indian Wells in Google IPA, and Adding Latitude and Longitude
# 507 Found Gustine in Google IPA, and Adding Latitude and Longitude
# 508 Found Fairfax in Google IPA, and Adding Latitude and Longitude
# 509 Found Castroville in Google IPA, and Adding Latitude and Longitude
# 510 Found Jamestown in Google IPA, and Adding Latitude and Longitude
# 511 Found Willows in Google IPA, and Adding Latitude and Longitude
# 512 Found Mentone in Google IPA, and Adding Latitude and Longitude
# 513 Found Riverdale in Google IPA, and Adding Latitude and Longitude
# 514 Found Mendota in Google IPA, and Adding Latitude and Longitude
# 515 Found Oceano in Google IPA, and Adding Latitude and Longitude
# 516 Found Los Altos Hills in Google IPA, and Adding Latitude and Longitude
# 517 Found West Athens in Google IPA, and Adding Latitude and Longitude
# 518 Found Mammoth Lakes in Google IPA, and Adding Latitude and Longitude
# 519 Found Colusa in Google IPA, and Adding Latitude and Longitude
# 520 Found Thousand Palms in Google IPA, and Adding Latitude and Longitude
# 521 Found Crestline in Google IPA, and Adding Latitude and Longitude
# 522 Found Acton in Google IPA, and Adding Latitude and Longitude
# 523 Found Calistoga in Google IPA, and Adding Latitude and Longitude
# 524 Found Solvang in Google IPA, and Adding Latitude and Longitude
# 525 Found Felton in Google IPA, and Adding Latitude and Longitude
# 526 Found Alondra Park in Google IPA, and Adding Latitude and Longitude
# 527 Found Lucerne Valley in Google IPA, and Adding Latitude and Longitude
# 528 Found Hilmar in Google IPA, and Adding Latitude and Longitude
# 529 Found August in Google IPA, and Adding Latitude and Longitude
# 530 Found Newcastle in Google IPA, and Adding Latitude and Longitude
# 531 Found Atherton in Google IPA, and Adding Latitude and Longitude
# 532 Found Montecito in Google IPA, and Adding Latitude and Longitude
# 533 Found Denair in Google IPA, and Adding Latitude and Longitude
# 534 Found Calipatria in Google IPA, and Adding Latitude and Longitude
# 535 Found Farmersville in Google IPA, and Adding Latitude and Longitude
# 536 Found Heber in Google IPA, and Adding Latitude and Longitude
# 537 Found Jackson in Google IPA, and Adding Latitude and Longitude
# 538 Found Guadalupe in Google IPA, and Adding Latitude and Longitude
# 539 Found Elverta in Google IPA, and Adding Latitude and Longitude
# 540 Found Acampo in Google IPA, and Adding Latitude and Longitude
# 541 Found Rio Vista in Google IPA, and Adding Latitude and Longitude
# 542 Found Kentfield in Google IPA, and Adding Latitude and Longitude
# 543 Found Freedom in Google IPA, and Adding Latitude and Longitude
# 544 Found La Habra Heights in Google IPA, and Adding Latitude and Longitude
# 545 Found Mojave in Google IPA, and Adding Latitude and Longitude
# 546 Found Fowler in Google IPA, and Adding Latitude and Longitude
# 547 Found San Miguel in Google IPA, and Adding Latitude and Longitude
# 548 Found Silverado in Google IPA, and Adding Latitude and Longitude
# 549 Found Topanga in Google IPA, and Adding Latitude and Longitude
# 550 Found Larkspur in Google IPA, and Adding Latitude and Longitude
# 551 Found Redwood Valley in Google IPA, and Adding Latitude and Longitude
# 552 Found French Camp in Google IPA, and Adding Latitude and Longitude
# 553 Found Oak View in Google IPA, and Adding Latitude and Longitude
# 554 Found Strathmore in Google IPA, and Adding Latitude and Longitude
# 555 Found Cutler in Google IPA, and Adding Latitude and Longitude
# 556 Found Pixley in Google IPA, and Adding Latitude and Longitude
# 557 Found Sloughhouse in Google IPA, and Adding Latitude and Longitude
# 558 Found Ben Lomond in Google IPA, and Adding Latitude and Longitude
# 559 Found Quincy in Google IPA, and Adding Latitude and Longitude
# 560 Found Carmel Valley in Google IPA, and Adding Latitude and Longitude
# 561 Found Huron in Google IPA, and Adding Latitude and Longitude
# 562 Found Lake Isabella in Google IPA, and Adding Latitude and Longitude
# 563 Found Homeland in Google IPA, and Adding Latitude and Longitude
# 564 Found San Martin in Google IPA, and Adding Latitude and Longitude
# 565 Found Williams in Google IPA, and Adding Latitude and Longitude
# 566 Found Villa Park in Google IPA, and Adding Latitude and Longitude
# 567 Found Caruthers in Google IPA, and Adding Latitude and Longitude
# 568 Found Terra Bella in Google IPA, and Adding Latitude and Longitude
# 569 Found Montague in Google IPA, and Adding Latitude and Longitude
# 570 Found Oakhurst in Google IPA, and Adding Latitude and Longitude
# 571 Found Pismo Beach in Google IPA, and Adding Latitude and Longitude
# 572 Found Kensington in Google IPA, and Adding Latitude and Longitude
# 573 Found Foresthill in Google IPA, and Adding Latitude and Longitude
# 574 Found Buellton in Google IPA, and Adding Latitude and Longitude
# 575 Found Santa Ynez in Google IPA, and Adding Latitude and Longitude
# 576 Found Forestville in Google IPA, and Adding Latitude and Longitude
# 577 Found Linden in Google IPA, and Adding Latitude and Longitude
# 578 Found East Pasadena in Google IPA, and Adding Latitude and Longitude
# 579 Found Helendale in Google IPA, and Adding Latitude and Longitude
# 580 Found Cambria in Google IPA, and Adding Latitude and Longitude
# 581 Found Murphys in Google IPA, and Adding Latitude and Longitude
# 582 Found Moss Landing in Google IPA, and Adding Latitude and Longitude
# 583 Found South Yuba City in Google IPA, and Adding Latitude and Longitude
# 584 Found Pioneer in Google IPA, and Adding Latitude and Longitude
# 585 Found Arbuckle in Google IPA, and Adding Latitude and Longitude
# 586 Found Pine Grove in Google IPA, and Adding Latitude and Longitude
# 587 Found Weed in Google IPA, and Adding Latitude and Longitude
# 588 Found Big Bear Lake in Google IPA, and Adding Latitude and Longitude
# 589 Found Mount Shasta in Google IPA, and Adding Latitude and Longitude
# 590 Found Pinon Hills in Google IPA, and Adding Latitude and Longitude
# 591 Found Wilton in Google IPA, and Adding Latitude and Longitude
# 592 Found San Joaquin in Google IPA, and Adding Latitude and Longitude
# 593 Found Diamond Springs in Google IPA, and Adding Latitude and Longitude
# 594 Found Camino in Google IPA, and Adding Latitude and Longitude
# 595 Found San Juan Bautista in Google IPA, and Adding Latitude and Longitude
# 596 Found Hidden Valley Lake in Google IPA, and Adding Latitude and Longitude
# 597 Found Kennedy in Google IPA, and Adding Latitude and Longitude
# 598 Found Rescue in Google IPA, and Adding Latitude and Longitude
# 599 Found Cool in Google IPA, and Adding Latitude and Longitude
# 600 Found Keyes in Google IPA, and Adding Latitude and Longitude
# 601 Found Frazier Park in Google IPA, and Adding Latitude and Longitude
# 602 Found San Andreas in Google IPA, and Adding Latitude and Longitude
# 603 Found Bonsall in Google IPA, and Adding Latitude and Longitude
# 604 Found Penngrove in Google IPA, and Adding Latitude and Longitude
# 605 Found Morongo Valley in Google IPA, and Adding Latitude and Longitude
# 606 Found Del Monte Forest in Google IPA, and Adding Latitude and Longitude
# 607 Found Guerneville in Google IPA, and Adding Latitude and Longitude
# 608 Found Wheatland in Google IPA, and Adding Latitude and Longitude
# 609 Found Morada in Google IPA, and Adding Latitude and Longitude
# 610 Found Brisbane in Google IPA, and Adding Latitude and Longitude
# 611 Found Clearlake Oaks in Google IPA, and Adding Latitude and Longitude
# 612 Found Needles in Google IPA, and Adding Latitude and Longitude
# 613 Found Aromas in Google IPA, and Adding Latitude and Longitude
# 614 Found Meadow Vista in Google IPA, and Adding Latitude and Longitude
# 615 Found Lower Lake in Google IPA, and Adding Latitude and Longitude
# 616 Found Middletown in Google IPA, and Adding Latitude and Longitude
# 617 Found Twain Harte in Google IPA, and Adding Latitude and Longitude
# 618 Found Glen Ellen in Google IPA, and Adding Latitude and Longitude
# 619 Found Lincoln Village in Google IPA, and Adding Latitude and Longitude
# 620 Found Mather in Google IPA, and Adding Latitude and Longitude
# 621 Found Esparto in Google IPA, and Adding Latitude and Longitude
# 622 Found Portola Valley in Google IPA, and Adding Latitude and Longitude
# 623 Found Angwin in Google IPA, and Adding Latitude and Longitude
# 624 Found Alturas in Google IPA, and Adding Latitude and Longitude
# 625 Found Highlands-Baywood Park in Google IPA, and Adding Latitude and Longitude
# 626 Found Garden Valley in Google IPA, and Adding Latitude and Longitude
# 627 Found Le Grand in Google IPA, and Adding Latitude and Longitude
# 628 Found Descanso in Google IPA, and Adding Latitude and Longitude
# 629 Found Palo Cedro in Google IPA, and Adding Latitude and Longitude
# 630 Found Tipton in Google IPA, and Adding Latitude and Longitude
# 631 Found Wrightwood in Google IPA, and Adding Latitude and Longitude
# 632 Found Garberville in Google IPA, and Adding Latitude and Longitude
# 633 Found Campo in Google IPA, and Adding Latitude and Longitude
# 634 Found Shandon in Google IPA, and Adding Latitude and Longitude
# 635 Found Shingletown in Google IPA, and Adding Latitude and Longitude
# 636 Found Laton in Google IPA, and Adding Latitude and Longitude
# 637 Found Del Mar in Google IPA, and Adding Latitude and Longitude
# 638 Found Durham in Google IPA, and Adding Latitude and Longitude
# 639 Found Burney in Google IPA, and Adding Latitude and Longitude
# 640 Found El Dorado in Google IPA, and Adding Latitude and Longitude
# 641 Found Lake Hughes in Google IPA, and Adding Latitude and Longitude
# 642 Found Del Rey in Google IPA, and Adding Latitude and Longitude
# 643 Found Cambrian Park in Google IPA, and Adding Latitude and Longitude
# 644 Found Emerald Lake Hills in Google IPA, and Adding Latitude and Longitude
# 645 Found Running Springs in Google IPA, and Adding Latitude and Longitude
# 646 Found Landers in Google IPA, and Adding Latitude and Longitude
# 647 Found Avalon in Google IPA, and Adding Latitude and Longitude
# 648 Found Janesville in Google IPA, and Adding Latitude and Longitude
# 649 Found Plymouth in Google IPA, and Adding Latitude and Longitude
# 650 Found Tuolumne in Google IPA, and Adding Latitude and Longitude
# 651 Found Gerber in Google IPA, and Adding Latitude and Longitude
# 652 Found Portola in Google IPA, and Adding Latitude and Longitude
# 653 Found Agua Dulce in Google IPA, and Adding Latitude and Longitude
# 654 Found Groveland in Google IPA, and Adding Latitude and Longitude
# 655 Found Ivanhoe in Google IPA, and Adding Latitude and Longitude
# 656 Found Boron in Google IPA, and Adding Latitude and Longitude
# 657 Found Ferndale in Google IPA, and Adding Latitude and Longitude
# 658 Found Aguanga in Google IPA, and Adding Latitude and Longitude
# 659 Found Cressey in Google IPA, and Adding Latitude and Longitude
# 660 Found North Fork in Google IPA, and Adding Latitude and Longitude
# 661 Found Buttonwillow in Google IPA, and Adding Latitude and Longitude
# 662 Found Farmington in Google IPA, and Adding Latitude and Longitude
# 663 Found Weaverville in Google IPA, and Adding Latitude and Longitude
# 664 Found Monte Sereno in Google IPA, and Adding Latitude and Longitude
# 665 Found Lockeford in Google IPA, and Adding Latitude and Longitude
# 666 Found Lucerne in Google IPA, and Adding Latitude and Longitude
# 667 Found Llano in Google IPA, and Adding Latitude and Longitude
# 668 Found Sunnyslope in Google IPA, and Adding Latitude and Longitude
# 669 Found Rio Dell in Google IPA, and Adding Latitude and Longitude
# 670 Found Planada in Google IPA, and Adding Latitude and Longitude
# 671 Found Moss Beach in Google IPA, and Adding Latitude and Longitude
# 672 Found Auberry in Google IPA, and Adding Latitude and Longitude
# 673 Found Herald in Google IPA, and Adding Latitude and Longitude
# 674 Found Somis in Google IPA, and Adding Latitude and Longitude
# 675 Found Ahwahnee in Google IPA, and Adding Latitude and Longitude
# 676 Found White Water in Google IPA, and Adding Latitude and Longitude
# 677 Found Yountville in Google IPA, and Adding Latitude and Longitude
# 678 Found Kings Beach in Google IPA, and Adding Latitude and Longitude
# 679 Found Somerset in Google IPA, and Adding Latitude and Longitude
# 680 Found Walnut Grove in Google IPA, and Adding Latitude and Longitude
# 681 Found Flournoy in Google IPA, and Adding Latitude and Longitude
# ...
# 879 Found Doyle in Google IPA, and Adding Latitude and Longitude
# 880 Found Mi Wuk Village in Google IPA, and Adding Latitude and Longitude
# 881 Found Midpines in Google IPA, and Adding Latitude and Longitude
# 882 Found Dillon Beach in Google IPA, and Adding Latitude and Longitude
# 883 Found Ranchita in Google IPA, and Adding Latitude and Longitude
# 884 Found Pine Valley in Google IPA, and Adding Latitude and Longitude
# 885 Found Lakeshore in Google IPA, and Adding Latitude and Longitude
# 886 Found Hornbrook in Google IPA, and Adding Latitude and Longitude
# 887 Found Oregon House in Google IPA, and Adding Latitude and Longitude
# 888 Found Glenhaven in Google IPA, and Adding Latitude and Longitude
# 889 Found Dorris in Google IPA, and Adding Latitude and Longitude
# 890 Found Albion in Google IPA, and Adding Latitude and Longitude
# 891 Found Westmorland in Google IPA, and Adding Latitude and Longitude
# 892 Found Cantua Creek in Google IPA, and Adding Latitude and Longitude
# 893 Found Maxwell in Google IPA, and Adding Latitude and Longitude
# 894 Found Onyx in Google IPA, and Adding Latitude and Longitude
# 895 Found Green Valley Lake in Google IPA, and Adding Latitude and Longitude
# 896 Found The Sea Ranch in Google IPA, and Adding Latitude and Longitude
# 897 Found Shaver Lake in Google IPA, and Adding Latitude and Longitude
# 898 Found Applegate in Google IPA, and Adding Latitude and Longitude
# 899 Found Salyer in Google IPA, and Adding Latitude and Longitude
# 900 Found Mc Kittrick in Google IPA, and Adding Latitude and Longitude
# 901 Found Lotus in Google IPA, and Adding Latitude and Longitude
# 902 Found Sunol-Midtown in Google IPA, and Adding Latitude and Longitude
# 903 Found Catheys Valley in Google IPA, and Adding Latitude and Longitude
# 904 Found Jenner in Google IPA, and Adding Latitude and Longitude
# 905 Found Birds Landing in Google IPA, and Adding Latitude and Longitude
# 906 Found Markleeville in Google IPA, and Adding Latitude and Longitude
# 907 Found Whitethorn in Google IPA, and Adding Latitude and Longitude
# 908 Found Bass Lake in Google IPA, and Adding Latitude and Longitude
# 909 Found McArthur in Google IPA, and Adding Latitude and Longitude
# 910 Found Litchfield in Google IPA, and Adding Latitude and Longitude
# 911 Found Petrolia in Google IPA, and Adding Latitude and Longitude
# 912 Found Lewiston in Google IPA, and Adding Latitude and Longitude
# 913 Found Wendel in Google IPA, and Adding Latitude and Longitude
# 914 Found Potrero in Google IPA, and Adding Latitude and Longitude
# 915 Found Wallace in Google IPA, and Adding Latitude and Longitude
# 916 Found Inverness in Google IPA, and Adding Latitude and Longitude
# 917 Found El Nido in Google IPA, and Adding Latitude and Longitude
# 918 Found Graton in Google IPA, and Adding Latitude and Longitude
# 919 Found Hyampom in Google IPA, and Adding Latitude and Longitude
# 920 Found Old Station in Google IPA, and Adding Latitude and Longitude
# 921 Found French Gulch in Google IPA, and Adding Latitude and Longitude
# 922 Found Carnelian Bay in Google IPA, and Adding Latitude and Longitude
# 923 Found Ione in Google IPA, and Adding Latitude and Longitude
# 924 Found Lebec in Google IPA, and Adding Latitude and Longitude
# 925 Found San Ardo in Google IPA, and Adding Latitude and Longitude
# 926 Found Junction City in Google IPA, and Adding Latitude and Longitude
# 927 Found Korbel in Google IPA, and Adding Latitude and Longitude
# 928 Found Stirling City in Google IPA, and Adding Latitude and Longitude
# 929 Found Independence in Google IPA, and Adding Latitude and Longitude
# 930 Found Redcrest in Google IPA, and Adding Latitude and Longitude
# 931 Found Port Costa in Google IPA, and Adding Latitude and Longitude
# 932 Found Bangor in Google IPA, and Adding Latitude and Longitude
# 933 Found Hat Creek in Google IPA, and Adding Latitude and Longitude
# 934 Found Montgomery Creek in Google IPA, and Adding Latitude and Longitude
# 935 Found Alta in Google IPA, and Adding Latitude and Longitude
# 936 Found Ducor in Google IPA, and Adding Latitude and Longitude
# 937 Found O Neals in Google IPA, and Adding Latitude and Longitude
# 938 Found Sugarloaf in Google IPA, and Adding Latitude and Longitude
# 939 Found Strawberry in Google IPA, and Adding Latitude and Longitude
# 940 Found Bella Vista in Google IPA, and Adding Latitude and Longitude
# 941 Found San Simeon in Google IPA, and Adding Latitude and Longitude
# 942 Found Vernon in Google IPA, and Adding Latitude and Longitude
# 943 Found Vallecito in Google IPA, and Adding Latitude and Longitude
# 944 Found San Geronimo in Google IPA, and Adding Latitude and Longitude
# 945 Found Caspar in Google IPA, and Adding Latitude and Longitude
# 946 Found Gold Run in Google IPA, and Adding Latitude and Longitude
# 947 Found Montara in Google IPA, and Adding Latitude and Longitude
# 948 Found Annapolis in Google IPA, and Adding Latitude and Longitude
# 949 Found Pope Valley in Google IPA, and Adding Latitude and Longitude
# 950 Found Armona in Google IPA, and Adding Latitude and Longitude
# 951 Found Kettleman City in Google IPA, and Adding Latitude and Longitude
# 952 Found Fiddletown in Google IPA, and Adding Latitude and Longitude
# 953 Found Marshall in Google IPA, and Adding Latitude and Longitude
# 954 Found Paskenta in Google IPA, and Adding Latitude and Longitude
# 955 Found Miramonte in Google IPA, and Adding Latitude and Longitude
# 956 Found Stinson Beach in Google IPA, and Adding Latitude and Longitude
# 957 Found Sutter Creek in Google IPA, and Adding Latitude and Longitude
# 958 Found Forest Falls in Google IPA, and Adding Latitude and Longitude
# 959 Found Butte City in Google IPA, and Adding Latitude and Longitude
# 960 Found Cedarville in Google IPA, and Adding Latitude and Longitude
# 961 Found Madeline in Google IPA, and Adding Latitude and Longitude
# 962 Found Termo in Google IPA, and Adding Latitude and Longitude
# 963 Found Comptche in Google IPA, and Adding Latitude and Longitude
# 964 Found Orick in Google IPA, and Adding Latitude and Longitude
# 965 Found Burnt Ranch in Google IPA, and Adding Latitude and Longitude
# 966 Found Badger in Google IPA, and Adding Latitude and Longitude
# 967 Found Blocksburg in Google IPA, and Adding Latitude and Longitude
# 968 Found Tomales in Google IPA, and Adding Latitude and Longitude
# 969 Found Grenada in Google IPA, and Adding Latitude and Longitude
# 970 Found Camptonville in Google IPA, and Adding Latitude and Longitude
# 971 Found Bridgeville in Google IPA, and Adding Latitude and Longitude
# 972 Found Pinecrest in Google IPA, and Adding Latitude and Longitude
# 973 Found Bodega in Google IPA, and Adding Latitude and Longitude
# 974 Found Campo Seco in Google IPA, and Adding Latitude and Longitude
# 975 Found Harmony in Google IPA, and Adding Latitude and Longitude
# 976 Found Homewood in Google IPA, and Adding Latitude and Longitude
# 977 Found Taylorsville in Google IPA, and Adding Latitude and Longitude
# 978 Found Green Valley in Google IPA, and Adding Latitude and Longitude
# 979 Found Elk Creek in Google IPA, and Adding Latitude and Longitude
# 980 Found Leggett in Google IPA, and Adding Latitude and Longitude
# 981 Found Piru in Google IPA, and Adding Latitude and Longitude
# 982 Found Nubieber in Google IPA, and Adding Latitude and Longitude
# 983 Found San Gregorio in Google IPA, and Adding Latitude and Longitude
# 984 Found Chilcoot in Google IPA, and Adding Latitude and Longitude
# 985 Found Big Bar in Google IPA, and Adding Latitude and Longitude
# 986 Found Round Mountain in Google IPA, and Adding Latitude and Longitude
# 987 Found Lee Vining in Google IPA, and Adding Latitude and Longitude
# 988 Found Brooks in Google IPA, and Adding Latitude and Longitude
# 989 Found Manchester in Google IPA, and Adding Latitude and Longitude
# 990 Found Fish Camp in Google IPA, and Adding Latitude and Longitude
# 991 Found Westport in Google IPA, and Adding Latitude and Longitude
# 992 Found Vina in Google IPA, and Adding Latitude and Longitude
# 993 Found Essex in Google IPA, and Adding Latitude and Longitude
# 994 Found Canby in Google IPA, and Adding Latitude and Longitude
# 995 Found Los Alamos in Google IPA, and Adding Latitude and Longitude
# 996 Found Adin in Google IPA, and Adding Latitude and Longitude
# 997 Found Callahan in Google IPA, and Adding Latitude and Longitude
# 998 Found Fort Bidwell in Google IPA, and Adding Latitude and Longitude
# 999 Found Orleans in Google IPA, and Adding Latitude and Longitude
# 1000 Found Jacumba in Google IPA, and Adding Latitude and Longitude
# 1001 Found Paynes Creek in Google IPA, and Adding Latitude and Longitude
# 1002 Found Seiad Valley in Google IPA, and Adding Latitude and Longitude
# 1003 Found Davis Creek in Google IPA, and Adding Latitude and Longitude
# 1004 Found Big Creek in Google IPA, and Adding Latitude and Longitude
# 1005 Found Westley in Google IPA, and Adding Latitude and Longitude
# 1006 Found Valley Ford in Google IPA, and Adding Latitude and Longitude
# 1007 Found Willow Creek in Google IPA, and Adding Latitude and Longitude
# 1008 Found Graeagle in Google IPA, and Adding Latitude and Longitude
# 1009 Found Mill Creek in Google IPA, and Adding Latitude and Longitude
# 1010 Found Big Bend in Google IPA, and Adding Latitude and Longitude
# 1011 Found June Lake in Google IPA, and Adding Latitude and Longitude
# 1012 Found Manton in Google IPA, and Adding Latitude and Longitude
# 1013 Found Likely in Google IPA, and Adding Latitude and Longitude
# 1014 Found Downieville in Google IPA, and Adding Latitude and Longitude
# 1015 Found Zenia in Google IPA, and Adding Latitude and Longitude
# 1016 Found Branscomb in Google IPA, and Adding Latitude and Longitude
# 1017 Found Wilseyville in Google IPA, and Adding Latitude and Longitude
# 1018 Found Glencoe in Google IPA, and Adding Latitude and Longitude
# 1019 Found El Portal in Google IPA, and Adding Latitude and Longitude
# 1020 Found Casmalia in Google IPA, and Adding Latitude and Longitude
# 1021 Found Yermo in Google IPA, and Adding Latitude and Longitude
# 1022 Found Castella in Google IPA, and Adding Latitude and Longitude
# 1023 Found Avery in Google IPA, and Adding Latitude and Longitude
# 1024 Found Sierra City in Google IPA, and Adding Latitude and Longitude
# 1025 Found Keene in Google IPA, and Adding Latitude and Longitude
# 1026 Found Grimes in Google IPA, and Adding Latitude and Longitude
# 1027 Found Daggett in Google IPA, and Adding Latitude and Longitude
# 1028 Found Bieber in Google IPA, and Adding Latitude and Longitude
# 1029 Found New Pine Creek in Google IPA, and Adding Latitude and Longitude
# 1030 Found Clio in Google IPA, and Adding Latitude and Longitude
# 1031 Found Raisin City in Google IPA, and Adding Latitude and Longitude
# 1032 Found Lookout in Google IPA, and Adding Latitude and Longitude
# 1033 Found Nipton in Google IPA, and Adding Latitude and Longitude
# 1034 Found Forbestown in Google IPA, and Adding Latitude and Longitude
# 1035 Found Clipper Mills in Google IPA, and Adding Latitude and Longitude
# 1036 Found Dutch Flat in Google IPA, and Adding Latitude and Longitude
# 1037 Found Lemon Cove in Google IPA, and Adding Latitude and Longitude
# 1038 Found Topaz in Google IPA, and Adding Latitude and Longitude
# 1039 Found Mad River in Google IPA, and Adding Latitude and Longitude
# 1040 Found Alderpoint in Google IPA, and Adding Latitude and Longitude
# 1041 Found Standish in Google IPA, and Adding Latitude and Longitude
# 1042 Found Hornitos in Google IPA, and Adding Latitude and Longitude
# 1043 Found Olancha in Google IPA, and Adding Latitude and Longitude
# 1044 Found Woody in Google IPA, and Adding Latitude and Longitude
# 1045 Found Calpine in Google IPA, and Adding Latitude and Longitude
# 1046 Found Eagleville in Google IPA, and Adding Latitude and Longitude
# 1047 Found Milford in Google IPA, and Adding Latitude and Longitude
# 1048 Found Hume in Google IPA, and Adding Latitude and Longitude
# 1049 Found Rackerby in Google IPA, and Adding Latitude and Longitude
# 1050 Found Princeton in Google IPA, and Adding Latitude and Longitude
# 1051 Found Lake City in Google IPA, and Adding Latitude and Longitude
# 1052 Found Benton in Google IPA, and Adding Latitude and Longitude
# 1053 Found Strawberry Valley in Google IPA, and Adding Latitude and Longitude
# 1054 Found Emigrant Gap in Google IPA, and Adding Latitude and Longitude
# 1055 Found Palomar Mountain in Google IPA, and Adding Latitude and Longitude
# 1056 Found Ravendale in Google IPA, and Adding Latitude and Longitude
# 1057 Found Clements in Google IPA, and Adding Latitude and Longitude
# 1058 Found Valyermo in Google IPA, and Adding Latitude and Longitude
# 1059 Found Canyon Dam in Google IPA, and Adding Latitude and Longitude
# 1060 Found Somes Bar in Google IPA, and Adding Latitude and Longitude
# 1061 Found Beckwourth in Google IPA, and Adding Latitude and Longitude
# 1062 Found Duncans Mills in Google IPA, and Adding Latitude and Longitude
# 1063 Found Thornton in Google IPA, and Adding Latitude and Longitude
# 1064 Found Deer Park in Google IPA, and Adding Latitude and Longitude
# 1065 Found Glennville in Google IPA, and Adding Latitude and Longitude
# 1066 Found Sierraville in Google IPA, and Adding Latitude and Longitude
# 1067 Found Twain in Google IPA, and Adding Latitude and Longitude
# 1068 Found Loma Mar in Google IPA, and Adding Latitude and Longitude
# 1069 Found Elmira in Google IPA, and Adding Latitude and Longitude
# 1070 Found Crescent Mills in Google IPA, and Adding Latitude and Longitude
# 1071 Found Zamora in Google IPA, and Adding Latitude and Longitude
# 1072 Found Long Barn in Google IPA, and Adding Latitude and Longitude
# 1073 Found Fawnskin in Google IPA, and Adding Latitude and Longitude
# 1074 Found Soda Springs in Google IPA, and Adding Latitude and Longitude
# 1075 Found Kyburz in Google IPA, and Adding Latitude and Longitude
# 1076 Found Twin Bridges in Google IPA, and Adding Latitude and Longitude
# 1077 Found Echo Lake in Google IPA, and Adding Latitude and Longitude
# 1078 Found Tehama in Google IPA, and Adding Latitude and Longitude
# 1079 Found Nelson in Google IPA, and Adding Latitude and Longitude
# 1080 Found Big Oak Flat in Google IPA, and Adding Latitude and Longitude
# 1081 Found Miranda in Google IPA, and Adding Latitude and Longitude
# 1082 Found Madison in Google IPA, and Adding Latitude and Longitude
# 1083 Found Camp Meeker in Google IPA, and Adding Latitude and Longitude
# 1084 Found Bear Valley in Google IPA, and Adding Latitude and Longitude
# 1085 Found Guinda in Google IPA, and Adding Latitude and Longitude
# 1086 Found Meadow Valley in Google IPA, and Adding Latitude and Longitude
# 1087 Found Keeler in Google IPA, and Adding Latitude and Longitude
# 1088 Found Washington in Google IPA, and Adding Latitude and Longitude
# 1089 Found Little Grass Valley in Google IPA, and Adding Latitude and Longitude
# 1090 Found Shasta in Google IPA, and Adding Latitude and Longitude
# 1091 Found Biola in Google IPA, and Adding Latitude and Longitude
# 1092 Found Cassel in Google IPA, and Adding Latitude and Longitude
# 1093 Found Amador City in Google IPA, and Adding Latitude and Longitude
# 1094 Found Kirkwood in Google IPA, and Adding Latitude and Longitude
# 1095 Found San Lucas in Google IPA, and Adding Latitude and Longitude
# 1096 Found Empire in Google IPA, and Adding Latitude and Longitude
# 1097 Found Goodyears Bar in Google IPA, and Adding Latitude and Longitude
# 1098 Found River Pines in Google IPA, and Adding Latitude and Longitude
# 1099 Found McCloud in Google IPA, and Adding Latitude and Longitude
# 1100 Found Mount Baldy in Google IPA, and Adding Latitude and Longitude
# 1101 Found Mettler in Google IPA, and Adding Latitude and Longitude
# 1102 Found North Palm Springs in Google IPA, and Adding Latitude and Longitude
# 1103 Found Fields Landing in Google IPA, and Adding Latitude and Longitude
# 1104 Found Lockwood in Google IPA, and Adding Latitude and Longitude
# 1105 Found Tecopa in Google IPA, and Adding Latitude and Longitude
# 1106 Found Challenge in Google IPA, and Adding Latitude and Longitude
# 1107 Found Honeydew in Google IPA, and Adding Latitude and Longitude
# 1108 Found Darwin in Google IPA, and Adding Latitude and Longitude

# %%
#print count of cities that failed and the names
print(len(failedcity))
print((failedcity))
# Out:
# 0
# []

# %%
#Show the new DF
SingleCCal

#Dropping Outliers for purposes of Graphs3,4,6
SingleCCal = SingleCCal[SingleCCal.RegionName != "Truckee"]

SingleCCal
# Out:
#        RegionID  SizeRank     RegionName RegionType StateName State  \
# 1         12447         1    Los Angeles       City        CA    CA
# 8         54296         8      San Diego       City        CA    CA
# 11        33839        11       San Jose       City        CA    CA
# 14        20330        14  San Francisco       City        CA    CA
# 30        20288        30     Sacramento       City        CA    CA
# ...         ...       ...            ...        ...       ...   ...
# 26401     29195     29449       Lockwood       City        CA    CA
# 26406     36339     29449         Tecopa       City        CA    CA
# 26435     17380     29449      Challenge       City        CA    CA
# 26466     21913     29449       Honeydew       City        CA    CA
# 26472     28264     29449         Darwin       City        CA    CA
#
#                                      Metro            CountyName  2012-12-31  \
# 1           Los Angeles-Long Beach-Anaheim    Los Angeles County    450942.0
# 8                       San Diego-Carlsbad      San Diego County    474020.0
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    588222.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    824245.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    174266.0
# ...                                    ...                   ...         ...
# 26401                              Salinas       Monterey County         NaN
# 26406                                  NaN           Inyo County         NaN
# 26435                            Yuba City           Yuba County    129791.0
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
# 26472                                  NaN           Inyo County         NaN
#
#        2013-01-31  ...  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 1        456335.0  ...    766002.0    770182.0    774078.0    780205.0
# 8        480412.0  ...    730853.0    734733.0    740112.0    744208.0
# 11       599714.0  ...   1027883.0   1034380.0   1046264.0   1057397.0
# 14       841667.0  ...   1519514.0   1531203.0   1535710.0   1539101.0
# 30       177728.0  ...    356618.0    358601.0    360857.0    362724.0
# ...           ...  ...         ...         ...         ...         ...
# 26401         NaN  ...    613047.0    613266.0    611159.0    610241.0
# 26406         NaN  ...     34687.0     34614.0     34465.0     34328.0
# 26435    130369.0  ...    215080.0    215313.0    215703.0    214733.0
# 26466         NaN  ...    688958.0    698685.0    707643.0    720505.0
# 26472         NaN  ...     48758.0     48704.0     48665.0     48617.0
#
#        2020-03-31  2020-04-30  2020-05-31  2020-06-30  Latitude  Longitude
# 1        785793.0    789989.0    790037.0    788920.0   34.0522   -118.244
# 8        748744.0    751096.0    753893.0    754223.0   32.7157   -117.161
# 11      1068942.0   1074703.0   1080058.0   1088749.0   37.3382   -121.886
# 14      1535882.0   1533941.0   1523778.0   1511653.0   37.7749   -122.419
# 30       365194.0    366583.0    366772.0    366198.0   38.5816   -121.494
# ...           ...         ...         ...         ...       ...        ...
# 26401    611718.0    615934.0    623633.0    631555.0   35.9441   -121.082
# 26406     34042.0     33631.0     33159.0     32578.0   35.8483   -116.226
# 26435    212881.0    211004.0    208809.0    205041.0   39.4856   -121.231
# 26466    733777.0    749997.0    767960.0    792172.0   40.2432   -124.123
# 26472     48550.0     48529.0     48557.0     48661.0    36.268   -117.592
#
# [1107 rows x 101 columns]

# %%
#Converting column values to numbers
SingleCCal['Latitude']  = pd.to_numeric(SingleCCal['Latitude'],errors = 'coerce')
SingleCCal['Longitude']  = pd.to_numeric(SingleCCal['Longitude'],errors = 'coerce')
#Creating a DF for just Northern California
SingleNCity  = SingleCCal.loc[SingleCCal['Latitude'].gt(37)==True]
SingleNCity
# Out:
#        RegionID  SizeRank      RegionName RegionType StateName State  \
# 11        33839        11        San Jose       City        CA    CA
# 14        20330        14   San Francisco       City        CA    CA
# 30        20288        30      Sacramento       City        CA    CA
# 45        13072        45         Oakland       City        CA    CA
# 79         7266        80        Stockton       City        CA    CA
# ...         ...       ...             ...        ...       ...   ...
# 26173     50219     29449     River Pines       City        CA    CA
# 26198      9014     29449         McCloud       City        CA    CA
# 26305     11431     29449  Fields Landing       City        CA    CA
# 26435     17380     29449       Challenge       City        CA    CA
# 26466     21913     29449        Honeydew       City        CA    CA
#
#                                      Metro            CountyName  2012-12-31  \
# 11          San Jose-Sunnyvale-Santa Clara    Santa Clara County    588222.0
# 14           San Francisco-Oakland-Hayward  San Francisco County    824245.0
# 30     Sacramento--Roseville--Arden-Arcade     Sacramento County    174266.0
# 45           San Francisco-Oakland-Hayward        Alameda County    396996.0
# 79                           Stockton-Lodi    San Joaquin County    141257.0
# ...                                    ...                   ...         ...
# 26173                                  NaN         Amador County     75866.0
# 26198                                  NaN       Siskiyou County    157275.0
# 26305                Eureka-Arcata-Fortuna       Humboldt County    207525.0
# 26435                            Yuba City           Yuba County    129791.0
# 26466                Eureka-Arcata-Fortuna       Humboldt County         NaN
#
#        2013-01-31  ...  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# 11       599714.0  ...   1027883.0   1034380.0   1046264.0   1057397.0
# 14       841667.0  ...   1519514.0   1531203.0   1535710.0   1539101.0
# 30       177728.0  ...    356618.0    358601.0    360857.0    362724.0
# 45       407238.0  ...    831207.0    836265.0    842970.0    847396.0
# 79       143062.0  ...    314393.0    316322.0    317459.0    319191.0
# ...           ...  ...         ...         ...         ...         ...
# 26173     76790.0  ...    117252.0    118747.0    120672.0    122050.0
# 26198    158565.0  ...    224779.0    224773.0    224615.0    224075.0
# 26305    210453.0  ...    280930.0    280717.0    278815.0    277085.0
# 26435    130369.0  ...    215080.0    215313.0    215703.0    214733.0
# 26466         NaN  ...    688958.0    698685.0    707643.0    720505.0
#
#        2020-03-31  2020-04-30  2020-05-31  2020-06-30   Latitude   Longitude
# 11      1068942.0   1074703.0   1080058.0   1088749.0  37.338208 -121.886329
# 14      1535882.0   1533941.0   1523778.0   1511653.0  37.774929 -122.419415
# 30       365194.0    366583.0    366772.0    366198.0  38.581572 -121.494400
# 45       849890.0    848782.0    845181.0    841257.0  37.804351 -122.271164
# 79       319988.0    321367.0    321519.0    320896.0  37.957702 -121.290780
# ...           ...         ...         ...         ...        ...         ...
# 26173    124010.0    125275.0    125754.0    125431.0  38.546296 -120.744100
# 26198    223584.0    223098.0    222318.0    221061.0  41.255712 -122.139449
# 26305    275763.0    276381.0    277400.0    277990.0  40.724912 -124.216377
# 26435    212881.0    211004.0    208809.0    205041.0  39.485614 -121.231158
# 26466    733777.0    749997.0    767960.0    792172.0  40.243234 -124.123013
#
# [607 rows x 101 columns]

# %%
#Declairing a function and setting 4 variable  Max and min on  Longitude and latitude 
def singlecity(latMin, latMax, lngMin, lngMax):  
    #Create a copy of the DF of fire and single city
    SingleFire = Nfire.copy()
    #create a box of latitude and longitude using the DFs
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMin))==True]
    SingleFire = SingleFire.loc[SingleFire['Latitude'].gt(int(latMax))==False]

    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMin))==False]
    SingleFire = SingleFire.loc[SingleFire['Longitude'].gt(int(lngMax))==True]
    
    
    SingleCity = SingleNCity.copy()
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMin))==True]
    SingleCity = SingleCity.loc[SingleCity['Latitude'].gt(int(latMax))==False]

    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMin))==False]
    SingleCity = SingleCity.loc[SingleCity['Longitude'].gt(int(lngMax))==True]
    #return the DF into a list
    return [SingleCity, SingleFire]

# %%
#Create a list to hold the DF CHICO/PARADISE
TwoSingleCity_Fire = []
#choose the Lat and Long
TwoSingleCity_Fire =singlecity(39.5,40.5,-120.3,-122)
#Print number of rows
print(f'There are {TwoSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {TwoSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show

#cleaning the City Data
#picking the columns
TwoSingleCity_Fire[0] = TwoSingleCity_Fire[0][["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30','Latitude',"Longitude"]] 
#if they are missing any data we drop the city 
TwoSingleCity_Fire[0] = TwoSingleCity_Fire[0].dropna(how='any')


#picking the columns we wanted 
TwoSingleCity_Fire[1] = TwoSingleCity_Fire[1][['Name','AcresBurned','ArchiveYear','Started','Extinguished','Latitude',"Longitude"]]
#dropping missing data 
TwoSingleCity_Fire[1] = TwoSingleCity_Fire[1].dropna(how= 'any')
#dropping the duplicates(there were duplicates for the counties)
TwoSingleCity_Fire[1] = TwoSingleCity_Fire[1].drop_duplicates(subset = 'Name')
#organizing by achers burned
TwoSingleCity_Fire[1] = TwoSingleCity_Fire[1].sort_values(by ='AcresBurned',ascending = False)
#print number of rows after cleaning
print(f'There are {TwoSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {TwoSingleCity_Fire[1]["Name"].count()} Fires')
# Out:
# There are 68 Cities
# There are 110 Fires
# There are 65 Cities
# There are 102 Fires

# %%
#create new Data Frame with columns we want
fillempty = TwoSingleCity_Fire[1][['Name','Started']]
#choose the top best fires(They were already sorted by acres burned)
fillempty = fillempty.head(5)
#make sure the DF is a DF and not a list
fillempty= pd.DataFrame(fillempty)
#print Dates for Reference against decimal points
print(fillempty)
#taking the year and making it a whole number then taking the month and day and turning it into a decimal
for index, row in fillempty.iterrows():
    #create variable to hold date value
    strdate = str(row[1])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date string
    if month == 1:
        fillempty.loc[index,'Started'] = year +((day)/365)
    if month == 2:
        fillempty.loc[index,'Started'] = year +((day+28)/365)   
    if month == 3:
        fillempty.loc[index,'Started'] = year +((day+28+31)/365) 
    if month == 4:
        fillempty.loc[index,'Started'] = year +((day+28+31+30)/365) 
    if month == 5:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 

#create location Speicific DF 
Twofillempty = fillempty.copy()

#present DF
Twofillempty
# Out:
#                              Name     Started
# 1060                    Camp Fire  2018-11-30
# 3                   American Fire  2013-08-31
# 644   Cascade Fire (Wind Complex)  2017-10-31
# 647                 Cherokee Fire  2017-10-31
# 653   LaPorte Fire (Wind Complex)  2017-10-31
#                              Name  Started
# 1060                    Camp Fire  2018.91
# 3                   American Fire  2013.67
# 644   Cascade Fire (Wind Complex)  2017.83
# 647                 Cherokee Fire  2017.83
# 653   LaPorte Fire (Wind Complex)  2017.83

# %%
####Graph number 6

#Create copy of Fire DF and choose columns we want to keep
CityLine = TwoSingleCity_Fire[0][["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 
#select top 10 cities
CityLine = CityLine.head(10)
#index the DF by Region name
CityLine = CityLine.set_index('RegionName')
#flip(transpose) the indexed values(RegionName) with the columns
CityLine = CityLine.T
#reset the index to allow the days to be edited
CityLine = CityLine.reset_index()
#taking the year and making it a whole number then taking the month and day and turning it into a decimal
for index, row in CityLine.iterrows():
        #create variable to hold date value
    strdate = str(row[0])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date string
    if month == 1:
        CityLine.loc[index,'index'] = year +((day)/365)
    if month == 2:
        CityLine.loc[index,'index'] = year +((day+28)/365)   
    if month == 3:
        CityLine.loc[index,'index'] = year +((day+28+31)/365) 
    if month == 4:
        CityLine.loc[index,'index'] = year +((day+28+31+30)/365) 
    if month == 5:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 
#create location Speicific DF 
Twoline = CityLine.copy()


#pull location from Speicific DF 
fillempty = Twofillempty.copy()

#Create plot
ax = Twoline.plot(x='index',figsize= (9,9))
#create color pallet
color = ['black','red']
#create color counter for 5 fires
colorcount = 0
#create line styles for fires 
linestyle = ["", "-" ,"--", '-.', ':']
#create a for loop to create different line styles for the fires
for index, row in fillempty.iterrows():
    if colorcount == 0:
        ax.axvline( row[1],color=color[1], label = row[0])
    else:
        ax.axvline( row[1],color=color[0], linestyle = linestyle[colorcount], label = row[0])
    colorcount+=1
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Chico/Paradise Area \nPrice of Single Households VS Time \nWith Major Fire Constants" )
#save file outside notebook
plt.savefig("Images/ChicoHouseWithFireConst.png")
#show Graph
plt.show()

# %%
##Graph#3

#plot line data and create graph
ax = Twoline.plot(x='index',figsize= (10,10))
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Chico/Paradise Area \nPrice of Single Households VS Time" )
#Save file outside notebook
plt.savefig("Images/ChicoHouse.png")
#show graph
plt.show()

# %%
#####Graph number 4
#create copy of city data
heatcity = TwoSingleCity_Fire[0]
#choose columns wanted
heatcity = heatcity[['RegionName','Latitude',"Longitude"]]
#choose top 25 cities
heatcity = heatcity.head(25)
# create lat and lng list            
locationsheatcity = heatcity[['Latitude',"Longitude"]]
#get fire data
heatfire = TwoSingleCity_Fire[1]
#choose columns wanted
heatfire = heatfire[['Name','AcresBurned','Latitude',"Longitude"]]
# choose top 25 fires
heatfire = heatfire.head(25)
#create lat and lng list of fire data
locheatfire = heatfire[['Latitude','Longitude']]
#create how intense we want the heat areas to be off acers burned
heat = heatfire['AcresBurned'].astype(float)
#create map figure
fig = gmaps.figure()
#create heat locations
heatH = gmaps.heatmap_layer(locheatfire,weights = heat,dissipating = False,
                           max_intensity = 1, point_radius = .01)
#Create info box for cities
info_box_template = """
<dl>
<dt>City</dt><dd>{RegionName}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
cityinfo = [info_box_template.format(**row) for index, row in heatcity.iterrows()]
marker = gmaps.marker_layer(locationsheatcity, info_box_content = cityinfo) 
#add city markers on map
fig.add_layer(marker)
#add heat layer on map
fig.add_layer(heatH)
#Save images outside of the notebook
embed_minimal_html('Images/chicoHeatcitiesandfire.html', views=[fig])
#show figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a list to hold the DF SACRAMENTO
ThreeSingleCity_Fire = []
#choose the Lat and Long
ThreeSingleCity_Fire =singlecity(38,39,-120,-122)
#print number of rows at start
print(f'There are {ThreeSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {ThreeSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show
ThreeSingleCity_Fire[0].head()

#cleaning the City Data
#picking the columns
ThreeSingleCity_Fire[0] = ThreeSingleCity_Fire[0][["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30','Latitude',"Longitude"]] 
#if they are missing any data we drop the city 
ThreeSingleCity_Fire[0] = ThreeSingleCity_Fire[0].dropna(how='any')


#picking the columns we wanted 
ThreeSingleCity_Fire[1] = ThreeSingleCity_Fire[1][['Name','AcresBurned','ArchiveYear','Started','Extinguished','Latitude',"Longitude"]]
#dropping missing data 
ThreeSingleCity_Fire[1] = ThreeSingleCity_Fire[1].dropna(how= 'any')
#dropping the duplicates(there were duplicates for the counties)
ThreeSingleCity_Fire[1] = ThreeSingleCity_Fire[1].drop_duplicates(subset = 'Name')
# #organizing by achers burned
ThreeSingleCity_Fire[1] = ThreeSingleCity_Fire[1].sort_values(by ='AcresBurned',ascending = False)

#print number of rows after cleaning
print(f'There are {ThreeSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {ThreeSingleCity_Fire[1]["Name"].count()} Fires')
# Out:
# There are 106 Cities
# There are 95 Fires
# There are 99 Cities
# There are 85 Fires

# %%
#create new Data Frame with columns we want
fillempty = ThreeSingleCity_Fire[1][['Name','Started']]
#choose the top best fires(They were already sorted by acres burned)
fillempty = fillempty.head(5)
#make sure the DF is a DF and not a list
fillempty= pd.DataFrame(fillempty)

#print Dates for Reference against decimal points
print(fillempty)

#taking the year and making it a whole number then taking the month and day and turning it into a decimal
for index, row in fillempty.iterrows():
    #create variable to hold date value
    strdate = str(row[1])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date string  
    if month == 1:
        fillempty.loc[index,'Started'] = year +((day)/365)
    if month == 2:
        fillempty.loc[index,'Started'] = year +((day+28)/365)   
    if month == 3:
        fillempty.loc[index,'Started'] = year +((day+28+31)/365) 
    if month == 4:
        fillempty.loc[index,'Started'] = year +((day+28+31+30)/365) 
    if month == 5:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 
#create location Speicific DF 
Threefillempty = fillempty.copy()

#present DF
Threefillempty
# Out:
#                 Name     Started
# 162        King Fire  2014-09-30
# 1079    Waverly Fire  2018-06-30
# 444   Trailhead Fire  2016-06-30
# 182        Sand Fire  2014-07-31
# 1408     Caples Fire  2019-10-31
#                 Name  Started
# 162        King Fire  2014.75
# 1079    Waverly Fire  2018.49
# 444   Trailhead Fire  2016.49
# 182        Sand Fire  2014.58
# 1408     Caples Fire  2019.83

# %%
####Graph number 6

#drop duplicates and create copy
CityLine = ThreeSingleCity_Fire[0].drop(ThreeSingleCity_Fire[0].loc[ThreeSingleCity_Fire[0]['RegionName']=='Pittsburg'].index)
#Choose columns we want to keep
CityLine = CityLine[["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 
#select top 10 cities
CityLine = CityLine.head(10)
#index the DF by Region name
CityLine = CityLine.set_index('RegionName')
#flip(transpose) the indexed values(RegionName) with the columns
CityLine = CityLine.T
#reset the index to allow the days to be edited
CityLine = CityLine.reset_index()
#create Decimal point out of month and ay
for index, row in CityLine.iterrows():
    #create variable to hold date value
    strdate = str(row[0])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date strin    
    if month == 1:
        CityLine.loc[index,'index'] = year +((day)/365)
    if month == 2:
        CityLine.loc[index,'index'] = year +((day+28)/365)   
    if month == 3:
        CityLine.loc[index,'index'] = year +((day+28+31)/365) 
    if month == 4:
        CityLine.loc[index,'index'] = year +((day+28+31+30)/365) 
    if month == 5:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 
#create location Speicific DF 
Threeline = CityLine.copy()

#pull location from specific DF 
fillempty = Threefillempty.copy()

#Create plot
ax = Threeline.plot(x='index',figsize= (10,10))
#create color pallet
color = ['black','red']
#create color counter for 5 fires
colorcount = 0
#create line styles for fires 
linestyle = ["", "-" ,"--", '-.', ':']
#create a for loop to create different line styles for the fires
for index, row in fillempty.iterrows():
    if colorcount == 0:
        ax.axvline( row[1],color=color[1], label = row[0])
    else:
        ax.axvline( row[1],color=color[0], linestyle = linestyle[colorcount], label = row[0])
    colorcount+=1
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Sacramento/Delta Area \nPrice of Single Households VS Time \nWith Major Fire Constants" )
#save file outside notebook
plt.savefig("Images/SacramentoHouseWithFireConst.png")
#show graph
plt.show()

# %%
##Graph#3
#plot line data and create graph
ax = Threeline.plot(x='index',figsize= (7,7))
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Sacramento/ Delta \nPrice of Single Households VS Time" )
#Save file outside notebook
plt.savefig("Images/SacramentoHouse.png")
#show graph
plt.show()

# %%
#####Graph number 4
#create copy of city data
heatcity = ThreeSingleCity_Fire[0]
#choose columns wanted
heatcity = heatcity[['RegionName','Latitude',"Longitude"]]
#choose top 25 cities
heatcity = heatcity.head(25)
# create lat and lng list                        
locationsheatcity = heatcity[['Latitude',"Longitude"]]
#get fire data
heatfire = ThreeSingleCity_Fire[1]
#choose columns wanted
heatfire = heatfire[['Name','AcresBurned','Latitude',"Longitude"]]
# choose top 25 fires
heatfire = heatfire.head(25)
#create lat and lng list of fire data
locheatfire = heatfire[['Latitude','Longitude']]
#create how intense we want the heat areas to be off acers burned
heat = heatfire['AcresBurned'].astype(float)
#create map figure
fig = gmaps.figure()
#create heat locations
heatH = gmaps.heatmap_layer(locheatfire,weights = heat,dissipating = False,
                           max_intensity = 1, point_radius = .01)

#Create info box for cities
info_box_template = """
<dl>
<dt>City</dt><dd>{RegionName}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
cityinfo = [info_box_template.format(**row) for index, row in heatcity.iterrows()]
marker = gmaps.marker_layer(locationsheatcity, info_box_content = cityinfo) 
#add city markers on map
fig.add_layer(marker)
#add heat layer on map
fig.add_layer(heatH)
#Save image outside of Notebook
embed_minimal_html('Images/SacHeatcitiesandfire.html', views=[fig])
#Show figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Create a list to hold the DF REDDING
FourSingleCity_Fire = []
#choose the Lat and Long
FourSingleCity_Fire =singlecity(40,41,-121,-123)
#pring number of rows at start

print(f'There are {FourSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {FourSingleCity_Fire[1]["Name"].count()} Fires')
#Choose DF to show
FourSingleCity_Fire[1]


#cleaning the City Data
#picking the columns
FourSingleCity_Fire[0] = FourSingleCity_Fire[0][["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30','Latitude',"Longitude"]] 
#if they are missing any data we drop the city 
FourSingleCity_Fire[0] = FourSingleCity_Fire[0].dropna(how='any')


#picking the columns we wanted 
FourSingleCity_Fire[1] = FourSingleCity_Fire[1][['Name','AcresBurned','ArchiveYear','Started','Extinguished','Latitude',"Longitude"]]
#dropping missing data 
FourSingleCity_Fire[1] = FourSingleCity_Fire[1].dropna(how= 'any')
#dropping the duplicates(there were duplicates for the counties)
FourSingleCity_Fire[1] = FourSingleCity_Fire[1].drop_duplicates(subset = 'Name')
#organizing by achers burned
FourSingleCity_Fire[1] = FourSingleCity_Fire[1].sort_values(by ='AcresBurned',ascending = False)
#print number of rows after cleanup
print(f'There are {FourSingleCity_Fire[0]["RegionName"].count()} Cities')
print(f'There are {FourSingleCity_Fire[1]["Name"].count()} Fires')
# Out:
# There are 36 Cities
# There are 107 Fires
# There are 21 Cities
# There are 97 Fires

# %%
#create new Data Frame with columns we want
fillempty = FourSingleCity_Fire[1][['Name','Started']]
#choose the top best fires(They were already sorted by acres burned)
fillempty = fillempty.head(5)
#make sure the DF is a DF and not a list
fillempty= pd.DataFrame(fillempty)
#print Dates for Reference against decimal points
print(fillempty)
#taking the year and making it a whole number then taking the month and day and turning it into a decimal
for index, row in fillempty.iterrows():
    #create variable to hold date value
    strdate = str(row[1])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date string
    if month == 1:
        fillempty.loc[index,'Started'] = year +((day)/365)
    if month == 2:
        fillempty.loc[index,'Started'] = year +((day+28)/365)   
    if month == 3:
        fillempty.loc[index,'Started'] = year +((day+28+31)/365) 
    if month == 4:
        fillempty.loc[index,'Started'] = year +((day+28+31+30)/365) 
    if month == 5:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        fillempty.loc[index,'Started'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 

        
#create location Speicific DF 
Fourfillempty = fillempty.copy()

#present DF
Fourfillempty
# Out:
#             Name     Started
# 1058   Carr Fire  2018-07-31
# 1066  Delta Fire  2018-09-30
# 1071   Hirz Fire  2018-08-31
# 164    Bald Fire  2014-07-31
# 167   Eiler Fire  2014-07-31
#             Name  Started
# 1058   Carr Fire  2018.58
# 1066  Delta Fire  2018.75
# 1071   Hirz Fire  2018.67
# 164    Bald Fire  2014.58
# 167   Eiler Fire  2014.58

# %%
####Graph number 6

#Drop outliers and create copy of DF
CityLine =FourSingleCity_Fire[0].drop(FourSingleCity_Fire[0].loc[FourSingleCity_Fire[0]['RegionName']=='Westwood'].index)
#Choose columns we want to keep
CityLine = FourSingleCity_Fire[0][["RegionName",'2012-12-31', '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30', '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30']] 
#select top 10 cities
CityLine = CityLine.head(10)
#index the DF by Region name
CityLine = CityLine.set_index('RegionName')
#flip(transpose) the indexed values(RegionName) with the columns
CityLine = CityLine.T
#reset the index to allow the days to be edited
CityLine = CityLine.reset_index()
#taking the year and making it a whole number then taking the month and day and turning it into a decimal
for index, row in CityLine.iterrows():
    #create variable to hold date value
    strdate = str(row[0])
    #split the Date into value, Day, month, and Year
    day = strdate.split('-')[2]
    month = strdate.split('-')[1]
    year = strdate.split('-')[0]
    #turn 3 date values to integers
    day = int(day)
    month = int(month)
    year = int(year)
    #turn Month Values into number of days add it to the "Day" variable and divide by number of days
    #then add back to the DF and replace the "Started" Date string
    if month == 1:
        CityLine.loc[index,'index'] = year +((day)/365)
    if month == 2:
        CityLine.loc[index,'index'] = year +((day+28)/365)   
    if month == 3:
        CityLine.loc[index,'index'] = year +((day+28+31)/365) 
    if month == 4:
        CityLine.loc[index,'index'] = year +((day+28+31+30)/365) 
    if month == 5:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31)/365) 
    if month == 6:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30)/365) 
    if month == 7:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31)/365) 
    if month == 8:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31)/365) 
    if month == 9:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30)/365) 
    if month == 10:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31)/365)         
    if month == 11:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30)/365) 
    if month == 12:
        CityLine.loc[index,'index'] = year +((day+28+31+30+31+30+31+31+30+31+30+31)/365) 
#create location Speicific DF 
Fourline = CityLine.copy()


#pull location from specific DF 

fillempty = Fourfillempty.copy()
#Create plot
ax = Fourline.plot(x='index',figsize= (10,10))
#create color pallet
color = ['black','red']
#create color counter for 5 fires
colorcount = 0
#create line styles for fires 
linestyle = ["", "-" ,"--", '-.', ':']
#create a for loop to create different line styles for the fires
for index, row in fillempty.iterrows():
    if colorcount == 0:
        ax.axvline( row[1],color=color[1], label = row[0])
    else:
        ax.axvline( row[1],color=color[0], linestyle = linestyle[colorcount], label = row[0])
    colorcount+=1
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Redding/Shasta Area \nPrice of Single Households VS Time \nWith Major Fire Constants" )
#save file outside notebook
plt.savefig("Images/ReddingHouseWithFireConst.png")
#show Graph
plt.show()

# %%
##Graph#3
#plot line data and create graph
ax = Fourline.plot(x='index',figsize= (10,10))
#set labels
ax.set(xlabel = "Years",ylabel='Price of Single Household',title ="Redding/Shasta Area \nPrice of Single Households VS Time" )
#Save file outside notebook
plt.savefig("Images/ReddingHouse.png")
#show graph
plt.show()

# %%
#####Graph number 4
#create copy of city data
heatcity = FourSingleCity_Fire[0]
#choose columns wanted
heatcity = heatcity[['RegionName','Latitude',"Longitude"]]

#choose top 25 cities
heatcity = heatcity.head(25)
                    
# create lat and lng list            
locationsheatcity = heatcity[['Latitude',"Longitude"]]

#get fire data
heatfire = FourSingleCity_Fire[1]
#choose columns wanted
heatfire = heatfire[['Name','AcresBurned','Latitude',"Longitude"]]
# choose top 25 cities
heatfire = heatfire.head(25)
#create lat and lng list of fire data
locheatfire = heatfire[['Latitude','Longitude']]
#create how intense we want the heat areas to be off acers burned
heat = heatfire['AcresBurned'].astype(float)
#create map figure
fig = gmaps.figure()
#create heat locations
heatH = gmaps.heatmap_layer(locheatfire,weights = heat,dissipating = False,
                           max_intensity = 1, point_radius = .01)

#Create info box for cities
info_box_template = """
<dl>
<dt>City</dt><dd>{RegionName}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
cityinfo = [info_box_template.format(**row) for index, row in heatcity.iterrows()]
marker = gmaps.marker_layer(locationsheatcity, info_box_content = cityinfo) 
#add city markers on map
fig.add_layer(marker)
#add heat layer on map
fig.add_layer(heatH)
#Save image outside of Notebook
embed_minimal_html('Images/SacHeatcitiesandfire.html', views=[fig])
#show figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
